# %%
import numpy as np
import scipy as sp
import math
import random
from scipy.stats import norm, poisson, entropy

nneuron = 41

sprefs = np.linspace(-60, 60, nneuron)

sig1_sq      = 3**2
sig2_sq      = 12**2
sigtc_sq     = 10**2
gains        = [1, 3, 15]
ndatapergain = 3000
mu = 0

def generate_popcode_noisy_data(ndatapergain, nneuron, sig1_sq, sig2_sq, sigtc_sq, gains):
    s1_s1 = np.random.normal(mu, math.sqrt(sig1_sq), ndatapergain/2)
    s1_s2 = np.random.normal(mu, math.sqrt(sig2_sq), ndatapergain/2)
    s1 = np.concatenate((s1_s1, s1_s2), axis=1)
    sprefs_data = np.tile(sprefs, (ndatapergain, 1))
    r1 = np.exp(-np.square((np.transpose(np.tile(s1, (nneuron, 1))) - sprefs_data))/(2 * sigtc_sq))
    ar1 = np.sum(r1, axis=1)/sigtc_sq
    br1 = np.sum(r1*sprefs_data, axis=1)/sigtc_sq
    
    term_1 = (1 + sig2_sq * ar1) / (1 + sig1_sq  * ar1)
    term_2_num = (sig2_sq - sig1_sq) * br1**2
    term_2_denom = 2 * (1 + sig1_sq  * ar1) * (1 + sig2_sq * ar1)
    xpnt_a = .5 * np.log(term_1) - term_2_num/term_2_denom
    p1 = 1/(1 + np.exp(-xpnt_a))
    return r1, p1

R, P = generate_popcode_noisy_data(ndatapergain, nneuron, sig1_sq, sig2_sq, sigtc_sq, gains)
print R
print P
# Out:
# [[  7.40900991e-10   4.95504111e-09   3.02864133e-08 ...,   5.66053618e-06
#     1.23839026e-06   2.47611598e-07]
#  [  7.68713257e-08   4.09232262e-07   1.99108066e-06 ...,   1.00869815e-07
#     1.75662714e-08   2.79583444e-09]
#  [  8.17266961e-09   4.87475336e-08   2.65738726e-07 ...,   8.07091644e-07
#     1.57479645e-07   2.80827414e-08]
#  ...,
#  [  1.99055121e-05   7.68497453e-05   2.71159613e-04 ...,   1.30192635e-10
#     1.64425195e-11   1.89785842e-12]
#  [  9.86339133e-10   6.50945186e-09   3.92623303e-08 ...,   4.54887828e-06
#     9.82053942e-07   1.93767023e-07]
#  [  4.00912945e-11   3.05519772e-10   2.12785514e-09 ...,   4.37350257e-05
#     1.09026357e-05   2.48397436e-06]]
# [ 0.62696013  0.69970751  0.72740228 ...,  0.06051833  0.64649615
#   0.32261149]

# %%
"""
This tutorial introduces the multilayer perceptron using Theano.

 A multilayer perceptron is a logistic regressor where
instead of feeding the input to the logistic regression you insert a
intermediate layer, called the hidden layer, that has a nonlinear
activation function (usually tanh or sigmoid) . One can use many such
hidden layers making the architecture deep. The tutorial will also tackle
the problem of MNIST digit classification.

.. math::

    f(x) = G( b^{(2)} + W^{(2)}( s( b^{(1)} + W^{(1)} x))),

References:

    - textbooks: "Pattern Recognition and Machine Learning" -
                 Christopher M. Bishop, section 5

"""

import os
import sys
import time

import numpy

import theano
import theano.tensor as T

def relu(x):
    return theano.tensor.switch(x<0, 0, x)

class HiddenLayer(object):
    def __init__(self, rng, input, n_in, n_out, W=None, b=None,
                 activation=relu):
        """
        Typical hidden layer of a MLP: units are fully-connected and have
        sigmoidal activation function. Weight matrix W is of shape (n_in,n_out)
        and the bias vector b is of shape (n_out,).

        NOTE : The nonlinearity used here is tanh

        Hidden unit activation is given by: tanh(dot(input,W) + b)

        :type rng: numpy.random.RandomState
        :param rng: a random number generator used to initialize weights

        :type input: theano.tensor.dmatrix
        :param input: a symbolic tensor of shape (n_examples, n_in)

        :type n_in: int
        :param n_in: dimensionality of input

        :type n_out: int
        :param n_out: number of hidden units

        :type activation: theano.Op or function
        :param activation: Non linearity to be applied in the hidden
                           layer
        """
        self.input = input
        # end-snippet-1

        # `W` is initialized with `W_values` which is uniformely sampled
        # from sqrt(-6./(n_in+n_hidden)) and sqrt(6./(n_in+n_hidden))
        # for tanh activation function
        # the output of uniform if converted using asarray to dtype
        # theano.config.floatX so that the code is runable on GPU
        # Note : optimal initialization of weights is dependent on the
        #        activation function used (among other things).
        #        For example, results presented in [Xavier10] suggest that you
        #        should use 4 times larger initial weights for sigmoid
        #        compared to tanh
        #        We have no info for other function, so we use the same as
        #        tanh.
        if W is None:
            W_values = numpy.asarray(
                rng.uniform(
                    low=-numpy.sqrt(6. / (n_in + n_out)),
                    high=numpy.sqrt(6. / (n_in + n_out)),
                    size=(n_in, n_out)
                ),
                dtype=theano.config.floatX
            )
            if activation == theano.tensor.nnet.sigmoid:
                W_values *= 4

            W = theano.shared(value=W_values, name='W', borrow=True)

        if b is None:
            b_values = numpy.zeros((n_out,), dtype=theano.config.floatX)
            b = theano.shared(value=b_values, name='b', borrow=True)

        self.W = W
        self.b = b

        lin_output = T.dot(input, self.W) + self.b
        self.output = (
            lin_output if activation is None
            else activation(lin_output)
        )
        # parameters of the model
        self.params = [self.W, self.b]

class MLP(object):


    def __init__(self, rng, input, n_in, n_hidden, n_out):
        """Initialize the parameters for the multilayer perceptron

        :type rng: numpy.random.RandomState
        :param rng: a random number generator used to initialize weights

        :type input: theano.tensor.TensorType
        :param input: symbolic variable that describes the input of the
        architecture (one minibatch)

        :type n_in: int
        :param n_in: number of input units, the dimension of the space in
        which the datapoints lie

        :type n_hidden: int
        :param n_hidden: number of hidden units

        :type n_out: int
        :param n_out: number of output units, the dimension of the space in
        which the labels lie

        """

        # Since we are dealing with a one hidden layer MLP, this will translate
        # into a HiddenLayer with a tanh activation function connected to the
        # LogisticRegression layer; the activation function can be replaced by
        # sigmoid or any other nonlinear function
        self.hiddenLayer1 = HiddenLayer(
            rng=rng,
            input=input,
            n_in=n_in,
            n_out=n_hidden,
            activation=relu
        )
        
        self.hiddenLayer2 = HiddenLayer(
            rng=rng,
            input=self.hiddenLayer1.output,
            n_in=n_hidden,
            n_out=n_out,
            activation=relu
        )
        
        self.y_pred = self.hiddenLayer2.output
        
        # the parameters of the model are the parameters of the two layers it is made out of
        self.params = self.hiddenLayer1.params + self.hiddenLayer2.params
        
    def mse(self, y):
        # error between output and target
        print self.y_pred.shape
        print y
        return T.mean((self.y_pred.T - y) ** 2)
        #return T.mean((self.y_pred - y) ** 2)


def test_mlp(dataset, n_hidden=2, learning_rate=0.01, n_epochs=10, batch_size=20):
    """
    Demonstrate stochastic gradient descent optimization for a multilayer
    perceptron

    This is demonstrated on MNIST.

    :type learning_rate: float
    :param learning_rate: learning rate used (factor for the stochastic
    gradient

    :type n_epochs: int
    :param n_epochs: maximal number of epochs to run the optimizer

    :type dataset: string
    :param dataset: the path of the MNIST dataset file from
                 http://www.iro.umontreal.ca/~lisa/deep/data/mnist/mnist.pkl.gz


   """
    def shared_dataset(data_xy, borrow=True):
        """ Function that loads the dataset into shared variables

        The reason we store our dataset in shared variables is to allow
        Theano to copy it into the GPU memory (when code is run on GPU).
        Since copying data into the GPU is slow, copying a minibatch everytime
        is needed (the default behaviour if the data is not in a shared
        variable) would lead to a large decrease in performance.
        """
        data_x, data_y = data_xy
        shared_x = theano.shared(numpy.asarray(data_x,
                                               dtype='float32'),
                                 borrow=borrow)
        shared_y = theano.shared(numpy.asarray(data_y,
                                               dtype='float32'),
                                 borrow=borrow)
        print shared_y.get_value()
        # When storing data on the GPU it has to be stored as floats
        # therefore we will store the labels as ``floatX`` as well
        # (``shared_y`` does exactly that). But during our computations
        # we need them as ints (we use labels as index, and if they are
        # floats it doesn't make sense) therefore instead of returning
        # ``shared_y`` we will have to cast it to int. This little hack
        # lets ous get around this issue
        return shared_x, shared_y
    
    train_set_x, train_set_y = shared_dataset(dataset)

    # compute number of minibatches for training, validation and testing
    n_train_batches = train_set_x.get_value(borrow=True).shape[0] / batch_size
    
    test_data = generate_popcode_noisy_data(ndatapergain, nneuron, sig1_sq, sig2_sq, sigtc_sq, gains)
    test_set_x, test_set_y = shared_dataset(test_data)
    
    test_batch_size = 1
    
    ######################
    # BUILD ACTUAL MODEL #
    ######################
    print '... building the model'

    # allocate symbolic variables for the data
    index = T.lscalar()  # index to a [mini]batch
    x = T.fmatrix('x')   # input data from visual neurons
    y = T.fvector('y')  # posterior

    rng = numpy.random.RandomState(1234)

    # construct the MLP class
    classifier = MLP(
        rng=rng,
        input=x,
        n_in=41,
        n_hidden=n_hidden,
        n_out=1
    )

    # the cost we minimize during training is the mean squared error; cost is expressed
    # here symbolically
    cost = classifier.mse(y)

    # compute the gradient of cost with respect to theta (sotred in params)
    # the resulting gradients will be stored in a list gparams
    gparams = [T.grad(cost, param) for param in classifier.params]

    # specify how to update the parameters of the model as a list of
    # (variable, update expression) pairs

    # given two list the zip A = [a1, a2, a3, a4] and B = [b1, b2, b3, b4] of
    # same length, zip generates a list C of same size, where each element
    # is a pair formed from the two lists :
    #    C = [(a1, b1), (a2, b2), (a3, b3), (a4, b4)]
    updates = [
        (param, param - learning_rate * gparam)
        for param, gparam in zip(classifier.params, gparams)
    ]
    
    print train_set_x.get_value()

    # compiling a Theano function `train_model` that returns the cost, but
    # in the same time updates the parameter of the model based on the rules
    # defined in `updates`
    train_model = theano.function(
        inputs=[index],
        outputs=cost,
        updates=updates,
        givens={
            x: train_set_x[index * batch_size: (index + 1) * batch_size],
            y: train_set_y[index * batch_size: (index + 1) * batch_size]
        }
    )

    ###############
    # TRAIN MODEL #
    ###############
    print '... training'

    start_time = time.clock()

    epoch = 0
    done_looping = False

    while (epoch < n_epochs) and (not done_looping):
        epoch = epoch + 1
        for minibatch_index in xrange(n_train_batches):
            
            minibatch_avg_cost = train_model(minibatch_index)
            
            print "epoch " + repr(epoch)
            print "minibatch " + repr(minibatch_index + 1) + "/" + repr(n_train_batches)
            print "average cost " + repr(minibatch_avg_cost)

    end_time = time.clock()
    
    print 'testing'
    test_model = theano.function(
        inputs=[index],
        outputs=classifier.y_pred,
        givens={
            x: test_set_x[index * test_batch_size: (index + 1) * test_batch_size]
        }
    )
    
    true_ys = test_set_y.get_value()
    pred_ys = numpy.zeros(len(true_ys))
    for i in range(len(true_ys)):
        pred_ys[i] = test_model(i)
    
    return pred_ys, true_ys

train_data = generate_popcode_noisy_data(ndatapergain, nneuron, sig1_sq, sig2_sq, sigtc_sq, gains)
model, analytic = test_mlp(train_data)
# Out:
# [  7.30453730e-01   7.24649608e-01   7.29515314e-01 ...,   6.22892916e-01
#    4.23221320e-01   6.21800209e-05]
# [ 0.46702737  0.72629702  0.65461749 ...,  0.25288594  0.0035322
#   0.72507387]
# ... building the model
# Shape.0
# y
# [[  2.12361897e-08   1.20784421e-07   6.27854092e-07 ...,   3.44166409e-07
#     6.40347437e-08   1.08887077e-08]
#  [  3.32306804e-08   1.84755081e-07   9.38786911e-07 ...,   2.26933594e-07
#     4.12732639e-08   6.86044554e-09]
#  [  2.36102995e-08   1.33570182e-07   6.90607123e-07 ...,   3.12172347e-07
#     5.77717216e-08   9.77124071e-09]
#  ...,
#  [  2.59634874e-07   1.29517571e-06   5.90483614e-06 ...,   2.87903141e-08
#     4.69812900e-09   7.00675518e-10]
#  [  1.32683454e-06   6.04075740e-06   2.51350375e-05 ...,   4.56500171e-09
#     6.79874046e-10   9.25399896e-11]
#  [  1.34089392e-15   1.53499616e-14   1.60595617e-13 ...,   7.59752560e-03
#     2.84510269e-03   9.73726972e-04]]
# ... training
# epoch 1
# minibatch 1/150
# average cost array(0.2820808080186856)
# epoch 1
# minibatch 2/150
# average cost array(0.2536156533259225)
# epoch 1
# minibatch 3/150
# average cost array(0.2015471220729078)
# epoch 1
# minibatch 4/150
# average cost array(0.22148180078948915)
# epoch 1
# minibatch 5/150
# average cost array(0.19487154876446947)
# epoch 1
# minibatch 6/150
# average cost array(0.17940335508876387)
# epoch 1
# minibatch 7/150
# average cost array(0.16468434948264166)
# epoch 1
# minibatch 8/150
# average cost array(0.14243299054917405)
# epoch 1
# minibatch 9/150
# average cost array(0.1177043691343381)
# epoch 1
# minibatch 10/150
# average cost array(0.11741643406286748)
# epoch 1
# minibatch 11/150
# average cost array(0.09196631655780892)
# epoch 1
# minibatch 12/150
# average cost array(0.08740522626699067)
# epoch 1
# minibatch 13/150
# average cost array(0.08566838541719927)
# epoch 1
# minibatch 14/150
# average cost array(0.07211645823008508)
# epoch 1
# minibatch 15/150
# average cost array(0.06580179021793962)
# epoch 1
# minibatch 16/150
# average cost array(0.06228403481340161)
# epoch 1
# minibatch 17/150
# average cost array(0.05918386361570001)
# epoch 1
# minibatch 18/150
# average cost array(0.04800462143096616)
# epoch 1
# minibatch 19/150
# average cost array(0.039930207598362716)
# epoch 1
# minibatch 20/150
# average cost array(0.04136012119751563)
# epoch 1
# minibatch 21/150
# average cost array(0.03205233892930167)
# epoch 1
# minibatch 22/150
# average cost array(0.028801690553368915)
# epoch 1
# minibatch 23/150
# average cost array(0.029974253528073463)
# epoch 1
# minibatch 24/150
# average cost array(0.025474807750557132)
# epoch 1
# minibatch 25/150
# average cost array(0.02435984401015067)
# epoch 1
# minibatch 26/150
# average cost array(0.01355062950986671)
# epoch 1
# minibatch 27/150
# average cost array(0.01779575039951057)
# epoch 1
# minibatch 28/150
# average cost array(0.014568051723473982)
# epoch 1
# minibatch 29/150
# average cost array(0.011508633663061617)
# epoch 1
# minibatch 30/150
# average cost array(0.011614267058868892)
# epoch 1
# minibatch 31/150
# average cost array(0.012822141552997515)
# epoch 1
# minibatch 32/150
# average cost array(0.0113943781707515)
# epoch 1
# minibatch 33/150
# average cost array(0.010278460371791625)
# epoch 1
# minibatch 34/150
# average cost array(0.008138835114904123)
# epoch 1
# minibatch 35/150
# average cost array(0.008201199222917642)
# epoch 1
# minibatch 36/150
# average cost array(0.005381169523585994)
# epoch 1
# minibatch 37/150
# average cost array(0.006839958058540122)
# epoch 1
# minibatch 38/150
# average cost array(0.005324234453178019)
# epoch 1
# minibatch 39/150
# average cost array(0.005459370180070651)
# epoch 1
# minibatch 40/150
# average cost array(0.005547785590542632)
# epoch 1
# minibatch 41/150
# average cost array(0.004059668348063874)
# epoch 1
# minibatch 42/150
# average cost array(0.0041509898118662035)
# epoch 1
# minibatch 43/150
# average cost array(0.003368832348149523)
# epoch 1
# minibatch 44/150
# average cost array(0.003172537797256976)
# epoch 1
# minibatch 45/150
# average cost array(0.0027696426284255808)
# epoch 1
# minibatch 46/150
# average cost array(0.0018992327790879923)
# epoch 1
# minibatch 47/150
# average cost array(0.003027984066597769)
# epoch 1
# minibatch 48/150
# average cost array(0.0022820901522003683)
# epoch 1
# minibatch 49/150
# average cost array(0.004843858968990263)
# epoch 1
# minibatch 50/150
# average cost array(0.0030213929693374527)
# epoch 1
# minibatch 51/150
# average cost array(0.006690187966061201)
# epoch 1
# minibatch 52/150
# average cost array(0.007485770237945846)
# epoch 1
# minibatch 53/150
# average cost array(0.009915920158647541)
# epoch 1
# minibatch 54/150
# average cost array(0.002183711350643737)
# epoch 1
# minibatch 55/150
# average cost array(0.0042366020804182015)
# epoch 1
# minibatch 56/150
# average cost array(0.004271368090015898)
# epoch 1
# minibatch 57/150
# average cost array(0.009323832788147876)
# epoch 1
# minibatch 58/150
# average cost array(0.005693167638638528)
# epoch 1
# minibatch 59/150
# average cost array(0.0016811211349118172)
# epoch 1
# minibatch 60/150
# average cost array(0.0012286795844013325)
# epoch 1
# minibatch 61/150
# average cost array(0.0021451702553576977)
# epoch 1
# minibatch 62/150
# average cost array(0.0022497251360325426)
# epoch 1
# minibatch 63/150
# average cost array(0.0022944224950336937)
# epoch 1
# minibatch 64/150
# average cost array(0.001897560758926609)
# epoch 1
# minibatch 65/150
# average cost array(0.0014374548791567091)
# epoch 1
# minibatch 66/150
# average cost array(0.008945364417259643)
# epoch 1
# minibatch 67/150
# average cost array(0.0023170063279389403)
# epoch 1
# minibatch 68/150
# average cost array(0.0036052250572949822)
# epoch 1
# minibatch 69/150
# average cost array(0.0012188257706912315)
# epoch 1
# minibatch 70/150
# average cost array(0.004813748340096078)
# epoch 1
# minibatch 71/150
# average cost array(0.0050919636304244936)
# epoch 1
# minibatch 72/150
# average cost array(0.0025178351021650108)
# epoch 1
# minibatch 73/150
# average cost array(0.004216982009045634)
# epoch 1
# minibatch 74/150
# average cost array(0.0020384819590379736)
# epoch 1
# minibatch 75/150
# average cost array(0.0014304637427343839)
# epoch 1
# minibatch 76/150
# average cost array(0.21636084096399202)
# epoch 1
# minibatch 77/150
# average cost array(0.17050539448213245)
# epoch 1
# minibatch 78/150
# average cost array(0.0971139823274331)
# epoch 1
# minibatch 79/150
# average cost array(0.13733840805896108)
# epoch 1
# minibatch 80/150
# average cost array(0.07528359432490778)
# epoch 1
# minibatch 81/150
# average cost array(0.13123653290819373)
# epoch 1
# minibatch 82/150
# average cost array(0.08361617287759397)
# epoch 1
# minibatch 83/150
# average cost array(0.08490576602588895)
# epoch 1
# minibatch 84/150
# average cost array(0.052912640385809714)
# epoch 1
# minibatch 85/150
# average cost array(0.09994637605448434)
# epoch 1
# minibatch 86/150
# average cost array(0.05451081342922176)
# epoch 1
# minibatch 87/150
# average cost array(0.09073337197763585)
# epoch 1
# minibatch 88/150
# average cost array(0.07847770979850553)
# epoch 1
# minibatch 89/150
# average cost array(0.07916750644092202)
# epoch 1
# minibatch 90/150
# average cost array(0.05927912323032478)
# epoch 1
# minibatch 91/150
# average cost array(0.05688062354128577)
# epoch 1
# minibatch 92/150
# average cost array(0.06265783002592665)
# epoch 1
# minibatch 93/150
# average cost array(0.06561525794306494)
# epoch 1
# minibatch 94/150
# average cost array(0.07295412655780592)
# epoch 1
# minibatch 95/150
# average cost array(0.05966044263750483)
# epoch 1
# minibatch 96/150
# average cost array(0.06682217465429124)
# epoch 1
# minibatch 97/150
# average cost array(0.033412667575660096)
# epoch 1
# minibatch 98/150
# average cost array(0.06713085688411327)
# epoch 1
# minibatch 99/150
# average cost array(0.045473535012195546)
# epoch 1
# minibatch 100/150
# average cost array(0.050703293865149365)
# epoch 1
# minibatch 101/150
# average cost array(0.08563055174972815)
# epoch 1
# minibatch 102/150
# average cost array(0.05448414542665072)
# epoch 1
# minibatch 103/150
# average cost array(0.055874673209762936)
# epoch 1
# minibatch 104/150
# average cost array(0.046500858820284596)
# epoch 1
# minibatch 105/150
# average cost array(0.03986174117696211)
# epoch 1
# minibatch 106/150
# average cost array(0.047358719496039786)
# epoch 1
# minibatch 107/150
# average cost array(0.06083262513930869)
# epoch 1
# minibatch 108/150
# average cost array(0.056319088566224196)
# epoch 1
# minibatch 109/150
# average cost array(0.05855165861268456)
# epoch 1
# minibatch 110/150
# average cost array(0.07307640656231221)
# epoch 1
# minibatch 111/150
# average cost array(0.03669906261375552)
# epoch 1
# minibatch 112/150
# average cost array(0.05492309887450046)
# epoch 1
# minibatch 113/150
# average cost array(0.04207741809339875)
# epoch 1
# minibatch 114/150
# average cost array(0.04680798330769637)
# epoch 1
# minibatch 115/150
# average cost array(0.06525911345983343)
# epoch 1
# minibatch 116/150
# average cost array(0.04315843627439253)
# epoch 1
# minibatch 117/150
# average cost array(0.04567312349309409)
# epoch 1
# minibatch 118/150
# average cost array(0.05547131340598956)
# epoch 1
# minibatch 119/150
# average cost array(0.058950320392315424)
# epoch 1
# minibatch 120/150
# average cost array(0.054728310936943456)
# epoch 1
# minibatch 121/150
# average cost array(0.04022064597294077)
# epoch 1
# minibatch 122/150
# average cost array(0.06049721198566878)
# epoch 1
# minibatch 123/150
# average cost array(0.05360799611482009)
# epoch 1
# minibatch 124/150
# average cost array(0.05558366331143263)
# epoch 1
# minibatch 125/150
# average cost array(0.04832043062643112)
# epoch 1
# minibatch 126/150
# average cost array(0.052334194113969265)
# epoch 1
# minibatch 127/150
# average cost array(0.04777536272012585)
# epoch 1
# minibatch 128/150
# average cost array(0.04217151376881419)
# epoch 1
# minibatch 129/150
# average cost array(0.04942580017999052)
# epoch 1
# minibatch 130/150
# average cost array(0.04998429899736348)
# epoch 1
# minibatch 131/150
# average cost array(0.059280647193723515)
# epoch 1
# minibatch 132/150
# average cost array(0.04564260328477677)
# epoch 1
# minibatch 133/150
# average cost array(0.048749120239018666)
# epoch 1
# minibatch 134/150
# average cost array(0.05335776774322717)
# epoch 1
# minibatch 135/150
# average cost array(0.05660898175257252)
# epoch 1
# minibatch 136/150
# average cost array(0.05622763340362389)
# epoch 1
# minibatch 137/150
# average cost array(0.04045581940711589)
# epoch 1
# minibatch 138/150
# average cost array(0.055941235984589534)
# epoch 1
# minibatch 139/150
# average cost array(0.03937973577971306)
# epoch 1
# minibatch 140/150
# average cost array(0.04844843121371603)
# epoch 1
# minibatch 141/150
# average cost array(0.04822481740790203)
# epoch 1
# minibatch 142/150
# average cost array(0.03453782659569217)
# epoch 1
# minibatch 143/150
# average cost array(0.046989019278016256)
# epoch 1
# minibatch 144/150
# average cost array(0.04089509163719027)
# epoch 1
# minibatch 145/150
# average cost array(0.054079350772891686)
# epoch 1
# minibatch 146/150
# average cost array(0.03710813434247103)
# epoch 1
# minibatch 147/150
# average cost array(0.053889559016923404)
# epoch 1
# minibatch 148/150
# average cost array(0.04238866119947437)
# epoch 1
# minibatch 149/150
# average cost array(0.04630878067419828)
# epoch 1
# minibatch 150/150
# average cost array(0.043286720684581115)
# epoch 2
# minibatch 1/150
# average cost array(0.054698166252317736)
# epoch 2
# minibatch 2/150
# average cost array(0.04615052196509887)
# epoch 2
# minibatch 3/150
# average cost array(0.033567564357951406)
# epoch 2
# minibatch 4/150
# average cost array(0.038560117663910126)
# epoch 2
# minibatch 5/150
# average cost array(0.031555737833406344)
# epoch 2
# minibatch 6/150
# average cost array(0.028344624320027417)
# epoch 2
# minibatch 7/150
# average cost array(0.025143415905459425)
# epoch 2
# minibatch 8/150
# average cost array(0.019906298682976265)
# epoch 2
# minibatch 9/150
# average cost array(0.01643921202487956)
# epoch 2
# minibatch 10/150
# average cost array(0.015653395124406472)
# epoch 2
# minibatch 11/150
# average cost array(0.011230641465209355)
# epoch 2
# minibatch 12/150
# average cost array(0.010294862002392952)
# epoch 2
# minibatch 13/150
# average cost array(0.011543912566267108)
# epoch 2
# minibatch 14/150
# average cost array(0.008115362924295405)
# epoch 2
# minibatch 15/150
# average cost array(0.007438668532815033)
# epoch 2
# minibatch 16/150
# average cost array(0.007209578236568261)
# epoch 2
# minibatch 17/150
# average cost array(0.0070622357068403)
# epoch 2
# minibatch 18/150
# average cost array(0.006418464514848161)
# epoch 2
# minibatch 19/150
# average cost array(0.006368326071597671)
# epoch 2
# minibatch 20/150
# average cost array(0.00477979619881738)
# epoch 2
# minibatch 21/150
# average cost array(0.0033568930036158113)
# epoch 2
# minibatch 22/150
# average cost array(0.003452717309461617)
# epoch 2
# minibatch 23/150
# average cost array(0.0037076246768754885)
# epoch 2
# minibatch 24/150
# average cost array(0.003479895187820151)
# epoch 2
# minibatch 25/150
# average cost array(0.0030193601411184576)
# epoch 2
# minibatch 26/150
# average cost array(0.0035317218736017853)
# epoch 2
# minibatch 27/150
# average cost array(0.005068932433363137)
# epoch 2
# minibatch 28/150
# average cost array(0.0025268320281803367)
# epoch 2
# minibatch 29/150
# average cost array(0.0019326110383233743)
# epoch 2
# minibatch 30/150
# average cost array(0.001638424429023021)
# epoch 2
# minibatch 31/150
# average cost array(0.0017572304259761118)
# epoch 2
# minibatch 32/150
# average cost array(0.0016142682020184793)
# epoch 2
# minibatch 33/150
# average cost array(0.004013143715380498)
# epoch 2
# minibatch 34/150
# average cost array(0.002762194094477083)
# epoch 2
# minibatch 35/150
# average cost array(0.004557290751398703)
# epoch 2
# minibatch 36/150
# average cost array(0.0016909429168548405)
# epoch 2
# minibatch 37/150
# average cost array(0.002202301191612354)
# epoch 2
# minibatch 38/150
# average cost array(0.0018561736267917756)
# epoch 2
# minibatch 39/150
# average cost array(0.0010573079343820968)
# epoch 2
# minibatch 40/150
# average cost array(0.0026488032309893756)
# epoch 2
# minibatch 41/150
# average cost array(0.0008934043594826616)
# epoch 2
# minibatch 42/150
# average cost array(0.002105296673514741)
# epoch 2
# minibatch 43/150
# average cost array(0.0011151502809585985)
# epoch 2
# minibatch 44/150
# average cost array(0.0009664741266502345)
# epoch 2
# minibatch 45/150
# average cost array(0.0006501686018672468)
# epoch 2
# minibatch 46/150
# average cost array(0.00041429790075508185)
# epoch 2
# minibatch 47/150
# average cost array(0.0018407995230212107)
# epoch 2
# minibatch 48/150
# average cost array(0.0013183077598320663)
# epoch 2
# minibatch 49/150
# average cost array(0.0035850855267699822)
# epoch 2
# minibatch 50/150
# average cost array(0.0018837288247462829)
# epoch 2
# minibatch 51/150
# average cost array(0.005046213057331431)
# epoch 2
# minibatch 52/150
# average cost array(0.005974974108958494)
# epoch 2
# minibatch 53/150
# average cost array(0.007188571873279507)
# epoch 2
# minibatch 54/150
# average cost array(0.0011201733732777073)
# epoch 2
# minibatch 55/150
# average cost array(0.0032861218867834144)
# epoch 2
# minibatch 56/150
# average cost array(0.0031325352656456453)
# epoch 2
# minibatch 57/150
# average cost array(0.006921326982875999)
# epoch 2
# minibatch 58/150
# average cost array(0.004124107283621618)
# epoch 2
# minibatch 59/150
# average cost array(0.000835434108246471)
# epoch 2
# minibatch 60/150
# average cost array(0.0005652528381147315)
# epoch 2
# minibatch 61/150
# average cost array(0.0015349290715657433)
# epoch 2
# minibatch 62/150
# average cost array(0.0014976758586483234)
# epoch 2
# minibatch 63/150
# average cost array(0.0015101229309807593)
# epoch 2
# minibatch 64/150
# average cost array(0.0012814491541020762)
# epoch 2
# minibatch 65/150
# average cost array(0.0009649041775732301)
# epoch 2
# minibatch 66/150
# average cost array(0.006544250106703476)
# epoch 2
# minibatch 67/150
# average cost array(0.0016234666684914485)
# epoch 2
# minibatch 68/150
# average cost array(0.002793816366888176)
# epoch 2
# minibatch 69/150
# average cost array(0.0007295925630806103)
# epoch 2
# minibatch 70/150
# average cost array(0.0035292513211387195)
# epoch 2
# minibatch 71/150
# average cost array(0.0036286560348009742)
# epoch 2
# minibatch 72/150
# average cost array(0.0017597535323556422)
# epoch 2
# minibatch 73/150
# average cost array(0.00332961353168816)
# epoch 2
# minibatch 74/150
# average cost array(0.001389537235502011)
# epoch 2
# minibatch 75/150
# average cost array(0.0009347298655128856)
# epoch 2
# minibatch 76/150
# average cost array(0.11577508911647376)
# epoch 2
# minibatch 77/150
# average cost array(0.08227962901717559)
# epoch 2
# minibatch 78/150
# average cost array(0.06190616779148798)
# epoch 2
# minibatch 79/150
# average cost array(0.05682627265853537)
# epoch 2
# minibatch 80/150
# average cost array(0.052633184964265056)
# epoch 2
# minibatch 81/150
# average cost array(0.08486632305164346)
# epoch 2
# minibatch 82/150
# average cost array(0.058527135060625346)
# epoch 2
# minibatch 83/150
# average cost array(0.04705664229953357)
# epoch 2
# minibatch 84/150
# average cost array(0.03981926560649927)
# epoch 2
# minibatch 85/150
# average cost array(0.06217031584159951)
# epoch 2
# minibatch 86/150
# average cost array(0.035319527101469586)
# epoch 2
# minibatch 87/150
# average cost array(0.06548560153092814)
# epoch 2
# minibatch 88/150
# average cost array(0.05575657731780083)
# epoch 2
# minibatch 89/150
# average cost array(0.048395137982292)
# epoch 2
# minibatch 90/150
# average cost array(0.04178555417785718)
# epoch 2
# minibatch 91/150
# average cost array(0.041957640672708296)
# epoch 2
# minibatch 92/150
# average cost array(0.03976385572997852)
# epoch 2
# minibatch 93/150
# average cost array(0.047292163663076245)
# epoch 2
# minibatch 94/150
# average cost array(0.045824709917798134)
# epoch 2
# minibatch 95/150
# average cost array(0.04396268960439415)
# epoch 2
# minibatch 96/150
# average cost array(0.05004582004812143)
# epoch 2
# minibatch 97/150
# average cost array(0.02078041203397954)
# epoch 2
# minibatch 98/150
# average cost array(0.04603115002054701)
# epoch 2
# minibatch 99/150
# average cost array(0.03204032940687461)
# epoch 2
# minibatch 100/150
# average cost array(0.035486967698282315)
# epoch 2
# minibatch 101/150
# average cost array(0.06198748082150094)
# epoch 2
# minibatch 102/150
# average cost array(0.038829637168386354)
# epoch 2
# minibatch 103/150
# average cost array(0.041135618487712716)
# epoch 2
# minibatch 104/150
# average cost array(0.031016426774372025)
# epoch 2
# minibatch 105/150
# average cost array(0.026438400549961605)
# epoch 2
# minibatch 106/150
# average cost array(0.03429997176798806)
# epoch 2
# minibatch 107/150
# average cost array(0.041226085889739125)
# epoch 2
# minibatch 108/150
# average cost array(0.039326890381952195)
# epoch 2
# minibatch 109/150
# average cost array(0.04243274424370955)
# epoch 2
# minibatch 110/150
# average cost array(0.04812583515885747)
# epoch 2
# minibatch 111/150
# average cost array(0.02663860047080202)
# epoch 2
# minibatch 112/150
# average cost array(0.03835601037528769)
# epoch 2
# minibatch 113/150
# average cost array(0.02863681370263781)
# epoch 2
# minibatch 114/150
# average cost array(0.03386980641149898)
# epoch 2
# minibatch 115/150
# average cost array(0.0454627956354519)
# epoch 2
# minibatch 116/150
# average cost array(0.0326319780258575)
# epoch 2
# minibatch 117/150
# average cost array(0.03232540072132776)
# epoch 2
# minibatch 118/150
# average cost array(0.0337415375158383)
# epoch 2
# minibatch 119/150
# average cost array(0.04015969663586431)
# epoch 2
# minibatch 120/150
# average cost array(0.03908724295575941)
# epoch 2
# minibatch 121/150
# average cost array(0.02789128975254157)
# epoch 2
# minibatch 122/150
# average cost array(0.03611393946723944)
# epoch 2
# minibatch 123/150
# average cost array(0.036170026373730194)
# epoch 2
# minibatch 124/150
# average cost array(0.04018477880967153)
# epoch 2
# minibatch 125/150
# average cost array(0.033066902028929715)
# epoch 2
# minibatch 126/150
# average cost array(0.03679453223263795)
# epoch 2
# minibatch 127/150
# average cost array(0.03239376774370651)
# epoch 2
# minibatch 128/150
# average cost array(0.0277054413706738)
# epoch 2
# minibatch 129/150
# average cost array(0.035391931561761306)
# epoch 2
# minibatch 130/150
# average cost array(0.03461411683332927)
# epoch 2
# minibatch 131/150
# average cost array(0.0447043559028001)
# epoch 2
# minibatch 132/150
# average cost array(0.032591564833662705)
# epoch 2
# minibatch 133/150
# average cost array(0.033425755965391095)
# epoch 2
# minibatch 134/150
# average cost array(0.036812262694435674)
# epoch 2
# minibatch 135/150
# average cost array(0.03874337557323886)
# epoch 2
# minibatch 136/150
# average cost array(0.03923767428564586)
# epoch 2
# minibatch 137/150
# average cost array(0.02774022891902218)
# epoch 2
# minibatch 138/150
# average cost array(0.034187432313455064)
# epoch 2
# minibatch 139/150
# average cost array(0.02328616447662818)
# epoch 2
# minibatch 140/150
# average cost array(0.03134432359554495)
# epoch 2
# minibatch 141/150
# average cost array(0.031476444261111965)
# epoch 2
# minibatch 142/150
# average cost array(0.021696748533318846)
# epoch 2
# minibatch 143/150
# average cost array(0.03119118487093343)
# epoch 2
# minibatch 144/150
# average cost array(0.026664224579835784)
# epoch 2
# minibatch 145/150
# average cost array(0.03656655283193217)
# epoch 2
# minibatch 146/150
# average cost array(0.026026613072521836)
# epoch 2
# minibatch 147/150
# average cost array(0.035513729039842463)
# epoch 2
# minibatch 148/150
# average cost array(0.029243131534954437)
# epoch 2
# minibatch 149/150
# average cost array(0.031965517552339034)
# epoch 2
# minibatch 150/150
# average cost array(0.03003630324580981)
# epoch 3
# minibatch 1/150
# average cost array(0.036327778898985454)
# epoch 3
# minibatch 2/150
# average cost array(0.03009965157351514)
# epoch 3
# minibatch 3/150
# average cost array(0.021564214024756074)
# epoch 3
# minibatch 4/150
# average cost array(0.024431238147894874)
# epoch 3
# minibatch 5/150
# average cost array(0.019670674557709853)
# epoch 3
# minibatch 6/150
# average cost array(0.017374046461345237)
# epoch 3
# minibatch 7/150
# average cost array(0.015173909938882874)
# epoch 3
# minibatch 8/150
# average cost array(0.011746635220161273)
# epoch 3
# minibatch 9/150
# average cost array(0.00994763633522254)
# epoch 3
# minibatch 10/150
# average cost array(0.009064482663692645)
# epoch 3
# minibatch 11/150
# average cost array(0.0064924342267425215)
# epoch 3
# minibatch 12/150
# average cost array(0.005782104092474336)
# epoch 3
# minibatch 13/150
# average cost array(0.006652531184140583)
# epoch 3
# minibatch 14/150
# average cost array(0.004438646549630596)
# epoch 3
# minibatch 15/150
# average cost array(0.0040210069247918956)
# epoch 3
# minibatch 16/150
# average cost array(0.0038768478555898816)
# epoch 3
# minibatch 17/150
# average cost array(0.0037965358737341117)
# epoch 3
# minibatch 18/150
# average cost array(0.0037295627905166856)
# epoch 3
# minibatch 19/150
# average cost array(0.0040284678237913814)
# epoch 3
# minibatch 20/150
# average cost array(0.0025760572687681324)
# epoch 3
# minibatch 21/150
# average cost array(0.0018058899509689468)
# epoch 3
# minibatch 22/150
# average cost array(0.0019424692985374776)
# epoch 3
# minibatch 23/150
# average cost array(0.0019976521420263086)
# epoch 3
# minibatch 24/150
# average cost array(0.0019911168065286262)
# epoch 3
# minibatch 25/150
# average cost array(0.00161291186683997)
# epoch 3
# minibatch 26/150
# average cost array(0.0025524528280417426)
# epoch 3
# minibatch 27/150
# average cost array(0.003490152829085091)
# epoch 3
# minibatch 28/150
# average cost array(0.0015530131674637002)
# epoch 3
# minibatch 29/150
# average cost array(0.0012118478611002803)
# epoch 3
# minibatch 30/150
# average cost array(0.0009454634622995456)
# epoch 3
# minibatch 31/150
# average cost array(0.0009483239836632545)
# epoch 3
# minibatch 32/150
# average cost array(0.0008685764367093708)
# epoch 3
# minibatch 33/150
# average cost array(0.0028522950832943162)
# epoch 3
# minibatch 34/150
# average cost array(0.0019136527356903824)
# epoch 3
# minibatch 35/150
# average cost array(0.0033277954361903934)
# epoch 3
# minibatch 36/150
# average cost array(0.0011523951662173533)
# epoch 3
# minibatch 37/150
# average cost array(0.0014617198249336702)
# epoch 3
# minibatch 38/150
# average cost array(0.0012644945389355057)
# epoch 3
# minibatch 39/150
# average cost array(0.0006118214579907585)
# epoch 3
# minibatch 40/150
# average cost array(0.0018863432836568386)
# epoch 3
# minibatch 41/150
# average cost array(0.0005349843858904739)
# epoch 3
# minibatch 42/150
# average cost array(0.0014758442255060813)
# epoch 3
# minibatch 43/150
# average cost array(0.0007258724924428671)
# epoch 3
# minibatch 44/150
# average cost array(0.00062378521349674)
# epoch 3
# minibatch 45/150
# average cost array(0.0003892890217918838)
# epoch 3
# minibatch 46/150
# average cost array(0.0002489833482660832)
# epoch 3
# minibatch 47/150
# average cost array(0.0013384057075450434)
# epoch 3
# minibatch 48/150
# average cost array(0.000926900232508239)
# epoch 3
# minibatch 49/150
# average cost array(0.002704571055777318)
# epoch 3
# minibatch 50/150
# average cost array(0.0013256274330726724)
# epoch 3
# minibatch 51/150
# average cost array(0.003688153382608989)
# epoch 3
# minibatch 52/150
# average cost array(0.004388103639484919)
# epoch 3
# minibatch 53/150
# average cost array(0.005238449721366374)
# epoch 3
# minibatch 54/150
# average cost array(0.0007605166569511865)
# epoch 3
# minibatch 55/150
# average cost array(0.0024150738139671274)
# epoch 3
# minibatch 56/150
# average cost array(0.0023006741064477503)
# epoch 3
# minibatch 57/150
# average cost array(0.005075845431683436)
# epoch 3
# minibatch 58/150
# average cost array(0.0029761824100081303)
# epoch 3
# minibatch 59/150
# average cost array(0.0005673213357404188)
# epoch 3
# minibatch 60/150
# average cost array(0.0003703069177364628)
# epoch 3
# minibatch 61/150
# average cost array(0.0010862760517151597)
# epoch 3
# minibatch 62/150
# average cost array(0.0010401660942681629)
# epoch 3
# minibatch 63/150
# average cost array(0.0010584109791731558)
# epoch 3
# minibatch 64/150
# average cost array(0.0008874874689138359)
# epoch 3
# minibatch 65/150
# average cost array(0.0006666993793047802)
# epoch 3
# minibatch 66/150
# average cost array(0.0047577423211045316)
# epoch 3
# minibatch 67/150
# average cost array(0.0011324897789443589)
# epoch 3
# minibatch 68/150
# average cost array(0.0020359682991227365)
# epoch 3
# minibatch 69/150
# average cost array(0.0004884564380987414)
# epoch 3
# minibatch 70/150
# average cost array(0.002553919361866911)
# epoch 3
# minibatch 71/150
# average cost array(0.002584469624954075)
# epoch 3
# minibatch 72/150
# average cost array(0.001245852105127081)
# epoch 3
# minibatch 73/150
# average cost array(0.002480467828233795)
# epoch 3
# minibatch 74/150
# average cost array(0.0009604552438076382)
# epoch 3
# minibatch 75/150
# average cost array(0.0006408461131326558)
# epoch 3
# minibatch 76/150
# average cost array(0.07679369824027778)
# epoch 3
# minibatch 77/150
# average cost array(0.05296266581388932)
# epoch 3
# minibatch 78/150
# average cost array(0.04005964727428223)
# epoch 3
# minibatch 79/150
# average cost array(0.02952172639308965)
# epoch 3
# minibatch 80/150
# average cost array(0.037305003325264256)
# epoch 3
# minibatch 81/150
# average cost array(0.056372237128876526)
# epoch 3
# minibatch 82/150
# average cost array(0.04009236755925113)
# epoch 3
# minibatch 83/150
# average cost array(0.02815792182317871)
# epoch 3
# minibatch 84/150
# average cost array(0.02802486275992703)
# epoch 3
# minibatch 85/150
# average cost array(0.0390508911370155)
# epoch 3
# minibatch 86/150
# average cost array(0.022404073775119954)
# epoch 3
# minibatch 87/150
# average cost array(0.044873807143875025)
# epoch 3
# minibatch 88/150
# average cost array(0.03781590390386316)
# epoch 3
# minibatch 89/150
# average cost array(0.02720750042867261)
# epoch 3
# minibatch 90/150
# average cost array(0.028283022757960696)
# epoch 3
# minibatch 91/150
# average cost array(0.02917546818645988)
# epoch 3
# minibatch 92/150
# average cost array(0.024136338886453296)
# epoch 3
# minibatch 93/150
# average cost array(0.032146570813740276)
# epoch 3
# minibatch 94/150
# average cost array(0.026179228044903337)
# epoch 3
# minibatch 95/150
# average cost array(0.030660389957343204)
# epoch 3
# minibatch 96/150
# average cost array(0.035697044821934636)
# epoch 3
# minibatch 97/150
# average cost array(0.012622747752144203)
# epoch 3
# minibatch 98/150
# average cost array(0.029659712552584677)
# epoch 3
# minibatch 99/150
# average cost array(0.02181031183435372)
# epoch 3
# minibatch 100/150
# average cost array(0.023528046218532477)
# epoch 3
# minibatch 101/150
# average cost array(0.041944161445028535)
# epoch 3
# minibatch 102/150
# average cost array(0.026160945831524222)
# epoch 3
# minibatch 103/150
# average cost array(0.029168417191248137)
# epoch 3
# minibatch 104/150
# average cost array(0.019733219502359386)
# epoch 3
# minibatch 105/150
# average cost array(0.017088367862345168)
# epoch 3
# minibatch 106/150
# average cost array(0.023560393063716)
# epoch 3
# minibatch 107/150
# average cost array(0.026511088437019825)
# epoch 3
# minibatch 108/150
# average cost array(0.02643878132301212)
# epoch 3
# minibatch 109/150
# average cost array(0.029606163543692415)
# epoch 3
# minibatch 110/150
# average cost array(0.029654966229672425)
# epoch 3
# minibatch 111/150
# average cost array(0.018753033150132638)
# epoch 3
# minibatch 112/150
# average cost array(0.025635801742203874)
# epoch 3
# minibatch 113/150
# average cost array(0.018848966141471184)
# epoch 3
# minibatch 114/150
# average cost array(0.023440455144308057)
# epoch 3
# minibatch 115/150
# average cost array(0.03058099730653293)
# epoch 3
# minibatch 116/150
# average cost array(0.023591494973252674)
# epoch 3
# minibatch 117/150
# average cost array(0.0222869516689336)
# epoch 3
# minibatch 118/150
# average cost array(0.018725785258941887)
# epoch 3
# minibatch 119/150
# average cost array(0.025490310535184246)
# epoch 3
# minibatch 120/150
# average cost array(0.026626631720112502)
# epoch 3
# minibatch 121/150
# average cost array(0.018908440302987155)
# epoch 3
# minibatch 122/150
# average cost array(0.01970242131290309)
# epoch 3
# minibatch 123/150
# average cost array(0.02307903062611625)
# epoch 3
# minibatch 124/150
# average cost array(0.027877527260065593)
# epoch 3
# minibatch 125/150
# average cost array(0.02166170896517228)
# epoch 3
# minibatch 126/150
# average cost array(0.02443142908065052)
# epoch 3
# minibatch 127/150
# average cost array(0.021260317367273317)
# epoch 3
# minibatch 128/150
# average cost array(0.0173161285592733)
# epoch 3
# minibatch 129/150
# average cost array(0.024651734134846157)
# epoch 3
# minibatch 130/150
# average cost array(0.022908081839561438)
# epoch 3
# minibatch 131/150
# average cost array(0.03243256534595314)
# epoch 3
# minibatch 132/150
# average cost array(0.022411442796218588)
# epoch 3
# minibatch 133/150
# average cost array(0.022070554678998405)
# epoch 3
# minibatch 134/150
# average cost array(0.024186714369251554)
# epoch 3
# minibatch 135/150
# average cost array(0.02520878246870197)
# epoch 3
# minibatch 136/150
# average cost array(0.026261577135861143)
# epoch 3
# minibatch 137/150
# average cost array(0.018616841777762266)
# epoch 3
# minibatch 138/150
# average cost array(0.019871377380163528)
# epoch 3
# minibatch 139/150
# average cost array(0.013264817847299697)
# epoch 3
# minibatch 140/150
# average cost array(0.01978361525655739)
# epoch 3
# minibatch 141/150
# average cost array(0.02023378435684019)
# epoch 3
# minibatch 142/150
# average cost array(0.013080177563290237)
# epoch 3
# minibatch 143/150
# average cost array(0.020197744508897837)
# epoch 3
# minibatch 144/150
# average cost array(0.01668858407614678)
# epoch 3
# minibatch 145/150
# average cost array(0.02362844086797483)
# epoch 3
# minibatch 146/150
# average cost array(0.01820223157858551)
# epoch 3
# minibatch 147/150
# average cost array(0.022203904132750946)
# epoch 3
# minibatch 148/150
# average cost array(0.019344344704406)
# epoch 3
# minibatch 149/150
# average cost array(0.02171853049577535)
# epoch 3
# minibatch 150/150
# average cost array(0.019905723087443847)
# epoch 4
# minibatch 1/150
# average cost array(0.023268881964245005)
# epoch 4
# minibatch 2/150
# average cost array(0.01896417596819683)
# epoch 4
# minibatch 3/150
# average cost array(0.013410192814440785)
# epoch 4
# minibatch 4/150
# average cost array(0.014957604508539366)
# epoch 4
# minibatch 5/150
# average cost array(0.011928242185874805)
# epoch 4
# minibatch 6/150
# average cost array(0.01036739808935094)
# epoch 4
# minibatch 7/150
# average cost array(0.00892687084836657)
# epoch 4
# minibatch 8/150
# average cost array(0.006775485757541788)
# epoch 4
# minibatch 9/150
# average cost array(0.005958265373785814)
# epoch 4
# minibatch 10/150
# average cost array(0.005174992097165783)
# epoch 4
# minibatch 11/150
# average cost array(0.0037580518630058084)
# epoch 4
# minibatch 12/150
# average cost array(0.0032158538413819535)
# epoch 4
# minibatch 13/150
# average cost array(0.0038189586729589836)
# epoch 4
# minibatch 14/150
# average cost array(0.0024011805163113506)
# epoch 4
# minibatch 15/150
# average cost array(0.0021300357550772097)
# epoch 4
# minibatch 16/150
# average cost array(0.002049620473670242)
# epoch 4
# minibatch 17/150
# average cost array(0.002018343223361804)
# epoch 4
# minibatch 18/150
# average cost array(0.002219722061441177)
# epoch 4
# minibatch 19/150
# average cost array(0.0026078064995629056)
# epoch 4
# minibatch 20/150
# average cost array(0.0014228967103987694)
# epoch 4
# minibatch 21/150
# average cost array(0.0010020567613060328)
# epoch 4
# minibatch 22/150
# average cost array(0.0011378495276768712)
# epoch 4
# minibatch 23/150
# average cost array(0.0010889660790077403)
# epoch 4
# minibatch 24/150
# average cost array(0.0011844012742658488)
# epoch 4
# minibatch 25/150
# average cost array(0.0008853816342315449)
# epoch 4
# minibatch 26/150
# average cost array(0.0018139410163771704)
# epoch 4
# minibatch 27/150
# average cost array(0.0024492960344695484)
# epoch 4
# minibatch 28/150
# average cost array(0.0009888980515047757)
# epoch 4
# minibatch 29/150
# average cost array(0.0007536525459765136)
# epoch 4
# minibatch 30/150
# average cost array(0.0005691242985718535)
# epoch 4
# minibatch 31/150
# average cost array(0.0005316944877513088)
# epoch 4
# minibatch 32/150
# average cost array(0.00047994750482099744)
# epoch 4
# minibatch 33/150
# average cost array(0.0020571344197611524)
# epoch 4
# minibatch 34/150
# average cost array(0.0013294434862523663)
# epoch 4
# minibatch 35/150
# average cost array(0.002407460558316275)
# epoch 4
# minibatch 36/150
# average cost array(0.0007808260284638167)
# epoch 4
# minibatch 37/150
# average cost array(0.0009804976953342256)
# epoch 4
# minibatch 38/150
# average cost array(0.0008555960432373467)
# epoch 4
# minibatch 39/150
# average cost array(0.0003640437000979646)
# epoch 4
# minibatch 40/150
# average cost array(0.0013465762829308436)
# epoch 4
# minibatch 41/150
# average cost array(0.00033017273101869913)
# epoch 4
# minibatch 42/150
# average cost array(0.0010237889306730576)
# epoch 4
# minibatch 43/150
# average cost array(0.0004854775337142147)
# epoch 4
# minibatch 44/150
# average cost array(0.0004062125722990847)
# epoch 4
# minibatch 45/150
# average cost array(0.00024056347269424457)
# epoch 4
# minibatch 46/150
# average cost array(0.0001607891069276465)
# epoch 4
# minibatch 47/150
# average cost array(0.0009421601344348886)
# epoch 4
# minibatch 48/150
# average cost array(0.0006220813891622324)
# epoch 4
# minibatch 49/150
# average cost array(0.0019621150246314973)
# epoch 4
# minibatch 50/150
# average cost array(0.0009325769849628796)
# epoch 4
# minibatch 51/150
# average cost array(0.0026930240766889933)
# epoch 4
# minibatch 52/150
# average cost array(0.003149292062687174)
# epoch 4
# minibatch 53/150
# average cost array(0.0038090810887395554)
# epoch 4
# minibatch 54/150
# average cost array(0.0005151982611705916)
# epoch 4
# minibatch 55/150
# average cost array(0.0017274407467832431)
# epoch 4
# minibatch 56/150
# average cost array(0.0016157906776929042)
# epoch 4
# minibatch 57/150
# average cost array(0.0037040119933932176)
# epoch 4
# minibatch 58/150
# average cost array(0.0021380517110370233)
# epoch 4
# minibatch 59/150
# average cost array(0.000391813586425012)
# epoch 4
# minibatch 60/150
# average cost array(0.00024262112660039157)
# epoch 4
# minibatch 61/150
# average cost array(0.0007317688484638421)
# epoch 4
# minibatch 62/150
# average cost array(0.0007215455601258893)
# epoch 4
# minibatch 63/150
# average cost array(0.0007396296532931079)
# epoch 4
# minibatch 64/150
# average cost array(0.0005998866024473571)
# epoch 4
# minibatch 65/150
# average cost array(0.00044059718253473216)
# epoch 4
# minibatch 66/150
# average cost array(0.0034521541279437197)
# epoch 4
# minibatch 67/150
# average cost array(0.0007653664422774922)
# epoch 4
# minibatch 68/150
# average cost array(0.0014237642190169384)
# epoch 4
# minibatch 69/150
# average cost array(0.0003146538661724271)
# epoch 4
# minibatch 70/150
# average cost array(0.001824099259840385)
# epoch 4
# minibatch 71/150
# average cost array(0.0018444106888864148)
# epoch 4
# minibatch 72/150
# average cost array(0.0008732869770992864)
# epoch 4
# minibatch 73/150
# average cost array(0.0017721245256986553)
# epoch 4
# minibatch 74/150
# average cost array(0.000657781075522158)
# epoch 4
# minibatch 75/150
# average cost array(0.0004339109490166434)
# epoch 4
# minibatch 76/150
# average cost array(0.04881369258742414)
# epoch 4
# minibatch 77/150
# average cost array(0.032470721779938)
# epoch 4
# minibatch 78/150
# average cost array(0.025281193998316916)
# epoch 4
# minibatch 79/150
# average cost array(0.01419826979430901)
# epoch 4
# minibatch 80/150
# average cost array(0.025924581244987234)
# epoch 4
# minibatch 81/150
# average cost array(0.03642388779702469)
# epoch 4
# minibatch 82/150
# average cost array(0.026413095054477132)
# epoch 4
# minibatch 83/150
# average cost array(0.016086834250810304)
# epoch 4
# minibatch 84/150
# average cost array(0.01915100386800847)
# epoch 4
# minibatch 85/150
# average cost array(0.02366806710409781)
# epoch 4
# minibatch 86/150
# average cost array(0.01420930225027554)
# epoch 4
# minibatch 87/150
# average cost array(0.029823228270103485)
# epoch 4
# minibatch 88/150
# average cost array(0.024582637864965052)
# epoch 4
# minibatch 89/150
# average cost array(0.014528149701875015)
# epoch 4
# minibatch 90/150
# average cost array(0.018424270240672554)
# epoch 4
# minibatch 91/150
# average cost array(0.019425291810212866)
# epoch 4
# minibatch 92/150
# average cost array(0.014439328083909908)
# epoch 4
# minibatch 93/150
# average cost array(0.021313228527135204)
# epoch 4
# minibatch 94/150
# average cost array(0.01431707207447093)
# epoch 4
# minibatch 95/150
# average cost array(0.02049448991632906)
# epoch 4
# minibatch 96/150
# average cost array(0.024815033292805523)
# epoch 4
# minibatch 97/150
# average cost array(0.007926955423808911)
# epoch 4
# minibatch 98/150
# average cost array(0.018362062148266235)
# epoch 4
# minibatch 99/150
# average cost array(0.014728571050442979)
# epoch 4
# minibatch 100/150
# average cost array(0.014947183849541246)
# epoch 4
# minibatch 101/150
# average cost array(0.026918435848633522)
# epoch 4
# minibatch 102/150
# average cost array(0.01707750746498492)
# epoch 4
# minibatch 103/150
# average cost array(0.020305484022533758)
# epoch 4
# minibatch 104/150
# average cost array(0.012487655078386914)
# epoch 4
# minibatch 105/150
# average cost array(0.011075555104833597)
# epoch 4
# minibatch 106/150
# average cost array(0.015479559289698195)
# epoch 4
# minibatch 107/150
# average cost array(0.016690417524558864)
# epoch 4
# minibatch 108/150
# average cost array(0.017614273299019698)
# epoch 4
# minibatch 109/150
# average cost array(0.020342750493146437)
# epoch 4
# minibatch 110/150
# average cost array(0.017773176819771516)
# epoch 4
# minibatch 111/150
# average cost array(0.01306681235209603)
# epoch 4
# minibatch 112/150
# average cost array(0.016901320588161732)
# epoch 4
# minibatch 113/150
# average cost array(0.012175936110669569)
# epoch 4
# minibatch 114/150
# average cost array(0.01579501929204894)
# epoch 4
# minibatch 115/150
# average cost array(0.020533637545145134)
# epoch 4
# minibatch 116/150
# average cost array(0.01659345141450687)
# epoch 4
# minibatch 117/150
# average cost array(0.015280977748897107)
# epoch 4
# minibatch 118/150
# average cost array(0.009885417701929912)
# epoch 4
# minibatch 119/150
# average cost array(0.015394550741781851)
# epoch 4
# minibatch 120/150
# average cost array(0.017782881968341165)
# epoch 4
# minibatch 121/150
# average cost array(0.013203128566022834)
# epoch 4
# minibatch 122/150
# average cost array(0.010635301005816247)
# epoch 4
# minibatch 123/150
# average cost array(0.014389220435502625)
# epoch 4
# minibatch 124/150
# average cost array(0.018982270257712812)
# epoch 4
# minibatch 125/150
# average cost array(0.0141436097237306)
# epoch 4
# minibatch 126/150
# average cost array(0.015656296996368852)
# epoch 4
# minibatch 127/150
# average cost array(0.014244606953926436)
# epoch 4
# minibatch 128/150
# average cost array(0.010770483273504886)
# epoch 4
# minibatch 129/150
# average cost array(0.01697546827110149)
# epoch 4
# minibatch 130/150
# average cost array(0.014988711028405332)
# epoch 4
# minibatch 131/150
# average cost array(0.023109319272146617)
# epoch 4
# minibatch 132/150
# average cost array(0.015147246521321564)
# epoch 4
# minibatch 133/150
# average cost array(0.014438261331618638)
# epoch 4
# minibatch 134/150
# average cost array(0.015669834274043958)
# epoch 4
# minibatch 135/150
# average cost array(0.016060751575110103)
# epoch 4
# minibatch 136/150
# average cost array(0.01727646307334455)
# epoch 4
# minibatch 137/150
# average cost array(0.012768569287710873)
# epoch 4
# minibatch 138/150
# average cost array(0.012287906632000018)
# epoch 4
# minibatch 139/150
# average cost array(0.008345929636987022)
# epoch 4
# minibatch 140/150
# average cost array(0.012796874124951637)
# epoch 4
# minibatch 141/150
# average cost array(0.01362812301070824)
# epoch 4
# minibatch 142/150
# average cost array(0.008006259092402272)
# epoch 4
# minibatch 143/150
# average cost array(0.01307850281533261)
# epoch 4
# minibatch 144/150
# average cost array(0.010544550886578616)
# epoch 4
# minibatch 145/150
# average cost array(0.015090024975865516)
# epoch 4
# minibatch 146/150
# average cost array(0.013044149673926636)
# epoch 4
# minibatch 147/150
# average cost array(0.013767730174162187)
# epoch 4
# minibatch 148/150
# average cost array(0.01275729537007699)
# epoch 4
# minibatch 149/150
# average cost array(0.014960310707439996)
# epoch 4
# minibatch 150/150
# average cost array(0.013032135993512415)
# epoch 5
# minibatch 1/150
# average cost array(0.014783915129162956)
# epoch 5
# minibatch 2/150
# average cost array(0.011894778390144984)
# epoch 5
# minibatch 3/150
# average cost array(0.008332599989657833)
# epoch 5
# minibatch 4/150
# average cost array(0.009129104525556913)
# epoch 5
# minibatch 5/150
# average cost array(0.007278672783113757)
# epoch 5
# minibatch 6/150
# average cost array(0.006229209446184367)
# epoch 5
# minibatch 7/150
# average cost array(0.0052997186065117195)
# epoch 5
# minibatch 8/150
# average cost array(0.003966407521300723)
# epoch 5
# minibatch 9/150
# average cost array(0.003652942702151609)
# epoch 5
# minibatch 10/150
# average cost array(0.0030277969305209764)
# epoch 5
# minibatch 11/150
# average cost array(0.0022670463199842886)
# epoch 5
# minibatch 12/150
# average cost array(0.0018447568815856373)
# epoch 5
# minibatch 13/150
# average cost array(0.0022605589656692314)
# epoch 5
# minibatch 14/150
# average cost array(0.0013372786475120027)
# epoch 5
# minibatch 15/150
# average cost array(0.0011478310237698051)
# epoch 5
# minibatch 16/150
# average cost array(0.001105405815632498)
# epoch 5
# minibatch 17/150
# average cost array(0.0011014936755433234)
# epoch 5
# minibatch 18/150
# average cost array(0.0013852606015038742)
# epoch 5
# minibatch 19/150
# average cost array(0.001742237723730157)
# epoch 5
# minibatch 20/150
# average cost array(0.0008371424745524655)
# epoch 5
# minibatch 21/150
# average cost array(0.0005933345411067326)
# epoch 5
# minibatch 22/150
# average cost array(0.0007103122362230159)
# epoch 5
# minibatch 23/150
# average cost array(0.000617589712603353)
# epoch 5
# minibatch 24/150
# average cost array(0.0007490908124570623)
# epoch 5
# minibatch 25/150
# average cost array(0.0005158313886758162)
# epoch 5
# minibatch 26/150
# average cost array(0.0012695690909958872)
# epoch 5
# minibatch 27/150
# average cost array(0.0017570224058726359)
# epoch 5
# minibatch 28/150
# average cost array(0.0006572299681629032)
# epoch 5
# minibatch 29/150
# average cost array(0.00046460737893395867)
# epoch 5
# minibatch 30/150
# average cost array(0.00036244501537940085)
# epoch 5
# minibatch 31/150
# average cost array(0.00031969621194526045)
# epoch 5
# minibatch 32/150
# average cost array(0.00027991441360831316)
# epoch 5
# minibatch 33/150
# average cost array(0.0015110842637269806)
# epoch 5
# minibatch 34/150
# average cost array(0.000933287866661666)
# epoch 5
# minibatch 35/150
# average cost array(0.0017418317439046372)
# epoch 5
# minibatch 36/150
# average cost array(0.0005294977468909797)
# epoch 5
# minibatch 37/150
# average cost array(0.0006692652532536926)
# epoch 5
# minibatch 38/150
# average cost array(0.0005810379059334388)
# epoch 5
# minibatch 39/150
# average cost array(0.00022703118519657107)
# epoch 5
# minibatch 40/150
# average cost array(0.0009715310711215633)
# epoch 5
# minibatch 41/150
# average cost array(0.00021410075664306653)
# epoch 5
# minibatch 42/150
# average cost array(0.000711519898914547)
# epoch 5
# minibatch 43/150
# average cost array(0.00033573850944621994)
# epoch 5
# minibatch 44/150
# average cost array(0.0002697082570900061)
# epoch 5
# minibatch 45/150
# average cost array(0.00015858986482321347)
# epoch 5
# minibatch 46/150
# average cost array(0.00011600945210929509)
# epoch 5
# minibatch 47/150
# average cost array(0.000653609800216007)
# epoch 5
# minibatch 48/150
# average cost array(0.0004056815280971287)
# epoch 5
# minibatch 49/150
# average cost array(0.0013992773137129146)
# epoch 5
# minibatch 50/150
# average cost array(0.0006646817075882633)
# epoch 5
# minibatch 51/150
# average cost array(0.001983896684645525)
# epoch 5
# minibatch 52/150
# average cost array(0.0022476126481228028)
# epoch 5
# minibatch 53/150
# average cost array(0.0027902711606910486)
# epoch 5
# minibatch 54/150
# average cost array(0.0003534590153200571)
# epoch 5
# minibatch 55/150
# average cost array(0.0012222999732894612)
# epoch 5
# minibatch 56/150
# average cost array(0.0011050524760821089)
# epoch 5
# minibatch 57/150
# average cost array(0.002722907835196122)
# epoch 5
# minibatch 58/150
# average cost array(0.0015469804056332565)
# epoch 5
# minibatch 59/150
# average cost array(0.00027871347804282954)
# epoch 5
# minibatch 60/150
# average cost array(0.00016267821608327893)
# epoch 5
# minibatch 61/150
# average cost array(0.0004789275299272409)
# epoch 5
# minibatch 62/150
# average cost array(0.0005073267765253412)
# epoch 5
# minibatch 63/150
# average cost array(0.0005240006028808393)
# epoch 5
# minibatch 64/150
# average cost array(0.0004032015319646148)
# epoch 5
# minibatch 65/150
# average cost array(0.00028736408409035764)
# epoch 5
# minibatch 66/150
# average cost array(0.0025241126286482123)
# epoch 5
# minibatch 67/150
# average cost array(0.000509444049874271)
# epoch 5
# minibatch 68/150
# average cost array(0.0009738442751986353)
# epoch 5
# minibatch 69/150
# average cost array(0.00019926571205160204)
# epoch 5
# minibatch 70/150
# average cost array(0.0013092424640288528)
# epoch 5
# minibatch 71/150
# average cost array(0.0013293433070233323)
# epoch 5
# minibatch 72/150
# average cost array(0.0006165280284626237)
# epoch 5
# minibatch 73/150
# average cost array(0.0012411814665854862)
# epoch 5
# minibatch 74/150
# average cost array(0.0004531212104820754)
# epoch 5
# minibatch 75/150
# average cost array(0.0002947246663004168)
# epoch 5
# minibatch 76/150
# average cost array(0.030459949852349677)
# epoch 5
# minibatch 77/150
# average cost array(0.019335003480986344)
# epoch 5
# minibatch 78/150
# average cost array(0.016063005118212677)
# epoch 5
# minibatch 79/150
# average cost array(0.007154041622000923)
# epoch 5
# minibatch 80/150
# average cost array(0.017941951073137737)
# epoch 5
# minibatch 81/150
# average cost array(0.02363145074857152)
# epoch 5
# minibatch 82/150
# average cost array(0.017226580901860987)
# epoch 5
# minibatch 83/150
# average cost array(0.009372737481801894)
# epoch 5
# minibatch 84/150
# average cost array(0.013014723137857282)
# epoch 5
# minibatch 85/150
# average cost array(0.01446379469303014)
# epoch 5
# minibatch 86/150
# average cost array(0.00952591290449004)
# epoch 5
# minibatch 87/150
# average cost array(0.019730176478510948)
# epoch 5
# minibatch 88/150
# average cost array(0.015770800896705843)
# epoch 5
# minibatch 89/150
# average cost array(0.008111412765771576)
# epoch 5
# minibatch 90/150
# average cost array(0.01184916594283462)
# epoch 5
# minibatch 91/150
# average cost array(0.012769314453334424)
# epoch 5
# minibatch 92/150
# average cost array(0.009058431544527437)
# epoch 5
# minibatch 93/150
# average cost array(0.01409108030688673)
# epoch 5
# minibatch 94/150
# average cost array(0.0081940497311454)
# epoch 5
# minibatch 95/150
# average cost array(0.013399516033425336)
# epoch 5
# minibatch 96/150
# average cost array(0.017232077283354727)
# epoch 5
# minibatch 97/150
# average cost array(0.005424902067103506)
# epoch 5
# minibatch 98/150
# average cost array(0.011351973272179742)
# epoch 5
# minibatch 99/150
# average cost array(0.010261477945201962)
# epoch 5
# minibatch 100/150
# average cost array(0.00924563182315047)
# epoch 5
# minibatch 101/150
# average cost array(0.01671184534236757)
# epoch 5
# minibatch 102/150
# average cost array(0.011096510441767574)
# epoch 5
# minibatch 103/150
# average cost array(0.014310725591591023)
# epoch 5
# minibatch 104/150
# average cost array(0.008234721830856898)
# epoch 5
# minibatch 105/150
# average cost array(0.007388933692426597)
# epoch 5
# minibatch 106/150
# average cost array(0.009945170420373392)
# epoch 5
# minibatch 107/150
# average cost array(0.010555628647380242)
# epoch 5
# minibatch 108/150
# average cost array(0.011836046254476802)
# epoch 5
# minibatch 109/150
# average cost array(0.014118742094383605)
# epoch 5
# minibatch 110/150
# average cost array(0.010878140917462259)
# epoch 5
# minibatch 111/150
# ...
# epoch 9
# minibatch 68/150
# average cost array(0.00022306184805165455)
# epoch 9
# minibatch 69/150
# average cost array(4.101214704099774e-05)
# epoch 9
# minibatch 70/150
# average cost array(0.0003951399337292009)
# epoch 9
# minibatch 71/150
# average cost array(0.00034402531182678605)
# epoch 9
# minibatch 72/150
# average cost array(0.0001718057215731309)
# epoch 9
# minibatch 73/150
# average cost array(0.00034530462626638597)
# epoch 9
# minibatch 74/150
# average cost array(0.00010664721230135518)
# epoch 9
# minibatch 75/150
# average cost array(6.653203067433087e-05)
# epoch 9
# minibatch 76/150
# average cost array(0.0049370501199525576)
# epoch 9
# minibatch 77/150
# average cost array(0.002751363614187927)
# epoch 9
# minibatch 78/150
# average cost array(0.0038343426885923426)
# epoch 9
# minibatch 79/150
# average cost array(0.001105602873507104)
# epoch 9
# minibatch 80/150
# average cost array(0.0039626901598681505)
# epoch 9
# minibatch 81/150
# average cost array(0.005305162864623967)
# epoch 9
# minibatch 82/150
# average cost array(0.003838879113236206)
# epoch 9
# minibatch 83/150
# average cost array(0.0020794743985429725)
# epoch 9
# minibatch 84/150
# average cost array(0.003372374532782583)
# epoch 9
# minibatch 85/150
# average cost array(0.0027679521713005863)
# epoch 9
# minibatch 86/150
# average cost array(0.0022963413776500726)
# epoch 9
# minibatch 87/150
# average cost array(0.004206289961432746)
# epoch 9
# minibatch 88/150
# average cost array(0.003703609905933021)
# epoch 9
# minibatch 89/150
# average cost array(0.0013154385202174307)
# epoch 9
# minibatch 90/150
# average cost array(0.0026126933789441505)
# epoch 9
# minibatch 91/150
# average cost array(0.0029219788085278323)
# epoch 9
# minibatch 92/150
# average cost array(0.0019265362325588682)
# epoch 9
# minibatch 93/150
# average cost array(0.003235164186577086)
# epoch 9
# minibatch 94/150
# average cost array(0.001466574691579075)
# epoch 9
# minibatch 95/150
# average cost array(0.002937652072682575)
# epoch 9
# minibatch 96/150
# average cost array(0.004716038178909394)
# epoch 9
# minibatch 97/150
# average cost array(0.001690621465483016)
# epoch 9
# minibatch 98/150
# average cost array(0.0021324612021439353)
# epoch 9
# minibatch 99/150
# average cost array(0.0029364592678174533)
# epoch 9
# minibatch 100/150
# average cost array(0.0014131829998267893)
# epoch 9
# minibatch 101/150
# average cost array(0.0028301063946577676)
# epoch 9
# minibatch 102/150
# average cost array(0.0026926274496256565)
# epoch 9
# minibatch 103/150
# average cost array(0.004249948194853986)
# epoch 9
# minibatch 104/150
# average cost array(0.0021517061322209995)
# epoch 9
# minibatch 105/150
# average cost array(0.0019292163346789602)
# epoch 9
# minibatch 106/150
# average cost array(0.0018681297955535393)
# epoch 9
# minibatch 107/150
# average cost array(0.0020183012780304846)
# epoch 9
# minibatch 108/150
# average cost array(0.0026112752416272704)
# epoch 9
# minibatch 109/150
# average cost array(0.003826643378410643)
# epoch 9
# minibatch 110/150
# average cost array(0.0018633813276635364)
# epoch 9
# minibatch 111/150
# average cost array(0.0029151432128235307)
# epoch 9
# minibatch 112/150
# average cost array(0.003146742505825692)
# epoch 9
# minibatch 113/150
# average cost array(0.0017693600826849596)
# epoch 9
# minibatch 114/150
# average cost array(0.0025047505014240334)
# epoch 9
# minibatch 115/150
# average cost array(0.003482471841982201)
# epoch 9
# minibatch 116/150
# average cost array(0.003350101508938385)
# epoch 9
# minibatch 117/150
# average cost array(0.0032691615921640474)
# epoch 9
# minibatch 118/150
# average cost array(0.0010443820239766323)
# epoch 9
# minibatch 119/150
# average cost array(0.001473326614046193)
# epoch 9
# minibatch 120/150
# average cost array(0.0031624427460881727)
# epoch 9
# minibatch 121/150
# average cost array(0.002929184691874451)
# epoch 9
# minibatch 122/150
# average cost array(0.0013579603795820323)
# epoch 9
# minibatch 123/150
# average cost array(0.0018365943080237833)
# epoch 9
# minibatch 124/150
# average cost array(0.00293075995053886)
# epoch 9
# minibatch 125/150
# average cost array(0.002461702127358761)
# epoch 9
# minibatch 126/150
# average cost array(0.002448808348951796)
# epoch 9
# minibatch 127/150
# average cost array(0.0028268885223484298)
# epoch 9
# minibatch 128/150
# average cost array(0.001309766859110806)
# epoch 9
# minibatch 129/150
# average cost array(0.002863435972286459)
# epoch 9
# minibatch 130/150
# average cost array(0.002604128784712248)
# epoch 9
# minibatch 131/150
# average cost array(0.0043576531070031385)
# epoch 9
# minibatch 132/150
# average cost array(0.0026393348316046017)
# epoch 9
# minibatch 133/150
# average cost array(0.002019988491602162)
# epoch 9
# minibatch 134/150
# average cost array(0.0025436808476498518)
# epoch 9
# minibatch 135/150
# average cost array(0.00210595786518093)
# epoch 9
# minibatch 136/150
# average cost array(0.0024674676107443857)
# epoch 9
# minibatch 137/150
# average cost array(0.0025245525054808427)
# epoch 9
# minibatch 138/150
# average cost array(0.002307006440041734)
# epoch 9
# minibatch 139/150
# average cost array(0.0020199964613710456)
# epoch 9
# minibatch 140/150
# average cost array(0.0018845535925209535)
# epoch 9
# minibatch 141/150
# average cost array(0.002354764304344806)
# epoch 9
# minibatch 142/150
# average cost array(0.0013625347860346576)
# epoch 9
# minibatch 143/150
# average cost array(0.002321924954464596)
# epoch 9
# minibatch 144/150
# average cost array(0.0016333755882486814)
# epoch 9
# minibatch 145/150
# average cost array(0.0021362669521117006)
# epoch 9
# minibatch 146/150
# average cost array(0.002787865600208531)
# epoch 9
# minibatch 147/150
# average cost array(0.0018597060136346256)
# epoch 9
# minibatch 148/150
# average cost array(0.002490819446302886)
# epoch 9
# minibatch 149/150
# average cost array(0.0024773412331016223)
# epoch 9
# minibatch 150/150
# average cost array(0.002772326777767789)
# epoch 10
# minibatch 1/150
# average cost array(0.002010969351124093)
# epoch 10
# minibatch 2/150
# average cost array(0.0016217437359737658)
# epoch 10
# minibatch 3/150
# average cost array(0.0011056537725786235)
# epoch 10
# minibatch 4/150
# average cost array(0.001079938816169991)
# epoch 10
# minibatch 5/150
# average cost array(0.000980414004122397)
# epoch 10
# minibatch 6/150
# average cost array(0.0007678212191258836)
# epoch 10
# minibatch 7/150
# average cost array(0.0006369719275860725)
# epoch 10
# minibatch 8/150
# average cost array(0.0005028817750358271)
# epoch 10
# minibatch 9/150
# average cost array(0.0005998286664360109)
# epoch 10
# minibatch 10/150
# average cost array(0.0003963597985018879)
# epoch 10
# minibatch 11/150
# average cost array(0.00033833335270383897)
# epoch 10
# minibatch 12/150
# average cost array(0.00023311259733683814)
# epoch 10
# minibatch 13/150
# average cost array(0.0002708362049499872)
# epoch 10
# minibatch 14/150
# average cost array(0.00016128073009311354)
# epoch 10
# minibatch 15/150
# average cost array(8.288614961913824e-05)
# epoch 10
# minibatch 16/150
# average cost array(0.00010334432841330369)
# epoch 10
# minibatch 17/150
# average cost array(0.0001021485350234918)
# epoch 10
# minibatch 18/150
# average cost array(0.00022821334389704903)
# epoch 10
# minibatch 19/150
# average cost array(0.00031383243529249774)
# epoch 10
# minibatch 20/150
# average cost array(0.00015753115367802078)
# epoch 10
# minibatch 21/150
# average cost array(0.00010820486101478742)
# epoch 10
# minibatch 22/150
# average cost array(0.000124733911073831)
# epoch 10
# minibatch 23/150
# average cost array(6.766454977486116e-05)
# epoch 10
# minibatch 24/150
# average cost array(0.00012665185598626522)
# epoch 10
# minibatch 25/150
# average cost array(7.468123224838692e-05)
# epoch 10
# minibatch 26/150
# average cost array(0.00022333144487484465)
# epoch 10
# minibatch 27/150
# average cost array(0.00037406074840528805)
# epoch 10
# minibatch 28/150
# average cost array(0.00010745547722006321)
# epoch 10
# minibatch 29/150
# average cost array(5.401980879040049e-05)
# epoch 10
# minibatch 30/150
# average cost array(6.456650739790289e-05)
# epoch 10
# minibatch 31/150
# average cost array(7.064738226512879e-05)
# epoch 10
# minibatch 32/150
# average cost array(5.401920249018174e-05)
# epoch 10
# minibatch 33/150
# average cost array(0.00034745807773935416)
# epoch 10
# minibatch 34/150
# average cost array(0.00020027501446522733)
# epoch 10
# minibatch 35/150
# average cost array(0.0003459832772147928)
# epoch 10
# minibatch 36/150
# average cost array(7.578824767466044e-05)
# epoch 10
# minibatch 37/150
# average cost array(0.00011306790469425897)
# epoch 10
# minibatch 38/150
# average cost array(0.00010626265647657352)
# epoch 10
# minibatch 39/150
# average cost array(4.984730218932644e-05)
# epoch 10
# minibatch 40/150
# average cost array(0.00020670105773891047)
# epoch 10
# minibatch 41/150
# average cost array(5.546950392216421e-05)
# epoch 10
# minibatch 42/150
# average cost array(0.000133968176352899)
# epoch 10
# minibatch 43/150
# average cost array(6.60423150152292e-05)
# epoch 10
# minibatch 44/150
# average cost array(5.3189170051325636e-05)
# epoch 10
# minibatch 45/150
# average cost array(6.6829057147966e-05)
# epoch 10
# minibatch 46/150
# average cost array(6.535778468259371e-05)
# epoch 10
# minibatch 47/150
# average cost array(0.00013134935424935235)
# epoch 10
# minibatch 48/150
# average cost array(5.336025494607976e-05)
# epoch 10
# minibatch 49/150
# average cost array(0.000347281057590258)
# epoch 10
# minibatch 50/150
# average cost array(0.00014164362712387038)
# epoch 10
# minibatch 51/150
# average cost array(0.0004332300082656107)
# epoch 10
# minibatch 52/150
# average cost array(0.0004590053409818779)
# epoch 10
# minibatch 53/150
# average cost array(0.0005966389004426828)
# epoch 10
# minibatch 54/150
# average cost array(7.077204142489554e-05)
# epoch 10
# minibatch 55/150
# average cost array(0.00023498050513151022)
# epoch 10
# minibatch 56/150
# average cost array(0.00018074237549516267)
# epoch 10
# minibatch 57/150
# average cost array(0.0006377603308327178)
# epoch 10
# minibatch 58/150
# average cost array(0.0003210798642326397)
# epoch 10
# minibatch 59/150
# average cost array(7.177183366643545e-05)
# epoch 10
# minibatch 60/150
# average cost array(4.260398166325234e-05)
# epoch 10
# minibatch 61/150
# average cost array(6.526612488894515e-05)
# epoch 10
# minibatch 62/150
# average cost array(0.00010253524427175277)
# epoch 10
# minibatch 63/150
# average cost array(0.00011980647512983876)
# epoch 10
# minibatch 64/150
# average cost array(6.587124824616091e-05)
# epoch 10
# minibatch 65/150
# average cost array(6.844432915423658e-05)
# epoch 10
# minibatch 66/150
# average cost array(0.0005366133817713149)
# epoch 10
# minibatch 67/150
# average cost array(6.534371770885018e-05)
# epoch 10
# minibatch 68/150
# average cost array(0.00016077437326166228)
# epoch 10
# minibatch 69/150
# average cost array(3.3161886028146586e-05)
# epoch 10
# minibatch 70/150
# average cost array(0.000306896808662236)
# epoch 10
# minibatch 71/150
# average cost array(0.00024199555308225388)
# epoch 10
# minibatch 72/150
# average cost array(0.00013111675163332478)
# epoch 10
# minibatch 73/150
# average cost array(0.0002675732692805439)
# epoch 10
# minibatch 74/150
# average cost array(7.748394492372998e-05)
# epoch 10
# minibatch 75/150
# average cost array(4.830526534269915e-05)
# epoch 10
# minibatch 76/150
# average cost array(0.0032417477849111614)
# epoch 10
# minibatch 77/150
# average cost array(0.0018750843926386227)
# epoch 10
# minibatch 78/150
# average cost array(0.002807753195938314)
# epoch 10
# minibatch 79/150
# average cost array(0.0007850983131041215)
# epoch 10
# minibatch 80/150
# average cost array(0.0027605917354728174)
# epoch 10
# minibatch 81/150
# average cost array(0.003865967603316899)
# epoch 10
# minibatch 82/150
# average cost array(0.002755712326851894)
# epoch 10
# minibatch 83/150
# average cost array(0.001567208677546621)
# epoch 10
# minibatch 84/150
# average cost array(0.0025637486057528604)
# epoch 10
# minibatch 85/150
# average cost array(0.0019097014620214178)
# epoch 10
# minibatch 86/150
# average cost array(0.0016943515237243377)
# epoch 10
# minibatch 87/150
# average cost array(0.0030597620913665725)
# epoch 10
# minibatch 88/150
# average cost array(0.0027905585165076785)
# epoch 10
# minibatch 89/150
# average cost array(0.0009823477268297363)
# epoch 10
# minibatch 90/150
# average cost array(0.0019248681666284007)
# epoch 10
# minibatch 91/150
# average cost array(0.002109474421819007)
# epoch 10
# minibatch 92/150
# average cost array(0.0013991888534201715)
# epoch 10
# minibatch 93/150
# average cost array(0.002366093892324686)
# epoch 10
# minibatch 94/150
# average cost array(0.0009927998949065728)
# epoch 10
# minibatch 95/150
# average cost array(0.0021747131558609847)
# epoch 10
# minibatch 96/150
# average cost array(0.003509424355073911)
# epoch 10
# minibatch 97/150
# average cost array(0.0013228726906508378)
# epoch 10
# minibatch 98/150
# average cost array(0.0015050927247841571)
# epoch 10
# minibatch 99/150
# average cost array(0.0022824584456793444)
# epoch 10
# minibatch 100/150
# average cost array(0.0010040924428352254)
# epoch 10
# minibatch 101/150
# average cost array(0.0018973793546044164)
# epoch 10
# minibatch 102/150
# average cost array(0.002058190959847752)
# epoch 10
# minibatch 103/150
# average cost array(0.0033257539113677828)
# epoch 10
# minibatch 104/150
# average cost array(0.0016516091282657603)
# epoch 10
# minibatch 105/150
# average cost array(0.0014649566001235742)
# epoch 10
# minibatch 106/150
# average cost array(0.001338012123582758)
# epoch 10
# minibatch 107/150
# average cost array(0.0014276588862195167)
# epoch 10
# minibatch 108/150
# average cost array(0.001869787368782013)
# epoch 10
# minibatch 109/150
# average cost array(0.0028518431464000732)
# epoch 10
# minibatch 110/150
# average cost array(0.0013631275630432236)
# epoch 10
# minibatch 111/150
# average cost array(0.0023263079702896634)
# epoch 10
# minibatch 112/150
# average cost array(0.002459894792135402)
# epoch 10
# minibatch 113/150
# average cost array(0.0012465959580202476)
# epoch 10
# minibatch 114/150
# average cost array(0.0018294462473077769)
# epoch 10
# minibatch 115/150
# average cost array(0.002565658570828735)
# epoch 10
# minibatch 116/150
# average cost array(0.0025220888342331934)
# epoch 10
# minibatch 117/150
# average cost array(0.0025229279768241406)
# epoch 10
# minibatch 118/150
# average cost array(0.0007730888735102868)
# epoch 10
# minibatch 119/150
# average cost array(0.0010273973482971335)
# epoch 10
# minibatch 120/150
# average cost array(0.002405597403981244)
# epoch 10
# minibatch 121/150
# average cost array(0.0022465867115109804)
# epoch 10
# minibatch 122/150
# average cost array(0.0010246380520082157)
# epoch 10
# minibatch 123/150
# average cost array(0.0013407430267223116)
# epoch 10
# minibatch 124/150
# average cost array(0.0021314353259320163)
# epoch 10
# minibatch 125/150
# average cost array(0.0018431806053482336)
# epoch 10
# minibatch 126/150
# average cost array(0.0018729513089148046)
# epoch 10
# minibatch 127/150
# average cost array(0.0021224790451073545)
# epoch 10
# minibatch 128/150
# average cost array(0.000897524450306089)
# epoch 10
# minibatch 129/150
# average cost array(0.002019895739417376)
# epoch 10
# minibatch 130/150
# average cost array(0.0019312170822726852)
# epoch 10
# minibatch 131/150
# average cost array(0.0032474256802130794)
# epoch 10
# minibatch 132/150
# average cost array(0.0020249782125730436)
# epoch 10
# minibatch 133/150
# average cost array(0.001423476362177913)
# epoch 10
# minibatch 134/150
# average cost array(0.0019481146993271935)
# epoch 10
# minibatch 135/150
# average cost array(0.0015335045161484616)
# epoch 10
# minibatch 136/150
# average cost array(0.0017373498632025006)
# epoch 10
# minibatch 137/150
# average cost array(0.0019204455761682767)
# epoch 10
# minibatch 138/150
# average cost array(0.001770756416848514)
# epoch 10
# minibatch 139/150
# average cost array(0.0016238430617020125)
# epoch 10
# minibatch 140/150
# average cost array(0.0013049471403074418)
# epoch 10
# minibatch 141/150
# average cost array(0.0017031328856973948)
# epoch 10
# minibatch 142/150
# average cost array(0.0010585535492183427)
# epoch 10
# minibatch 143/150
# average cost array(0.0017700427170759133)
# epoch 10
# minibatch 144/150
# average cost array(0.0011627651627310641)
# epoch 10
# minibatch 145/150
# average cost array(0.0015220772615170137)
# epoch 10
# minibatch 146/150
# average cost array(0.002106009479163502)
# epoch 10
# minibatch 147/150
# average cost array(0.001364160605094622)
# epoch 10
# minibatch 148/150
# average cost array(0.001901079095476407)
# epoch 10
# minibatch 149/150
# average cost array(0.0018762782160957729)
# epoch 10
# minibatch 150/150
# average cost array(0.002155665118153205)
# testing
# [ 0.45905067  0.69452524  0.62945212 ...,  0.31882685  0.          0.68484084]
# [ 0.46702737  0.72629702  0.65461749 ...,  0.25288594  0.0035322
#   0.72507387]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1)
ax.plot(analytic, model, 'bo', lw=5, alpha=0.6, label='g = 1')
