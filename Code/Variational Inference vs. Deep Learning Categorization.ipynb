# %%
import numpy as np

nneuron = 41

sprefs = np.linspace(-60, 60, nneuron)

sig0_sq      = float(3**2)
sig1_sq      = float(12**2)
sigtc_sq     = float(10**2)
ndatapergain = 3000
mu = 0

tau_0 = 1/sig0_sq
tau_1 = 1/sig1_sq
d_tau = tau_0 - tau_1
sig_tc = 10
min_angle = -60
max_angle = 60
step = 3
prefact = np.sqrt(tau_0/tau_1)

def generate_popcode_data(ndatapergain, nneuron, sig0_sq, sig1_sq, sigtc_sq, gain, noise):
    s_s0 = np.random.normal(mu, np.sqrt(sig0_sq), ndatapergain/2)
    s_s1 = np.random.normal(mu, np.sqrt(sig1_sq), ndatapergain/2)
    s = np.concatenate((s_s0, s_s1), axis=1)
    sprefs_data = np.tile(sprefs, (ndatapergain, 1))
    r = gain * np.exp(-np.square((np.transpose(np.tile(s, (nneuron, 1))) - sprefs_data))/(2 * sigtc_sq))
    if noise == "poisson":
        r = np.random.poisson(r) + 0.0
    ar = np.sum(r, axis=1)/sigtc_sq
    br = np.sum(r*sprefs_data, axis=1)/sigtc_sq
    
    term_1 = (1 + sig1_sq * ar) / (1 + sig0_sq  * ar)
    term_2_num = (sig1_sq - sig0_sq) * br**2
    term_2_denom = 2 * (1 + sig0_sq  * ar) * (1 + sig1_sq * ar)
    xpnt_a = .5 * np.log(term_1) - term_2_num/term_2_denom
    p = 1/(1 + np.exp(-xpnt_a))
    return r, p, ar, br

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

def run_variational_inference(ar, br):
    #variational inference
    p = np.random.random_sample()
    tau = np.random.random_sample() * .5
    eta = br
    
    prev_tau = 0
    prev_p = 0
    conv = 0
    while prev_tau != tau and prev_p != p:
    #while round(prev_tau, 3) != round(tau, 3) and round(prev_p, 3) != round(p, 3):
        prev_tau = tau
        prev_p = p
        conv += 1
        tau = ar + (tau_0 - (d_tau * p))
        xpnt = (((eta/tau)**2 + 1/tau) * d_tau)/2
        p = 1/(1 + prefact * np.exp(-xpnt))
        #round
        tau = round(tau, 3)
        p = round(p, 3)
    conv -= 1
    
    return 1 - p, conv

r1, p1, ar1, br1 = generate_popcode_data(ndatapergain, nneuron, sig0_sq, sig1_sq, sigtc_sq, 1, "poisson")
r3, p3, ar3, br3 = generate_popcode_data(ndatapergain, nneuron, sig0_sq, sig1_sq, sigtc_sq, 3, "poisson")
r15, p15, ar15, br15 = generate_popcode_data(ndatapergain, nneuron, sig0_sq, sig1_sq, sigtc_sq, 15, "poisson")
a1 = p1
a3 = p3
a15 = p15
v1 = [0] * len(a1)
v3 = [0] * len(a3)
v15 = [0] * len(a15)
for i in range(len(a1)):
    v1[i], _ = run_variational_inference(ar1[i], br1[i])
    v3[i], _ = run_variational_inference(ar3[i], br3[i])
    v15[i], _ = run_variational_inference(ar15[i], br15[i])

# %%
"""
Multilayer ReLU net
"""

import os
import sys
import time

import numpy

import theano
import theano.tensor as T

def relu(x):
    return theano.tensor.switch(x<0, 0, x)

class HiddenLayer(object):
    def __init__(self, rng, input, n_in, n_out, W=None, b=None,
                 activation=relu):
        """
        Typical hidden layer of a MLP: units are fully-connected and have
        sigmoidal activation function. Weight matrix W is of shape (n_in,n_out)
        and the bias vector b is of shape (n_out,).

        NOTE : The nonlinearity used here is tanh

        Hidden unit activation is given by: tanh(dot(input,W) + b)

        :type rng: numpy.random.RandomState
        :param rng: a random number generator used to initialize weights

        :type input: theano.tensor.dmatrix
        :param input: a symbolic tensor of shape (n_examples, n_in)

        :type n_in: int
        :param n_in: dimensionality of input

        :type n_out: int
        :param n_out: number of hidden units

        :type activation: theano.Op or function
        :param activation: Non linearity to be applied in the hidden
                           layer
        """
        self.input = input
        # end-snippet-1

        # `W` is initialized with `W_values` which is uniformely sampled
        # from sqrt(-6./(n_in+n_hidden)) and sqrt(6./(n_in+n_hidden))
        # for tanh activation function
        # the output of uniform if converted using asarray to dtype
        # theano.config.floatX so that the code is runable on GPU
        # Note : optimal initialization of weights is dependent on the
        #        activation function used (among other things).
        #        For example, results presented in [Xavier10] suggest that you
        #        should use 4 times larger initial weights for sigmoid
        #        compared to tanh
        #        We have no info for other function, so we use the same as
        #        tanh.
        if W is None:
            """
            W_values = numpy.asarray(
                rng.uniform(
                    low=-numpy.sqrt(6. / (n_in + n_out)),
                    high=numpy.sqrt(6. / (n_in + n_out)),
                    size=(n_in, n_out)
                ),
                dtype=theano.config.floatX
            )
            """
            W_values = .05 * numpy.random.randn(n_in, n_out)
            #W_values = .1 * numpy.random.randn(n_in, n_out)
            
            """
            if activation == theano.tensor.nnet.sigmoid:
                W_values *= 4
            """

            W = theano.shared(value=W_values, name='W', borrow=True)

        if b is None:
            b_values = numpy.zeros((n_out,), dtype=theano.config.floatX)
            b = theano.shared(value=b_values, name='b', borrow=True)

        self.W = W
        self.b = b

        lin_output = T.dot(input, self.W) + self.b
        self.output = (
            lin_output if activation is None
            else activation(lin_output)
        )
        # parameters of the model
        self.params = [self.W, self.b]

class MLP(object):


    def __init__(self, rng, input, n_in, n_hidden, n_out):
        """Initialize the parameters for the multilayer perceptron

        :type rng: numpy.random.RandomState
        :param rng: a random number generator used to initialize weights

        :type input: theano.tensor.TensorType
        :param input: symbolic variable that describes the input of the
        architecture (one minibatch)

        :type n_in: int
        :param n_in: number of input units, the dimension of the space in
        which the datapoints lie

        :type n_hidden: int
        :param n_hidden: number of hidden units

        :type n_out: int
        :param n_out: number of output units, the dimension of the space in
        which the labels lie

        """

        # Since we are dealing with a one hidden layer MLP, this will translate
        # into a HiddenLayer with a tanh activation function connected to the
        # LogisticRegression layer; the activation function can be replaced by
        # sigmoid or any other nonlinear function
        self.hiddenLayer1 = HiddenLayer(
            rng=rng,
            input=input,
            n_in=n_in,
            n_out=n_hidden,
            activation=relu
        )
        
        self.hiddenLayer2 = HiddenLayer(
            rng=rng,
            input=self.hiddenLayer1.output,
            n_in=n_hidden,
            n_out=n_out,
            activation=relu
        )
        
        self.y_pred = self.hiddenLayer2.output
        
        # the parameters of the model are the parameters of the two layers it is made out of
        self.params = self.hiddenLayer1.params + self.hiddenLayer2.params
        
    def mse(self, y):
        # error between output and target
        return T.mean((self.y_pred.T - y) ** 2)

def shared_dataset(data_xy, borrow=True):
        """ Function that loads the dataset into shared variables

        The reason we store our dataset in shared variables is to allow
        Theano to copy it into the GPU memory (when code is run on GPU).
        Since copying data into the GPU is slow, copying a minibatch everytime
        is needed (the default behaviour if the data is not in a shared
        variable) would lead to a large decrease in performance.
        """
        data_x, data_y, _, _ = data_xy
        shared_x = theano.shared(numpy.asarray(data_x,
                                               dtype='float32'),
                                 borrow=borrow)
        shared_y = theano.shared(numpy.asarray(data_y,
                                               dtype='float32'),
                                 borrow=borrow)
        # When storing data on the GPU it has to be stored as floats
        # therefore we will store the labels as ``floatX`` as well
        # (``shared_y`` does exactly that). But during our computations
        # we need them as ints (we use labels as index, and if they are
        # floats it doesn't make sense) therefore instead of returning
        # ``shared_y`` we will have to cast it to int. This little hack
        # lets ous get around this issue
        return shared_x, shared_y

def train_nn(dataset, n_hidden=2, learning_rate=0.01, n_epochs=10, batch_size=20, test_data=None):
    """
    Demonstrate stochastic gradient descent optimization for a multilayer
    perceptron

    This is demonstrated on MNIST.

    :type learning_rate: float
    :param learning_rate: learning rate used (factor for the stochastic
    gradient

    :type n_epochs: int
    :param n_epochs: maximal number of epochs to run the optimizer

    :type dataset: string
    :param dataset: the path of the MNIST dataset file from
                 http://www.iro.umontreal.ca/~lisa/deep/data/mnist/mnist.pkl.gz


   """
    train_set_x, train_set_y = shared_dataset(dataset)

    # compute number of minibatches for training, validation and testing
    n_train_batches = train_set_x.get_value(borrow=True).shape[0] / batch_size
    
    test_batch_size = 1
    
    ######################
    # BUILD ACTUAL MODEL #
    ######################
    print '... building the model'

    # allocate symbolic variables for the data
    index = T.lscalar()  # index to a [mini]batch
    x = T.fmatrix('x')   # input data from visual neurons
    y = T.fvector('y')  # posterior

    rng = numpy.random.RandomState(1234)

    # construct the MLP class
    nn = MLP(
        rng=rng,
        input=x,
        n_in=41,
        n_hidden=n_hidden,
        n_out=1
    )

    # the cost we minimize during training is the mean squared error; cost is expressed
    # here symbolically
    cost = nn.mse(y)

    # compute the gradient of cost with respect to theta (sotred in params)
    # the resulting gradients will be stored in a list gparams
    gparams = [T.grad(cost, param) for param in nn.params]

    # specify how to update the parameters of the model as a list of
    # (variable, update expression) pairs

    # given two list the zip A = [a1, a2, a3, a4] and B = [b1, b2, b3, b4] of
    # same length, zip generates a list C of same size, where each element
    # is a pair formed from the two lists :
    #    C = [(a1, b1), (a2, b2), (a3, b3), (a4, b4)]
    updates = [
        (param, param - learning_rate * gparam)
        for param, gparam in zip(nn.params, gparams)
    ]

    # compiling a Theano function `train_model` that returns the cost, but
    # in the same time updates the parameter of the model based on the rules
    # defined in `updates`
    train_model = theano.function(
        inputs=[index],
        outputs=cost,
        updates=updates,
        givens={
            x: train_set_x[index * batch_size: (index + 1) * batch_size],
            y: train_set_y[index * batch_size: (index + 1) * batch_size]
        }
    )

    ###############
    # TRAIN MODEL #
    ###############
    print '... training'

    start_time = time.clock()

    epoch = 0
    done_looping = False

    while (epoch < n_epochs) and (not done_looping):
        epoch = epoch + 1
        for minibatch_index in xrange(n_train_batches):
            
            minibatch_avg_cost = train_model(minibatch_index)
            
            print "epoch " + repr(epoch)
            print "minibatch " + repr(minibatch_index + 1) + "/" + repr(n_train_batches)
            print "average cost " + repr(minibatch_avg_cost)

    end_time = time.clock()

    print 'testing'
    test_batch_size = 1
    test_set_x, test_set_y = shared_dataset(test_data)
    test_model = theano.function(
        inputs=[index],
        outputs=nn.y_pred,
        givens={
            x: test_set_x[index * test_batch_size: (index + 1) * test_batch_size]
        },
    )
    
    true_ys = test_set_y.get_value()
    pred_ys = numpy.zeros(len(true_ys))
    for i in range(len(true_ys)):
        pred_ys[i] = test_model(i)
    
    return pred_ys, true_ys

train_data1 = generate_popcode_data(ndatapergain, nneuron, sig0_sq, sig1_sq, sigtc_sq, 1, "poisson")
train_data3 = generate_popcode_data(ndatapergain, nneuron, sig0_sq, sig1_sq, sigtc_sq, 3, "poisson")
train_data15 = generate_popcode_data(ndatapergain, nneuron, sig0_sq, sig1_sq, sigtc_sq, 15, "poisson")
nn1, _ = train_nn(train_data1, n_hidden=8, learning_rate=.01, n_epochs=50, test_data=(r1, p1, ar1, br1))
nn3, _ = train_nn(train_data1, n_hidden=8, learning_rate=.01, n_epochs=50, test_data=(r3, p3, ar3, br3))
nn15, _ = train_nn(train_data1, n_hidden=8, learning_rate=.01, n_epochs=50, test_data=(r15, p15, ar15, br15))
# Out:
# ... building the model
# ... training
# epoch 1
# minibatch 1/150
# average cost array(0.3613374434248732)
# epoch 1
# minibatch 2/150
# average cost array(0.40800069894106245)
# epoch 1
# minibatch 3/150
# average cost array(0.37471551916443924)
# epoch 1
# minibatch 4/150
# average cost array(0.3933774701030063)
# epoch 1
# minibatch 5/150
# average cost array(0.33222483699350386)
# epoch 1
# minibatch 6/150
# average cost array(0.3223198636768812)
# epoch 1
# minibatch 7/150
# average cost array(0.3485500073583917)
# epoch 1
# minibatch 8/150
# average cost array(0.27356570690581006)
# epoch 1
# minibatch 9/150
# average cost array(0.2780640036219844)
# epoch 1
# minibatch 10/150
# average cost array(0.2713423925080892)
# epoch 1
# minibatch 11/150
# average cost array(0.26052315143732063)
# epoch 1
# minibatch 12/150
# average cost array(0.25830750904170835)
# epoch 1
# minibatch 13/150
# average cost array(0.24969901868285432)
# epoch 1
# minibatch 14/150
# average cost array(0.22393902486033684)
# epoch 1
# minibatch 15/150
# average cost array(0.24386000694277402)
# epoch 1
# minibatch 16/150
# average cost array(0.2053444603339159)
# epoch 1
# minibatch 17/150
# average cost array(0.21594533139352193)
# epoch 1
# minibatch 18/150
# average cost array(0.16824596024595836)
# epoch 1
# minibatch 19/150
# average cost array(0.20068272680820579)
# epoch 1
# minibatch 20/150
# average cost array(0.1941010674232039)
# epoch 1
# minibatch 21/150
# average cost array(0.148275700560243)
# epoch 1
# minibatch 22/150
# average cost array(0.16310392074398902)
# epoch 1
# minibatch 23/150
# average cost array(0.14639538391262835)
# epoch 1
# minibatch 24/150
# average cost array(0.16572727054979527)
# epoch 1
# minibatch 25/150
# average cost array(0.15104945731597252)
# epoch 1
# minibatch 26/150
# average cost array(0.16502340270589472)
# epoch 1
# minibatch 27/150
# average cost array(0.11438537430542275)
# epoch 1
# minibatch 28/150
# average cost array(0.142905746993027)
# epoch 1
# minibatch 29/150
# average cost array(0.12984688540421138)
# epoch 1
# minibatch 30/150
# average cost array(0.10618495060767699)
# epoch 1
# minibatch 31/150
# average cost array(0.10122784933037532)
# epoch 1
# minibatch 32/150
# average cost array(0.11433119409488808)
# epoch 1
# minibatch 33/150
# average cost array(0.09626233951416775)
# epoch 1
# minibatch 34/150
# average cost array(0.059753011485652915)
# epoch 1
# minibatch 35/150
# average cost array(0.07717847565225071)
# epoch 1
# minibatch 36/150
# average cost array(0.10213797556703161)
# epoch 1
# minibatch 37/150
# average cost array(0.08870035160824886)
# epoch 1
# minibatch 38/150
# average cost array(0.09741681999212766)
# epoch 1
# minibatch 39/150
# average cost array(0.0838846279336368)
# epoch 1
# minibatch 40/150
# average cost array(0.08082808538524403)
# epoch 1
# minibatch 41/150
# average cost array(0.06653597840746787)
# epoch 1
# minibatch 42/150
# average cost array(0.07249348679630517)
# epoch 1
# minibatch 43/150
# average cost array(0.05932705009234004)
# epoch 1
# minibatch 44/150
# average cost array(0.06011473006517023)
# epoch 1
# minibatch 45/150
# average cost array(0.062078582481431874)
# epoch 1
# minibatch 46/150
# average cost array(0.06903064529586055)
# epoch 1
# minibatch 47/150
# average cost array(0.05839685523175181)
# epoch 1
# minibatch 48/150
# average cost array(0.06661052660958403)
# epoch 1
# minibatch 49/150
# average cost array(0.04971879190808569)
# epoch 1
# minibatch 50/150
# average cost array(0.053874033895104735)
# epoch 1
# minibatch 51/150
# average cost array(0.05093378209757501)
# epoch 1
# minibatch 52/150
# average cost array(0.05685808485848295)
# epoch 1
# minibatch 53/150
# average cost array(0.06141358834182662)
# epoch 1
# minibatch 54/150
# average cost array(0.053061024265380265)
# epoch 1
# minibatch 55/150
# average cost array(0.03371042146564751)
# epoch 1
# minibatch 56/150
# average cost array(0.04869444366353818)
# epoch 1
# minibatch 57/150
# average cost array(0.037859194797844796)
# epoch 1
# minibatch 58/150
# average cost array(0.03439270309586985)
# epoch 1
# minibatch 59/150
# average cost array(0.04241238681680963)
# epoch 1
# minibatch 60/150
# average cost array(0.03978162343534045)
# epoch 1
# minibatch 61/150
# average cost array(0.04152506407770667)
# epoch 1
# minibatch 62/150
# average cost array(0.032574282469969316)
# epoch 1
# minibatch 63/150
# average cost array(0.024792421221927402)
# epoch 1
# minibatch 64/150
# average cost array(0.032682501271750104)
# epoch 1
# minibatch 65/150
# average cost array(0.03649830033565644)
# epoch 1
# minibatch 66/150
# average cost array(0.04304339669043315)
# epoch 1
# minibatch 67/150
# average cost array(0.031162175897377076)
# epoch 1
# minibatch 68/150
# average cost array(0.022596836328476724)
# epoch 1
# minibatch 69/150
# average cost array(0.023406724584087043)
# epoch 1
# minibatch 70/150
# average cost array(0.02673407684783825)
# epoch 1
# minibatch 71/150
# average cost array(0.03044650981522292)
# epoch 1
# minibatch 72/150
# average cost array(0.024740571101581316)
# epoch 1
# minibatch 73/150
# average cost array(0.021810440172251745)
# epoch 1
# minibatch 74/150
# average cost array(0.022940248907316534)
# epoch 1
# minibatch 75/150
# average cost array(0.04479000387415071)
# epoch 1
# minibatch 76/150
# average cost array(0.07447294088434883)
# epoch 1
# minibatch 77/150
# average cost array(0.05336992742609318)
# epoch 1
# minibatch 78/150
# average cost array(0.10996939601649805)
# epoch 1
# minibatch 79/150
# average cost array(0.11985577538472691)
# epoch 1
# minibatch 80/150
# average cost array(0.048314911915448164)
# epoch 1
# minibatch 81/150
# average cost array(0.12098014176868069)
# epoch 1
# minibatch 82/150
# average cost array(0.15418106016297606)
# epoch 1
# minibatch 83/150
# average cost array(0.0721368854620545)
# epoch 1
# minibatch 84/150
# average cost array(0.0937116102633304)
# epoch 1
# minibatch 85/150
# average cost array(0.09525215831765452)
# epoch 1
# minibatch 86/150
# average cost array(0.08880817816603678)
# epoch 1
# minibatch 87/150
# average cost array(0.08701524382086401)
# epoch 1
# minibatch 88/150
# average cost array(0.07349447284231655)
# epoch 1
# minibatch 89/150
# average cost array(0.058337889477755187)
# epoch 1
# minibatch 90/150
# average cost array(0.10954349260690652)
# epoch 1
# minibatch 91/150
# average cost array(0.08389283703263528)
# epoch 1
# minibatch 92/150
# average cost array(0.0586308827271587)
# epoch 1
# minibatch 93/150
# average cost array(0.07104114927855756)
# epoch 1
# minibatch 94/150
# average cost array(0.11326533424409199)
# epoch 1
# minibatch 95/150
# average cost array(0.07227000392409812)
# epoch 1
# minibatch 96/150
# average cost array(0.09158700863355937)
# epoch 1
# minibatch 97/150
# average cost array(0.06775846858013493)
# epoch 1
# minibatch 98/150
# average cost array(0.08078086176556579)
# epoch 1
# minibatch 99/150
# average cost array(0.07424583420264748)
# epoch 1
# minibatch 100/150
# average cost array(0.07102992672654593)
# epoch 1
# minibatch 101/150
# average cost array(0.09502687676377326)
# epoch 1
# minibatch 102/150
# average cost array(0.057187305603309056)
# epoch 1
# minibatch 103/150
# average cost array(0.0828772797538071)
# epoch 1
# minibatch 104/150
# average cost array(0.08969484485992307)
# epoch 1
# minibatch 105/150
# average cost array(0.07644823598231075)
# epoch 1
# minibatch 106/150
# average cost array(0.09103258803112166)
# epoch 1
# minibatch 107/150
# average cost array(0.053602403492453154)
# epoch 1
# minibatch 108/150
# average cost array(0.06761890744764197)
# epoch 1
# minibatch 109/150
# average cost array(0.06843003513610393)
# epoch 1
# minibatch 110/150
# average cost array(0.09212258238016172)
# epoch 1
# minibatch 111/150
# average cost array(0.06873208902755142)
# epoch 1
# minibatch 112/150
# average cost array(0.10561497683731787)
# epoch 1
# minibatch 113/150
# average cost array(0.10006702303081878)
# epoch 1
# minibatch 114/150
# average cost array(0.07822903951277863)
# epoch 1
# minibatch 115/150
# average cost array(0.09140775040984075)
# epoch 1
# minibatch 116/150
# average cost array(0.08634069866787372)
# epoch 1
# minibatch 117/150
# average cost array(0.10958399702454633)
# epoch 1
# minibatch 118/150
# average cost array(0.0886375074222461)
# epoch 1
# minibatch 119/150
# average cost array(0.08670024413911223)
# epoch 1
# minibatch 120/150
# average cost array(0.07384817756336168)
# epoch 1
# minibatch 121/150
# average cost array(0.0821375384193172)
# epoch 1
# minibatch 122/150
# average cost array(0.04821579471556601)
# epoch 1
# minibatch 123/150
# average cost array(0.061869066594312225)
# epoch 1
# minibatch 124/150
# average cost array(0.07080640151494758)
# epoch 1
# minibatch 125/150
# average cost array(0.09429970537104776)
# epoch 1
# minibatch 126/150
# average cost array(0.05732067818756311)
# epoch 1
# minibatch 127/150
# average cost array(0.06855292909365998)
# epoch 1
# minibatch 128/150
# average cost array(0.05539991473690377)
# epoch 1
# minibatch 129/150
# average cost array(0.08226420998316396)
# epoch 1
# minibatch 130/150
# average cost array(0.06238869051821146)
# epoch 1
# minibatch 131/150
# average cost array(0.06463779027553926)
# epoch 1
# minibatch 132/150
# average cost array(0.0919016730850195)
# epoch 1
# minibatch 133/150
# average cost array(0.09095306812148217)
# epoch 1
# minibatch 134/150
# average cost array(0.06661981056180764)
# epoch 1
# minibatch 135/150
# average cost array(0.06286732153644885)
# epoch 1
# minibatch 136/150
# average cost array(0.061115411558568464)
# epoch 1
# minibatch 137/150
# average cost array(0.08083280483441271)
# epoch 1
# minibatch 138/150
# average cost array(0.0646475340144286)
# epoch 1
# minibatch 139/150
# average cost array(0.0873787752948657)
# epoch 1
# minibatch 140/150
# average cost array(0.07155761041745973)
# epoch 1
# minibatch 141/150
# average cost array(0.06251554230252922)
# epoch 1
# minibatch 142/150
# average cost array(0.06050342153674733)
# epoch 1
# minibatch 143/150
# average cost array(0.06843410827132887)
# epoch 1
# minibatch 144/150
# average cost array(0.071059076541213)
# epoch 1
# minibatch 145/150
# average cost array(0.07292050496936409)
# epoch 1
# minibatch 146/150
# average cost array(0.06391674285136982)
# epoch 1
# minibatch 147/150
# average cost array(0.08081286537931479)
# epoch 1
# minibatch 148/150
# average cost array(0.07019172937698921)
# epoch 1
# minibatch 149/150
# average cost array(0.05504310528750024)
# epoch 1
# minibatch 150/150
# average cost array(0.06386107778475389)
# epoch 2
# minibatch 1/150
# average cost array(0.04463430831753221)
# epoch 2
# minibatch 2/150
# average cost array(0.06556143245303686)
# epoch 2
# minibatch 3/150
# average cost array(0.06015802065246543)
# epoch 2
# minibatch 4/150
# average cost array(0.052771456281919274)
# epoch 2
# minibatch 5/150
# average cost array(0.05957303649498667)
# epoch 2
# minibatch 6/150
# average cost array(0.051846095038789695)
# epoch 2
# minibatch 7/150
# average cost array(0.051413492829227324)
# epoch 2
# minibatch 8/150
# average cost array(0.035251477499342695)
# epoch 2
# minibatch 9/150
# average cost array(0.03951989138843627)
# epoch 2
# minibatch 10/150
# average cost array(0.03623177279018862)
# epoch 2
# minibatch 11/150
# average cost array(0.0373449680918336)
# epoch 2
# minibatch 12/150
# average cost array(0.03999381742973375)
# epoch 2
# minibatch 13/150
# average cost array(0.04650169585203869)
# epoch 2
# minibatch 14/150
# average cost array(0.05136476999426799)
# epoch 2
# minibatch 15/150
# average cost array(0.03469343282852854)
# epoch 2
# minibatch 16/150
# average cost array(0.031012358278491053)
# epoch 2
# minibatch 17/150
# average cost array(0.02979334334392634)
# epoch 2
# minibatch 18/150
# average cost array(0.04659989015572139)
# epoch 2
# minibatch 19/150
# average cost array(0.03287339690190823)
# epoch 2
# minibatch 20/150
# average cost array(0.023927194887091725)
# epoch 2
# minibatch 21/150
# average cost array(0.03102231278771834)
# epoch 2
# minibatch 22/150
# average cost array(0.0239776997467152)
# epoch 2
# minibatch 23/150
# average cost array(0.028091815642764046)
# epoch 2
# minibatch 24/150
# average cost array(0.02280204593425654)
# epoch 2
# minibatch 25/150
# average cost array(0.02508371292275292)
# epoch 2
# minibatch 26/150
# average cost array(0.022863941124835398)
# epoch 2
# minibatch 27/150
# average cost array(0.01945521236253544)
# epoch 2
# minibatch 28/150
# average cost array(0.019985059957394368)
# epoch 2
# minibatch 29/150
# average cost array(0.023025817304569606)
# epoch 2
# minibatch 30/150
# average cost array(0.016343862297323184)
# epoch 2
# minibatch 31/150
# average cost array(0.026071754003656578)
# epoch 2
# minibatch 32/150
# average cost array(0.021070472039559588)
# epoch 2
# minibatch 33/150
# average cost array(0.023253769850199456)
# epoch 2
# minibatch 34/150
# average cost array(0.020974437300841184)
# epoch 2
# minibatch 35/150
# average cost array(0.03688964247865654)
# epoch 2
# minibatch 36/150
# average cost array(0.01795136376334943)
# epoch 2
# minibatch 37/150
# average cost array(0.022665357391443038)
# epoch 2
# minibatch 38/150
# average cost array(0.016031796768042113)
# epoch 2
# minibatch 39/150
# average cost array(0.014403994452777005)
# epoch 2
# minibatch 40/150
# average cost array(0.030140909125927835)
# epoch 2
# minibatch 41/150
# average cost array(0.01376761619686045)
# epoch 2
# minibatch 42/150
# average cost array(0.019497773611728712)
# epoch 2
# minibatch 43/150
# average cost array(0.01820822006663533)
# epoch 2
# minibatch 44/150
# average cost array(0.02883988343702083)
# epoch 2
# minibatch 45/150
# average cost array(0.025105661981897027)
# epoch 2
# minibatch 46/150
# average cost array(0.017432075542080892)
# epoch 2
# minibatch 47/150
# average cost array(0.014428559807916488)
# epoch 2
# minibatch 48/150
# average cost array(0.014231010776532405)
# epoch 2
# minibatch 49/150
# average cost array(0.01429791570010078)
# epoch 2
# minibatch 50/150
# average cost array(0.019984370685192526)
# epoch 2
# minibatch 51/150
# average cost array(0.029430128463983)
# epoch 2
# minibatch 52/150
# average cost array(0.017400884955387212)
# epoch 2
# minibatch 53/150
# average cost array(0.0379695694417485)
# epoch 2
# minibatch 54/150
# average cost array(0.02288267936396146)
# epoch 2
# minibatch 55/150
# average cost array(0.01636456662413561)
# epoch 2
# minibatch 56/150
# average cost array(0.015441271587074808)
# epoch 2
# minibatch 57/150
# average cost array(0.021213034911531443)
# epoch 2
# minibatch 58/150
# average cost array(0.015612189842739202)
# epoch 2
# minibatch 59/150
# average cost array(0.01709727782834126)
# epoch 2
# minibatch 60/150
# average cost array(0.03205831975508715)
# epoch 2
# minibatch 61/150
# average cost array(0.018562383244788375)
# epoch 2
# minibatch 62/150
# average cost array(0.0195039513978629)
# epoch 2
# minibatch 63/150
# average cost array(0.014082992198573407)
# epoch 2
# minibatch 64/150
# average cost array(0.01619118902634798)
# epoch 2
# minibatch 65/150
# average cost array(0.025267616165513568)
# epoch 2
# minibatch 66/150
# average cost array(0.040624410712423904)
# epoch 2
# minibatch 67/150
# average cost array(0.015382679658039258)
# epoch 2
# minibatch 68/150
# average cost array(0.008757995056113934)
# epoch 2
# minibatch 69/150
# average cost array(0.012291584627386196)
# epoch 2
# minibatch 70/150
# average cost array(0.014942644206540345)
# epoch 2
# minibatch 71/150
# average cost array(0.03016586806747736)
# epoch 2
# minibatch 72/150
# average cost array(0.015879284279503365)
# epoch 2
# minibatch 73/150
# average cost array(0.00948841768522872)
# epoch 2
# minibatch 74/150
# average cost array(0.012818927107998085)
# epoch 2
# minibatch 75/150
# average cost array(0.037499703546724314)
# epoch 2
# minibatch 76/150
# average cost array(0.07883314431713492)
# epoch 2
# minibatch 77/150
# average cost array(0.05227583854899215)
# epoch 2
# minibatch 78/150
# average cost array(0.11983557411195685)
# epoch 2
# minibatch 79/150
# average cost array(0.13031760787082172)
# epoch 2
# minibatch 80/150
# average cost array(0.05285113867315093)
# epoch 2
# minibatch 81/150
# average cost array(0.12842193932228035)
# epoch 2
# minibatch 82/150
# average cost array(0.16125709841266728)
# epoch 2
# minibatch 83/150
# average cost array(0.07328222066116703)
# epoch 2
# minibatch 84/150
# average cost array(0.09631672825480922)
# epoch 2
# minibatch 85/150
# average cost array(0.09654681884200303)
# epoch 2
# minibatch 86/150
# average cost array(0.0879383591971523)
# epoch 2
# minibatch 87/150
# average cost array(0.08801428752465837)
# epoch 2
# minibatch 88/150
# average cost array(0.07236023272655139)
# epoch 2
# minibatch 89/150
# average cost array(0.052567243550730246)
# epoch 2
# minibatch 90/150
# average cost array(0.11533271517887725)
# epoch 2
# minibatch 91/150
# average cost array(0.08905687264613674)
# epoch 2
# minibatch 92/150
# average cost array(0.05473507122622325)
# epoch 2
# minibatch 93/150
# average cost array(0.07591455754084056)
# epoch 2
# minibatch 94/150
# average cost array(0.11598666110115738)
# epoch 2
# minibatch 95/150
# average cost array(0.066517892924796)
# epoch 2
# minibatch 96/150
# average cost array(0.0882825720990751)
# epoch 2
# minibatch 97/150
# average cost array(0.06269291053111589)
# epoch 2
# minibatch 98/150
# average cost array(0.0820451755792837)
# epoch 2
# minibatch 99/150
# average cost array(0.07356877923258225)
# epoch 2
# minibatch 100/150
# average cost array(0.06864246354644475)
# epoch 2
# minibatch 101/150
# average cost array(0.09112912539180217)
# epoch 2
# minibatch 102/150
# average cost array(0.05369952881784407)
# epoch 2
# minibatch 103/150
# average cost array(0.08113463621197405)
# epoch 2
# minibatch 104/150
# average cost array(0.08574952713165471)
# epoch 2
# minibatch 105/150
# average cost array(0.07520972876433799)
# epoch 2
# minibatch 106/150
# average cost array(0.08692140845612466)
# epoch 2
# minibatch 107/150
# average cost array(0.04831175123880384)
# epoch 2
# minibatch 108/150
# average cost array(0.06249040593062279)
# epoch 2
# minibatch 109/150
# average cost array(0.062399331491537556)
# epoch 2
# minibatch 110/150
# average cost array(0.0896625438607449)
# epoch 2
# minibatch 111/150
# average cost array(0.06117325517588904)
# epoch 2
# minibatch 112/150
# average cost array(0.09766504460141619)
# epoch 2
# minibatch 113/150
# average cost array(0.0989569318096693)
# epoch 2
# minibatch 114/150
# average cost array(0.07161059902578433)
# epoch 2
# minibatch 115/150
# average cost array(0.08484455155605161)
# epoch 2
# minibatch 116/150
# average cost array(0.07821632872686807)
# epoch 2
# minibatch 117/150
# average cost array(0.10290812459771057)
# epoch 2
# minibatch 118/150
# average cost array(0.08515995666191598)
# epoch 2
# minibatch 119/150
# average cost array(0.07886861033909097)
# epoch 2
# minibatch 120/150
# average cost array(0.06561214433453566)
# epoch 2
# minibatch 121/150
# average cost array(0.07354826628948007)
# epoch 2
# minibatch 122/150
# average cost array(0.04472355308233546)
# epoch 2
# minibatch 123/150
# average cost array(0.05762205834772054)
# epoch 2
# minibatch 124/150
# average cost array(0.06746331683646536)
# epoch 2
# minibatch 125/150
# average cost array(0.09029114765379156)
# epoch 2
# minibatch 126/150
# average cost array(0.053140277408783174)
# epoch 2
# minibatch 127/150
# average cost array(0.06165823239169118)
# epoch 2
# minibatch 128/150
# average cost array(0.049684112827592004)
# epoch 2
# minibatch 129/150
# average cost array(0.07603188723599866)
# epoch 2
# minibatch 130/150
# average cost array(0.057252981361427036)
# epoch 2
# minibatch 131/150
# average cost array(0.05964743675189911)
# epoch 2
# minibatch 132/150
# average cost array(0.08486836493900751)
# epoch 2
# minibatch 133/150
# average cost array(0.08232508106378011)
# epoch 2
# minibatch 134/150
# average cost array(0.06001671810248862)
# epoch 2
# minibatch 135/150
# average cost array(0.05763659296159805)
# epoch 2
# minibatch 136/150
# average cost array(0.05401548033442487)
# epoch 2
# minibatch 137/150
# average cost array(0.07603608119679504)
# epoch 2
# minibatch 138/150
# average cost array(0.056454954711368376)
# epoch 2
# minibatch 139/150
# average cost array(0.07992005396027455)
# epoch 2
# minibatch 140/150
# average cost array(0.06739154663032418)
# epoch 2
# minibatch 141/150
# average cost array(0.05788332852597228)
# epoch 2
# minibatch 142/150
# average cost array(0.05821293208034556)
# epoch 2
# minibatch 143/150
# average cost array(0.05978368483981663)
# epoch 2
# minibatch 144/150
# average cost array(0.0659525414213846)
# epoch 2
# minibatch 145/150
# average cost array(0.0656227262421689)
# epoch 2
# minibatch 146/150
# average cost array(0.05827381345979038)
# epoch 2
# minibatch 147/150
# average cost array(0.071481761972127)
# epoch 2
# minibatch 148/150
# average cost array(0.06722912607727287)
# epoch 2
# minibatch 149/150
# average cost array(0.049120898709327565)
# epoch 2
# minibatch 150/150
# average cost array(0.05788000653760082)
# epoch 3
# minibatch 1/150
# average cost array(0.037292778927212784)
# epoch 3
# minibatch 2/150
# average cost array(0.055578274517454486)
# epoch 3
# minibatch 3/150
# average cost array(0.05143118576873592)
# epoch 3
# minibatch 4/150
# average cost array(0.0413520436884751)
# epoch 3
# minibatch 5/150
# average cost array(0.05333393329952977)
# epoch 3
# minibatch 6/150
# average cost array(0.041683077934238186)
# epoch 3
# minibatch 7/150
# average cost array(0.04317099963563955)
# epoch 3
# minibatch 8/150
# average cost array(0.029246669527843588)
# epoch 3
# minibatch 9/150
# average cost array(0.033525295630317246)
# epoch 3
# minibatch 10/150
# average cost array(0.029892368154837708)
# epoch 3
# minibatch 11/150
# average cost array(0.030052967063814807)
# epoch 3
# minibatch 12/150
# average cost array(0.034821769570874496)
# epoch 3
# minibatch 13/150
# average cost array(0.03913124092406391)
# epoch 3
# minibatch 14/150
# average cost array(0.0442795821001077)
# epoch 3
# minibatch 15/150
# average cost array(0.028638693089992978)
# epoch 3
# minibatch 16/150
# average cost array(0.026963339256481967)
# epoch 3
# minibatch 17/150
# average cost array(0.023833154304859445)
# epoch 3
# minibatch 18/150
# average cost array(0.04469157127235139)
# epoch 3
# minibatch 19/150
# average cost array(0.028540026239845258)
# epoch 3
# minibatch 20/150
# average cost array(0.019805819664648342)
# epoch 3
# minibatch 21/150
# average cost array(0.027188204123675803)
# epoch 3
# minibatch 22/150
# average cost array(0.020720814046730568)
# epoch 3
# minibatch 23/150
# average cost array(0.026459931025789286)
# epoch 3
# minibatch 24/150
# average cost array(0.01764768680149436)
# epoch 3
# minibatch 25/150
# average cost array(0.021840804913286493)
# epoch 3
# minibatch 26/150
# average cost array(0.01795921960003457)
# epoch 3
# minibatch 27/150
# average cost array(0.01754310387331463)
# epoch 3
# minibatch 28/150
# average cost array(0.016061289419998147)
# epoch 3
# minibatch 29/150
# average cost array(0.020259093423627077)
# epoch 3
# minibatch 30/150
# average cost array(0.014914925803248328)
# epoch 3
# minibatch 31/150
# average cost array(0.022060066967421712)
# epoch 3
# minibatch 32/150
# average cost array(0.02019593045935321)
# epoch 3
# minibatch 33/150
# average cost array(0.02016756046434437)
# epoch 3
# minibatch 34/150
# average cost array(0.019961654594019315)
# epoch 3
# minibatch 35/150
# average cost array(0.03432296903140805)
# epoch 3
# minibatch 36/150
# average cost array(0.017315982864151362)
# epoch 3
# minibatch 37/150
# average cost array(0.02313821863780983)
# epoch 3
# minibatch 38/150
# average cost array(0.012478336355285533)
# epoch 3
# minibatch 39/150
# average cost array(0.012627916291879811)
# epoch 3
# minibatch 40/150
# average cost array(0.027033390738031023)
# epoch 3
# minibatch 41/150
# average cost array(0.012412384977880194)
# epoch 3
# minibatch 42/150
# average cost array(0.01882744189825782)
# epoch 3
# minibatch 43/150
# average cost array(0.01829159903023367)
# epoch 3
# minibatch 44/150
# average cost array(0.031645047664248374)
# epoch 3
# minibatch 45/150
# average cost array(0.02295448438445547)
# epoch 3
# minibatch 46/150
# average cost array(0.01609437965231887)
# epoch 3
# minibatch 47/150
# average cost array(0.013348854361479612)
# epoch 3
# minibatch 48/150
# average cost array(0.013491123670835516)
# epoch 3
# minibatch 49/150
# average cost array(0.01491382600376497)
# epoch 3
# minibatch 50/150
# average cost array(0.018913099032635133)
# epoch 3
# minibatch 51/150
# average cost array(0.028194074384803952)
# epoch 3
# minibatch 52/150
# average cost array(0.017714495550078105)
# epoch 3
# minibatch 53/150
# average cost array(0.034687855608439115)
# epoch 3
# minibatch 54/150
# average cost array(0.02275425964615094)
# epoch 3
# minibatch 55/150
# average cost array(0.015270445144643726)
# epoch 3
# minibatch 56/150
# average cost array(0.013762242271754346)
# epoch 3
# minibatch 57/150
# average cost array(0.024920522785131023)
# epoch 3
# minibatch 58/150
# average cost array(0.014329976389420454)
# epoch 3
# minibatch 59/150
# average cost array(0.016095680095397812)
# epoch 3
# minibatch 60/150
# average cost array(0.0303686564763919)
# epoch 3
# minibatch 61/150
# average cost array(0.0197859318806382)
# epoch 3
# minibatch 62/150
# average cost array(0.02057260414866862)
# epoch 3
# minibatch 63/150
# average cost array(0.0130740216436529)
# epoch 3
# minibatch 64/150
# average cost array(0.015352131713705645)
# epoch 3
# minibatch 65/150
# average cost array(0.024896623185836204)
# epoch 3
# minibatch 66/150
# average cost array(0.038951681107498345)
# epoch 3
# minibatch 67/150
# average cost array(0.014335962649240966)
# epoch 3
# minibatch 68/150
# average cost array(0.009368754564922302)
# epoch 3
# minibatch 69/150
# average cost array(0.01428056087908625)
# epoch 3
# minibatch 70/150
# average cost array(0.01448684419254366)
# epoch 3
# minibatch 71/150
# average cost array(0.028422586590672823)
# epoch 3
# minibatch 72/150
# average cost array(0.016275315143849632)
# epoch 3
# minibatch 73/150
# average cost array(0.008775621077526465)
# epoch 3
# minibatch 74/150
# average cost array(0.013322627108629446)
# epoch 3
# minibatch 75/150
# average cost array(0.03375794554553653)
# epoch 3
# minibatch 76/150
# average cost array(0.07126675464006661)
# epoch 3
# minibatch 77/150
# average cost array(0.04349433940070425)
# epoch 3
# minibatch 78/150
# average cost array(0.10478336965964885)
# epoch 3
# minibatch 79/150
# average cost array(0.11439809800225095)
# epoch 3
# minibatch 80/150
# average cost array(0.047975638541772656)
# epoch 3
# minibatch 81/150
# average cost array(0.11334067945521872)
# epoch 3
# minibatch 82/150
# average cost array(0.1372737912307653)
# epoch 3
# minibatch 83/150
# average cost array(0.06537756295774687)
# epoch 3
# minibatch 84/150
# average cost array(0.08653672072698702)
# epoch 3
# minibatch 85/150
# average cost array(0.08473617452554763)
# epoch 3
# minibatch 86/150
# average cost array(0.07634370810039749)
# epoch 3
# minibatch 87/150
# average cost array(0.0777158964573672)
# epoch 3
# minibatch 88/150
# average cost array(0.062022027213318585)
# epoch 3
# minibatch 89/150
# average cost array(0.047462620535883196)
# epoch 3
# minibatch 90/150
# average cost array(0.10517064912053031)
# epoch 3
# minibatch 91/150
# average cost array(0.08151800036106885)
# epoch 3
# minibatch 92/150
# average cost array(0.04767043054339078)
# epoch 3
# minibatch 93/150
# average cost array(0.0696464042474202)
# epoch 3
# minibatch 94/150
# average cost array(0.10461151206412597)
# epoch 3
# minibatch 95/150
# average cost array(0.05709243657167941)
# epoch 3
# minibatch 96/150
# average cost array(0.07894764890792974)
# epoch 3
# minibatch 97/150
# average cost array(0.05484430353138962)
# epoch 3
# minibatch 98/150
# average cost array(0.07453189317325751)
# epoch 3
# minibatch 99/150
# average cost array(0.06634902964374165)
# epoch 3
# minibatch 100/150
# average cost array(0.06405627840288626)
# epoch 3
# minibatch 101/150
# average cost array(0.08246367704465961)
# epoch 3
# minibatch 102/150
# average cost array(0.051492965164681936)
# epoch 3
# minibatch 103/150
# average cost array(0.06989148522135177)
# epoch 3
# minibatch 104/150
# average cost array(0.07579219900901052)
# epoch 3
# minibatch 105/150
# average cost array(0.06939272654634923)
# epoch 3
# minibatch 106/150
# average cost array(0.07762070729733986)
# epoch 3
# minibatch 107/150
# average cost array(0.04439601024840541)
# epoch 3
# minibatch 108/150
# average cost array(0.05605809823977066)
# epoch 3
# minibatch 109/150
# average cost array(0.05569577099139976)
# epoch 3
# minibatch 110/150
# average cost array(0.08262993634878987)
# epoch 3
# minibatch 111/150
# average cost array(0.05348245273778145)
# epoch 3
# minibatch 112/150
# average cost array(0.0828647771600597)
# epoch 3
# minibatch 113/150
# average cost array(0.08958883810894391)
# epoch 3
# minibatch 114/150
# average cost array(0.06288949656949312)
# epoch 3
# minibatch 115/150
# average cost array(0.07542486815276571)
# epoch 3
# minibatch 116/150
# average cost array(0.06741740650277331)
# epoch 3
# minibatch 117/150
# average cost array(0.08812412140474256)
# epoch 3
# minibatch 118/150
# average cost array(0.07572167071361653)
# epoch 3
# minibatch 119/150
# average cost array(0.07128361841799963)
# epoch 3
# minibatch 120/150
# average cost array(0.05657399460103572)
# epoch 3
# minibatch 121/150
# average cost array(0.06421721994961974)
# epoch 3
# minibatch 122/150
# average cost array(0.03984480787575569)
# epoch 3
# minibatch 123/150
# average cost array(0.05188060140676215)
# epoch 3
# minibatch 124/150
# average cost array(0.06360672277508114)
# epoch 3
# minibatch 125/150
# average cost array(0.08169990729702577)
# epoch 3
# minibatch 126/150
# average cost array(0.05064090798977683)
# epoch 3
# minibatch 127/150
# average cost array(0.05455250063599604)
# epoch 3
# minibatch 128/150
# average cost array(0.04412279616816898)
# epoch 3
# minibatch 129/150
# average cost array(0.06714652593474783)
# epoch 3
# minibatch 130/150
# average cost array(0.05370416937991522)
# epoch 3
# minibatch 131/150
# average cost array(0.054866587166501946)
# epoch 3
# minibatch 132/150
# average cost array(0.07595642199675838)
# epoch 3
# minibatch 133/150
# average cost array(0.07261205496017585)
# epoch 3
# minibatch 134/150
# average cost array(0.053311146490020465)
# epoch 3
# minibatch 135/150
# average cost array(0.05120464985490249)
# epoch 3
# minibatch 136/150
# average cost array(0.048234845365739284)
# epoch 3
# minibatch 137/150
# average cost array(0.07007874488248356)
# epoch 3
# minibatch 138/150
# average cost array(0.04892865933140368)
# epoch 3
# minibatch 139/150
# average cost array(0.07038023521521711)
# epoch 3
# minibatch 140/150
# average cost array(0.06274351070511447)
# epoch 3
# minibatch 141/150
# average cost array(0.054482593371184516)
# epoch 3
# minibatch 142/150
# average cost array(0.054833112137677206)
# epoch 3
# minibatch 143/150
# average cost array(0.051619182374514704)
# epoch 3
# minibatch 144/150
# average cost array(0.059208366118784564)
# epoch 3
# minibatch 145/150
# average cost array(0.0576527515410889)
# epoch 3
# minibatch 146/150
# average cost array(0.05376522274140556)
# epoch 3
# minibatch 147/150
# average cost array(0.062397635875473)
# epoch 3
# minibatch 148/150
# average cost array(0.06239123547143355)
# epoch 3
# minibatch 149/150
# average cost array(0.0437553695693603)
# epoch 3
# minibatch 150/150
# average cost array(0.05183392592953852)
# epoch 4
# minibatch 1/150
# average cost array(0.03324370701290786)
# epoch 4
# minibatch 2/150
# average cost array(0.049526996212853155)
# epoch 4
# minibatch 3/150
# average cost array(0.04642023670435582)
# epoch 4
# minibatch 4/150
# average cost array(0.03414754824460508)
# epoch 4
# minibatch 5/150
# average cost array(0.05006489305113258)
# epoch 4
# minibatch 6/150
# average cost array(0.03459666497781218)
# epoch 4
# minibatch 7/150
# average cost array(0.03887506889992107)
# epoch 4
# minibatch 8/150
# average cost array(0.02620259168125837)
# epoch 4
# minibatch 9/150
# average cost array(0.03084994860845599)
# epoch 4
# minibatch 10/150
# average cost array(0.026552805378905742)
# epoch 4
# minibatch 11/150
# average cost array(0.02570264480737669)
# epoch 4
# minibatch 12/150
# average cost array(0.03280020068843988)
# epoch 4
# minibatch 13/150
# average cost array(0.034515425027674684)
# epoch 4
# minibatch 14/150
# average cost array(0.039738494166305136)
# epoch 4
# minibatch 15/150
# average cost array(0.025527286513521253)
# epoch 4
# minibatch 16/150
# average cost array(0.02526351914675972)
# epoch 4
# minibatch 17/150
# average cost array(0.020773574540220704)
# epoch 4
# minibatch 18/150
# average cost array(0.043818560647003256)
# epoch 4
# minibatch 19/150
# average cost array(0.026966785190553722)
# epoch 4
# minibatch 20/150
# average cost array(0.019579435901369548)
# epoch 4
# minibatch 21/150
# average cost array(0.02473787370507166)
# epoch 4
# minibatch 22/150
# average cost array(0.019533937347539238)
# epoch 4
# minibatch 23/150
# average cost array(0.026730004936050333)
# epoch 4
# minibatch 24/150
# average cost array(0.015289952959207712)
# epoch 4
# minibatch 25/150
# average cost array(0.020495699669882524)
# epoch 4
# minibatch 26/150
# average cost array(0.015771101725519245)
# epoch 4
# minibatch 27/150
# average cost array(0.017180980573923248)
# epoch 4
# minibatch 28/150
# average cost array(0.014746242009217042)
# epoch 4
# minibatch 29/150
# average cost array(0.01997734614035665)
# epoch 4
# minibatch 30/150
# average cost array(0.015123649774429131)
# epoch 4
# minibatch 31/150
# average cost array(0.019477430047284642)
# epoch 4
# minibatch 32/150
# average cost array(0.021538173753163494)
# epoch 4
# minibatch 33/150
# average cost array(0.018446828568165565)
# epoch 4
# minibatch 34/150
# average cost array(0.019055455584903763)
# epoch 4
# minibatch 35/150
# average cost array(0.03187497486605457)
# epoch 4
# minibatch 36/150
# average cost array(0.01905602017512356)
# epoch 4
# minibatch 37/150
# average cost array(0.025344454546774614)
# epoch 4
# minibatch 38/150
# average cost array(0.011340042806148715)
# epoch 4
# minibatch 39/150
# average cost array(0.012601660545523793)
# epoch 4
# minibatch 40/150
# average cost array(0.025445721947909766)
# epoch 4
# minibatch 41/150
# average cost array(0.012061354388181202)
# epoch 4
# minibatch 42/150
# average cost array(0.019360205345060815)
# epoch 4
# minibatch 43/150
# average cost array(0.019481656677227493)
# epoch 4
# minibatch 44/150
# average cost array(0.035397287855411415)
# epoch 4
# minibatch 45/150
# average cost array(0.021722182242356673)
# epoch 4
# minibatch 46/150
# average cost array(0.015924884347532222)
# epoch 4
# minibatch 47/150
# average cost array(0.01346374094167603)
# epoch 4
# minibatch 48/150
# average cost array(0.014118350977619645)
# epoch 4
# minibatch 49/150
# average cost array(0.016409734259398144)
# epoch 4
# minibatch 50/150
# average cost array(0.019074127095442005)
# epoch 4
# minibatch 51/150
# average cost array(0.02686500233608043)
# epoch 4
# minibatch 52/150
# average cost array(0.01912485098802473)
# epoch 4
# minibatch 53/150
# average cost array(0.03232479376482992)
# epoch 4
# minibatch 54/150
# average cost array(0.023616469047571323)
# epoch 4
# minibatch 55/150
# average cost array(0.014539261975809853)
# epoch 4
# minibatch 56/150
# average cost array(0.013429282761555783)
# epoch 4
# minibatch 57/150
# average cost array(0.02934408704660336)
# epoch 4
# minibatch 58/150
# average cost array(0.013727541173408126)
# epoch 4
# minibatch 59/150
# average cost array(0.01590628226076437)
# epoch 4
# minibatch 60/150
# average cost array(0.029500199066460155)
# epoch 4
# minibatch 61/150
# average cost array(0.022576140293978846)
# epoch 4
# minibatch 62/150
# average cost array(0.022389200279385277)
# epoch 4
# minibatch 63/150
# average cost array(0.012512930664781175)
# epoch 4
# minibatch 64/150
# average cost array(0.015509180073648626)
# epoch 4
# minibatch 65/150
# average cost array(0.02500680430908945)
# epoch 4
# minibatch 66/150
# average cost array(0.03751511651194793)
# epoch 4
# minibatch 67/150
# average cost array(0.013776238911281371)
# epoch 4
# minibatch 68/150
# average cost array(0.010585994312594979)
# epoch 4
# minibatch 69/150
# average cost array(0.01736547597975012)
# epoch 4
# minibatch 70/150
# average cost array(0.014441349811399778)
# epoch 4
# minibatch 71/150
# average cost array(0.026734095071806064)
# epoch 4
# minibatch 72/150
# average cost array(0.01718996042994524)
# epoch 4
# minibatch 73/150
# average cost array(0.00876822411296463)
# epoch 4
# minibatch 74/150
# average cost array(0.014430149312665671)
# epoch 4
# minibatch 75/150
# average cost array(0.030956096019646585)
# epoch 4
# minibatch 76/150
# average cost array(0.06396295607522258)
# epoch 4
# minibatch 77/150
# average cost array(0.03573337945489953)
# epoch 4
# minibatch 78/150
# average cost array(0.09010505690729344)
# epoch 4
# minibatch 79/150
# average cost array(0.09852860840981695)
# epoch 4
# minibatch 80/150
# average cost array(0.044373543763627586)
# epoch 4
# minibatch 81/150
# average cost array(0.09849021091303371)
# epoch 4
# minibatch 82/150
# average cost array(0.11387400340757103)
# epoch 4
# minibatch 83/150
# average cost array(0.057863150817821216)
# epoch 4
# minibatch 84/150
# average cost array(0.07718210405084144)
# epoch 4
# minibatch 85/150
# average cost array(0.07389201204992088)
# epoch 4
# minibatch 86/150
# average cost array(0.06561221713780639)
# epoch 4
# minibatch 87/150
# average cost array(0.06796820234707791)
# epoch 4
# minibatch 88/150
# average cost array(0.052097895730562185)
# epoch 4
# minibatch 89/150
# average cost array(0.04282739678581878)
# epoch 4
# minibatch 90/150
# average cost array(0.09477004186005508)
# epoch 4
# minibatch 91/150
# average cost array(0.0744707792919597)
# epoch 4
# minibatch 92/150
# average cost array(0.04191195677103203)
# epoch 4
# minibatch 93/150
# average cost array(0.06366341142892731)
# epoch 4
# minibatch 94/150
# average cost array(0.09370290378332183)
# epoch 4
# minibatch 95/150
# average cost array(0.04861090637742025)
# epoch 4
# minibatch 96/150
# average cost array(0.07075393015032014)
# epoch 4
# minibatch 97/150
# average cost array(0.04823451059734692)
# epoch 4
# minibatch 98/150
# average cost array(0.06712284407873416)
# epoch 4
# minibatch 99/150
# average cost array(0.059314283793403956)
# epoch 4
# minibatch 100/150
# average cost array(0.059884225166484895)
# epoch 4
# minibatch 101/150
# average cost array(0.07494213528946034)
# epoch 4
# minibatch 102/150
# average cost array(0.049330613882834703)
# epoch 4
# minibatch 103/150
# average cost array(0.059777852712463775)
# epoch 4
# minibatch 104/150
# average cost array(0.06638163088825132)
# epoch 4
# minibatch 105/150
# average cost array(0.06412878546231168)
# epoch 4
# minibatch 106/150
# average cost array(0.06898179224888873)
# epoch 4
# minibatch 107/150
# average cost array(0.04096063384730579)
# epoch 4
# minibatch 108/150
# average cost array(0.05018406740934295)
# epoch 4
# minibatch 109/150
# average cost array(0.04955376734555579)
# epoch 4
# minibatch 110/150
# average cost array(0.07553828177705141)
# epoch 4
# minibatch 111/150
# average cost array(0.046522151158318106)
# epoch 4
# minibatch 112/150
# average cost array(0.06894928449157059)
# epoch 4
# minibatch 113/150
# average cost array(0.08028890497381296)
# epoch 4
# minibatch 114/150
# average cost array(0.0548622552981053)
# epoch 4
# minibatch 115/150
# average cost array(0.06620698608004534)
# epoch 4
# minibatch 116/150
# average cost array(0.058478976831284904)
# epoch 4
# minibatch 117/150
# average cost array(0.07571553825481232)
# epoch 4
# minibatch 118/150
# average cost array(0.06630410370718884)
# epoch 4
# minibatch 119/150
# average cost array(0.06421597916729169)
# epoch 4
# minibatch 120/150
# average cost array(0.04883987508063577)
# epoch 4
# minibatch 121/150
# average cost array(0.05590735258757211)
# epoch 4
# minibatch 122/150
# average cost array(0.03588630140647683)
# epoch 4
# minibatch 123/150
# average cost array(0.046975126388745375)
# epoch 4
# minibatch 124/150
# average cost array(0.05983966369895163)
# epoch 4
# minibatch 125/150
# average cost array(0.07301833920300949)
# epoch 4
# minibatch 126/150
# average cost array(0.04874638952268516)
# epoch 4
# minibatch 127/150
# average cost array(0.0489848519791408)
# epoch 4
# minibatch 128/150
# average cost array(0.03907859475913897)
# epoch 4
# minibatch 129/150
# average cost array(0.05898721301203051)
# epoch 4
# minibatch 130/150
# average cost array(0.05044199702541805)
# epoch 4
# minibatch 131/150
# average cost array(0.05053843795924695)
# epoch 4
# minibatch 132/150
# average cost array(0.06777729987208941)
# epoch 4
# minibatch 133/150
# average cost array(0.06375286035392863)
# epoch 4
# minibatch 134/150
# average cost array(0.04760768329067619)
# epoch 4
# minibatch 135/150
# average cost array(0.045415288264579814)
# epoch 4
# minibatch 136/150
# average cost array(0.04305680301552935)
# epoch 4
# minibatch 137/150
# average cost array(0.06513187705090273)
# epoch 4
# minibatch 138/150
# average cost array(0.042377489390257726)
# epoch 4
# minibatch 139/150
# average cost array(0.06201326839628577)
# epoch 4
# minibatch 140/150
# average cost array(0.058900290824686896)
# epoch 4
# minibatch 141/150
# average cost array(0.05192449613403055)
# epoch 4
# minibatch 142/150
# average cost array(0.051308498866488875)
# epoch 4
# minibatch 143/150
# average cost array(0.044223357669749434)
# epoch 4
# minibatch 144/150
# average cost array(0.05325494452831907)
# epoch 4
# minibatch 145/150
# average cost array(0.05034235737123035)
# epoch 4
# minibatch 146/150
# average cost array(0.05032476122797912)
# epoch 4
# minibatch 147/150
# average cost array(0.05482690845595489)
# epoch 4
# minibatch 148/150
# average cost array(0.057387696710531934)
# epoch 4
# minibatch 149/150
# average cost array(0.039429056655054646)
# epoch 4
# minibatch 150/150
# average cost array(0.04654564021897739)
# epoch 5
# minibatch 1/150
# average cost array(0.03028992160219453)
# epoch 5
# minibatch 2/150
# average cost array(0.044955696706032874)
# epoch 5
# minibatch 3/150
# average cost array(0.04276860883780405)
# epoch 5
# minibatch 4/150
# average cost array(0.028928772581327495)
# epoch 5
# minibatch 5/150
# average cost array(0.04765221487679035)
# epoch 5
# minibatch 6/150
# average cost array(0.02912069486536668)
# epoch 5
# minibatch 7/150
# average cost array(0.036136280414475794)
# epoch 5
# minibatch 8/150
# average cost array(0.024480104366576605)
# epoch 5
# minibatch 9/150
# average cost array(0.02966021759331051)
# epoch 5
# minibatch 10/150
# average cost array(0.024421092713252247)
# epoch 5
# minibatch 11/150
# average cost array(0.022855953843628252)
# epoch 5
# minibatch 12/150
# average cost array(0.03210923795157429)
# epoch 5
# minibatch 13/150
# average cost array(0.03114285591829573)
# epoch 5
# minibatch 14/150
# average cost array(0.036871890791961306)
# epoch 5
# minibatch 15/150
# average cost array(0.023754553255435136)
# epoch 5
# minibatch 16/150
# average cost array(0.024606199403321104)
# epoch 5
# minibatch 17/150
# average cost array(0.019229808175679854)
# epoch 5
# minibatch 18/150
# average cost array(0.04331557711642682)
# epoch 5
# minibatch 19/150
# average cost array(0.02669562202315664)
# epoch 5
# minibatch 20/150
# average cost array(0.021475081939701594)
# epoch 5
# minibatch 21/150
# average cost array(0.02312573152112638)
# epoch 5
# minibatch 22/150
# average cost array(0.019216092848999125)
# epoch 5
# minibatch 23/150
# average cost array(0.027835326460364164)
# epoch 5
# minibatch 24/150
# average cost array(0.014425973055186841)
# epoch 5
# minibatch 25/150
# average cost array(0.019997834991266897)
# epoch 5
# minibatch 26/150
# average cost array(0.015031977321896003)
# epoch 5
# minibatch 27/150
# average cost array(0.017568210590683357)
# epoch 5
# minibatch 28/150
# average cost array(0.014902098167909017)
# epoch 5
# minibatch 29/150
# average cost array(0.02096651453473469)
# epoch 5
# minibatch 30/150
# average cost array(0.016070427675305997)
# epoch 5
# minibatch 31/150
# average cost array(0.018025607687448125)
# epoch 5
# minibatch 32/150
# average cost array(0.0238491446913083)
# epoch 5
# minibatch 33/150
# average cost array(0.017654723837765913)
# epoch 5
# minibatch 34/150
# average cost array(0.018389786891810235)
# epoch 5
# minibatch 35/150
# average cost array(0.029737966793449096)
# epoch 5
# minibatch 36/150
# average cost array(0.021879943481563753)
# epoch 5
# minibatch 37/150
# average cost array(0.02835103259085921)
# epoch 5
# minibatch 38/150
# average cost array(0.011608603132557847)
# epoch 5
# minibatch 39/150
# average cost array(0.013524740984864753)
# epoch 5
# minibatch 40/150
# average cost array(0.02491822864095311)
# epoch 5
# minibatch 41/150
# average cost array(0.012214089350684628)
# epoch 5
# minibatch 42/150
# average cost array(0.020498597067263116)
# epoch 5
# minibatch 43/150
# average cost array(0.021192291749993535)
# epoch 5
# minibatch 44/150
# average cost array(0.0392575776909473)
# epoch 5
# minibatch 45/150
# average cost array(0.021066389480498535)
# epoch 5
# minibatch 46/150
# average cost array(0.016233898377694754)
# epoch 5
# minibatch 47/150
# average cost array(0.014164269826946019)
# epoch 5
# minibatch 48/150
# average cost array(0.015287467810710765)
# epoch 5
# minibatch 49/150
# average cost array(0.01806536202795058)
# epoch 5
# minibatch 50/150
# average cost array(0.019854359544084838)
# epoch 5
# minibatch 51/150
# average cost array(0.025279615327684756)
# epoch 5
# minibatch 52/150
# average cost array(0.02084685633685104)
# epoch 5
# minibatch 53/150
# average cost array(0.030762240520041128)
# epoch 5
# minibatch 54/150
# average cost array(0.02481672136778633)
# epoch 5
# minibatch 55/150
# average cost array(0.014106220590612967)
# epoch 5
# minibatch 56/150
# average cost array(0.013919624003987965)
# epoch 5
# minibatch 57/150
# average cost array(0.033557044449666215)
# epoch 5
# minibatch 58/150
# average cost array(0.013575103284460557)
# epoch 5
# minibatch 59/150
# average cost array(0.016145191936149567)
# epoch 5
# minibatch 60/150
# average cost array(0.029517319456493663)
# epoch 5
# minibatch 61/150
# average cost array(0.025986033780811067)
# epoch 5
# minibatch 62/150
# average cost array(0.024383816412452335)
# epoch 5
# minibatch 63/150
# average cost array(0.01235182735044442)
# epoch 5
# minibatch 64/150
# average cost array(0.016323870508626204)
# epoch 5
# minibatch 65/150
# average cost array(0.025271313184073524)
# epoch 5
# minibatch 66/150
# average cost array(0.036439981783043036)
# epoch 5
# minibatch 67/150
# average cost array(0.013475629604268092)
# epoch 5
# minibatch 68/150
# average cost array(0.011998025419373993)
# epoch 5
# minibatch 69/150
# average cost array(0.020879439547824966)
# epoch 5
# minibatch 70/150
# average cost array(0.014521446213278805)
# epoch 5
# minibatch 71/150
# average cost array(0.02537065297308257)
# epoch 5
# minibatch 72/150
# average cost array(0.01828179694158971)
# epoch 5
# minibatch 73/150
# average cost array(0.009183244106859879)
# epoch 5
# minibatch 74/150
# average cost array(0.01578983178757227)
# epoch 5
# minibatch 75/150
# average cost array(0.029172984827590887)
# epoch 5
# minibatch 76/150
# average cost array(0.057565983940680854)
# epoch 5
# minibatch 77/150
# average cost array(0.029629020818586073)
# epoch 5
# minibatch 78/150
# average cost array(0.07752114107466207)
# epoch 5
# minibatch 79/150
# average cost array(0.08477738244863084)
# epoch 5
# minibatch 80/150
# average cost array(0.04206376574341018)
# epoch 5
# minibatch 81/150
# average cost array(0.08573960492869795)
# epoch 5
# minibatch 82/150
# average cost array(0.09422120659893776)
# epoch 5
# minibatch 83/150
# average cost array(0.0513904622769187)
# epoch 5
# minibatch 84/150
# average cost array(0.06945753167636978)
# epoch 5
# minibatch 85/150
# average cost array(0.06519184021805449)
# epoch 5
# minibatch 86/150
# average cost array(0.05711154362507169)
# epoch 5
# minibatch 87/150
# average cost array(0.060056618994332914)
# epoch 5
# minibatch 88/150
# average cost array(0.044049569557209727)
# epoch 5
# minibatch 89/150
# average cost array(0.03897814707326757)
# epoch 5
# minibatch 90/150
# average cost array(0.08551580914667528)
# epoch 5
# minibatch 91/150
# average cost array(0.06846268511882095)
# epoch 5
# minibatch 92/150
# average cost array(0.03769841706176184)
# epoch 5
# minibatch 93/150
# average cost array(0.058565752484492375)
# epoch 5
# minibatch 94/150
# average cost array(0.08430906356917754)
# epoch 5
# minibatch 95/150
# average cost array(0.041950617324255125)
# epoch 5
# minibatch 96/150
# average cost array(0.06413714439576032)
# epoch 5
# minibatch 97/150
# average cost array(0.04378943788005221)
# epoch 5
# minibatch 98/150
# average cost array(0.060469569055079886)
# epoch 5
# minibatch 99/150
# average cost array(0.05339054971315148)
# epoch 5
# minibatch 100/150
# average cost array(0.056709056245517295)
# epoch 5
# minibatch 101/150
# average cost array(0.06930219499522328)
# epoch 5
# minibatch 102/150
# average cost array(0.04736399283560154)
# epoch 5
# minibatch 103/150
# average cost array(0.05174511236579819)
# epoch 5
# minibatch 104/150
# average cost array(0.05843626939038249)
# epoch 5
# minibatch 105/150
# average cost array(0.059864107286608646)
# epoch 5
# minibatch 106/150
# average cost array(0.061976001289790215)
# epoch 5
# minibatch 107/150
# average cost array(0.0381628114171106)
# epoch 5
# minibatch 108/150
# average cost array(0.04512136565397103)
# epoch 5
# minibatch 109/150
# average cost array(0.044685218891403436)
# epoch 5
# minibatch 110/150
# average cost array(0.06918700993955378)
# epoch 5
# minibatch 111/150
# average cost array(0.040746684664458764)
# epoch 5
# minibatch 112/150
# average cost array(0.057857416463246214)
# epoch 5
# minibatch 113/150
# average cost array(0.07198879894367216)
# epoch 5
# minibatch 114/150
# average cost array(0.04831946297276415)
# epoch 5
# minibatch 115/150
# average cost array(0.05804890943912987)
# epoch 5
# minibatch 116/150
# average cost array(0.05126925362237879)
# epoch 5
# minibatch 117/150
# average cost array(0.06613547239056813)
# epoch 5
# minibatch 118/150
# average cost array(0.05792306927051059)
# epoch 5
# minibatch 119/150
# average cost array(0.05812671110802322)
# epoch 5
# minibatch 120/150
# average cost array(0.04296848761625667)
# epoch 5
# minibatch 121/150
# average cost array(0.04949552420613261)
# epoch 5
# minibatch 122/150
# average cost array(0.03277123910239686)
# epoch 5
# minibatch 123/150
# average cost array(0.04296721438393687)
# epoch 5
# minibatch 124/150
# average cost array(0.05643192208228923)
# epoch 5
# minibatch 125/150
# average cost array(0.0655146950379415)
# epoch 5
# minibatch 126/150
# average cost array(0.047402234655978245)
# epoch 5
# minibatch 127/150
# average cost array(0.044924857250987486)
# epoch 5
# minibatch 128/150
# average cost array(0.03496100345067219)
# epoch 5
# minibatch 129/150
# average cost array(0.05205220553560001)
# epoch 5
# minibatch 130/150
# average cost array(0.047637828478653214)
# epoch 5
# minibatch 131/150
# average cost array(0.04704973255169316)
# epoch 5
# minibatch 132/150
# ...
# average cost array(0.03787985167106228)
# epoch 49
# minibatch 62/150
# average cost array(0.022817056214401235)
# epoch 49
# minibatch 63/150
# average cost array(0.016865580515118005)
# epoch 49
# minibatch 64/150
# average cost array(0.019088223288622686)
# epoch 49
# minibatch 65/150
# average cost array(0.025404075052765922)
# epoch 49
# minibatch 66/150
# average cost array(0.03111555150085197)
# epoch 49
# minibatch 67/150
# average cost array(0.017629610558712105)
# epoch 49
# minibatch 68/150
# average cost array(0.019797489440394583)
# epoch 49
# minibatch 69/150
# average cost array(0.029198055849523293)
# epoch 49
# minibatch 70/150
# average cost array(0.015812295728412668)
# epoch 49
# minibatch 71/150
# average cost array(0.02630941712477547)
# epoch 49
# minibatch 72/150
# average cost array(0.019929774370494615)
# epoch 49
# minibatch 73/150
# average cost array(0.013204958560253614)
# epoch 49
# minibatch 74/150
# average cost array(0.026435684070178007)
# epoch 49
# minibatch 75/150
# average cost array(0.03171189790301061)
# epoch 49
# minibatch 76/150
# average cost array(0.049132776749592676)
# epoch 49
# minibatch 77/150
# average cost array(0.025482065647628692)
# epoch 49
# minibatch 78/150
# average cost array(0.04858360696904572)
# epoch 49
# minibatch 79/150
# average cost array(0.05622358278870947)
# epoch 49
# minibatch 80/150
# average cost array(0.03935624772255942)
# epoch 49
# minibatch 81/150
# average cost array(0.05873812376570882)
# epoch 49
# minibatch 82/150
# average cost array(0.06288460506224515)
# epoch 49
# minibatch 83/150
# average cost array(0.03892843588237399)
# epoch 49
# minibatch 84/150
# average cost array(0.06443092912452163)
# epoch 49
# minibatch 85/150
# average cost array(0.05974678991125043)
# epoch 49
# minibatch 86/150
# average cost array(0.05642591092845943)
# epoch 49
# minibatch 87/150
# average cost array(0.045837196952081306)
# epoch 49
# minibatch 88/150
# average cost array(0.03840388122154478)
# epoch 49
# minibatch 89/150
# average cost array(0.03376232183919173)
# epoch 49
# minibatch 90/150
# average cost array(0.07433708616787046)
# epoch 49
# minibatch 91/150
# average cost array(0.06894639378893908)
# epoch 49
# minibatch 92/150
# average cost array(0.03814862038973907)
# epoch 49
# minibatch 93/150
# average cost array(0.06043101924518683)
# epoch 49
# minibatch 94/150
# average cost array(0.07639265584484543)
# epoch 49
# minibatch 95/150
# average cost array(0.04087307018480575)
# epoch 49
# minibatch 96/150
# average cost array(0.053016820588265866)
# epoch 49
# minibatch 97/150
# average cost array(0.04551095010066063)
# epoch 49
# minibatch 98/150
# average cost array(0.05785635017511033)
# epoch 49
# minibatch 99/150
# average cost array(0.0577836065557968)
# epoch 49
# minibatch 100/150
# average cost array(0.06202967694695223)
# epoch 49
# minibatch 101/150
# average cost array(0.06573750924324193)
# epoch 49
# minibatch 102/150
# average cost array(0.043197791996459414)
# epoch 49
# minibatch 103/150
# average cost array(0.053313324419341536)
# epoch 49
# minibatch 104/150
# average cost array(0.06344854147076381)
# epoch 49
# minibatch 105/150
# average cost array(0.05898526876678674)
# epoch 49
# minibatch 106/150
# average cost array(0.061040783866192515)
# epoch 49
# minibatch 107/150
# average cost array(0.0365571908022831)
# epoch 49
# minibatch 108/150
# average cost array(0.03855342382066155)
# epoch 49
# minibatch 109/150
# average cost array(0.04704924974566819)
# epoch 49
# minibatch 110/150
# average cost array(0.06642413336865245)
# epoch 49
# minibatch 111/150
# average cost array(0.037091852083281)
# epoch 49
# minibatch 112/150
# average cost array(0.05981261541365771)
# epoch 49
# minibatch 113/150
# average cost array(0.07523825078123669)
# epoch 49
# minibatch 114/150
# average cost array(0.05058225744251317)
# epoch 49
# minibatch 115/150
# average cost array(0.05532426007968886)
# epoch 49
# minibatch 116/150
# average cost array(0.048804195683578064)
# epoch 49
# minibatch 117/150
# average cost array(0.08124045285641289)
# epoch 49
# minibatch 118/150
# average cost array(0.06090040624480821)
# epoch 49
# minibatch 119/150
# average cost array(0.04953328376004406)
# epoch 49
# minibatch 120/150
# average cost array(0.05126523262796308)
# epoch 49
# minibatch 121/150
# average cost array(0.053969646157448634)
# epoch 49
# minibatch 122/150
# average cost array(0.032178725256465396)
# epoch 49
# minibatch 123/150
# average cost array(0.04695472312403648)
# epoch 49
# minibatch 124/150
# average cost array(0.05938492885528114)
# epoch 49
# minibatch 125/150
# average cost array(0.06892149814433698)
# epoch 49
# minibatch 126/150
# average cost array(0.05486699098848975)
# epoch 49
# minibatch 127/150
# average cost array(0.05003800121879196)
# epoch 49
# minibatch 128/150
# average cost array(0.030388625097523575)
# epoch 49
# minibatch 129/150
# average cost array(0.06131525040435837)
# epoch 49
# minibatch 130/150
# average cost array(0.04059054219493776)
# epoch 49
# minibatch 131/150
# average cost array(0.053989401519439165)
# epoch 49
# minibatch 132/150
# average cost array(0.06752724378238653)
# epoch 49
# minibatch 133/150
# average cost array(0.059703297266114994)
# epoch 49
# minibatch 134/150
# average cost array(0.042998796449899894)
# epoch 49
# minibatch 135/150
# average cost array(0.04597825828673015)
# epoch 49
# minibatch 136/150
# average cost array(0.03340548717224928)
# epoch 49
# minibatch 137/150
# average cost array(0.06761276776935583)
# epoch 49
# minibatch 138/150
# average cost array(0.03978248431470151)
# epoch 49
# minibatch 139/150
# average cost array(0.06395824335650287)
# epoch 49
# minibatch 140/150
# average cost array(0.058805861552778484)
# epoch 49
# minibatch 141/150
# average cost array(0.04952277419559209)
# epoch 49
# minibatch 142/150
# average cost array(0.06046519462023645)
# epoch 49
# minibatch 143/150
# average cost array(0.03522206143513602)
# epoch 49
# minibatch 144/150
# average cost array(0.05244408022846804)
# epoch 49
# minibatch 145/150
# average cost array(0.055751248850319124)
# epoch 49
# minibatch 146/150
# average cost array(0.050900321692199046)
# epoch 49
# minibatch 147/150
# average cost array(0.051779200461581076)
# epoch 49
# minibatch 148/150
# average cost array(0.05223373318203824)
# epoch 49
# minibatch 149/150
# average cost array(0.03635680064349071)
# epoch 49
# minibatch 150/150
# average cost array(0.04281840810038947)
# epoch 50
# minibatch 1/150
# average cost array(0.019305797743766978)
# epoch 50
# minibatch 2/150
# average cost array(0.029120965657104193)
# epoch 50
# minibatch 3/150
# average cost array(0.028077309044514182)
# epoch 50
# minibatch 4/150
# average cost array(0.01269086460856667)
# epoch 50
# minibatch 5/150
# average cost array(0.03645604171854876)
# epoch 50
# minibatch 6/150
# average cost array(0.018858939244743914)
# epoch 50
# minibatch 7/150
# average cost array(0.027051528106126904)
# epoch 50
# minibatch 8/150
# average cost array(0.017140482520595322)
# epoch 50
# minibatch 9/150
# average cost array(0.02503420752714867)
# epoch 50
# minibatch 10/150
# average cost array(0.01844057375757122)
# epoch 50
# minibatch 11/150
# average cost array(0.020827006009864278)
# epoch 50
# minibatch 12/150
# average cost array(0.03207513606539032)
# epoch 50
# minibatch 13/150
# average cost array(0.022973881118446178)
# epoch 50
# minibatch 14/150
# average cost array(0.034825856592996765)
# epoch 50
# minibatch 15/150
# average cost array(0.02239297401440036)
# epoch 50
# minibatch 16/150
# average cost array(0.02930959169607067)
# epoch 50
# minibatch 17/150
# average cost array(0.020348048907191295)
# epoch 50
# minibatch 18/150
# average cost array(0.043478450890910084)
# epoch 50
# minibatch 19/150
# average cost array(0.029708706966174874)
# epoch 50
# minibatch 20/150
# average cost array(0.021159017853489285)
# epoch 50
# minibatch 21/150
# average cost array(0.021520078790551858)
# epoch 50
# minibatch 22/150
# average cost array(0.02166713183568498)
# epoch 50
# minibatch 23/150
# average cost array(0.03235684924229327)
# epoch 50
# minibatch 24/150
# average cost array(0.015319059401945034)
# epoch 50
# minibatch 25/150
# average cost array(0.020935592724837367)
# epoch 50
# minibatch 26/150
# average cost array(0.02018300102889272)
# epoch 50
# minibatch 27/150
# average cost array(0.01683095185088282)
# epoch 50
# minibatch 28/150
# average cost array(0.019912856178883886)
# epoch 50
# minibatch 29/150
# average cost array(0.018532088458764334)
# epoch 50
# minibatch 30/150
# average cost array(0.019958675338998096)
# epoch 50
# minibatch 31/150
# average cost array(0.016309673812691973)
# epoch 50
# minibatch 32/150
# average cost array(0.02868295181670063)
# epoch 50
# minibatch 33/150
# average cost array(0.023641863489294347)
# epoch 50
# minibatch 34/150
# average cost array(0.0197480357495002)
# epoch 50
# minibatch 35/150
# average cost array(0.02820930542829831)
# epoch 50
# minibatch 36/150
# average cost array(0.02718384571429127)
# epoch 50
# minibatch 37/150
# average cost array(0.03947054178795653)
# epoch 50
# minibatch 38/150
# average cost array(0.014181455896373336)
# epoch 50
# minibatch 39/150
# average cost array(0.02172412870666695)
# epoch 50
# minibatch 40/150
# average cost array(0.02809910011620987)
# epoch 50
# minibatch 41/150
# average cost array(0.015505761736576145)
# epoch 50
# minibatch 42/150
# average cost array(0.029788657773211158)
# epoch 50
# minibatch 43/150
# average cost array(0.028811312444790377)
# epoch 50
# minibatch 44/150
# average cost array(0.04220145802020917)
# epoch 50
# minibatch 45/150
# average cost array(0.01858658917343189)
# epoch 50
# minibatch 46/150
# average cost array(0.020543446323733564)
# epoch 50
# minibatch 47/150
# average cost array(0.022740019850905235)
# epoch 50
# minibatch 48/150
# average cost array(0.02516605648190885)
# epoch 50
# minibatch 49/150
# average cost array(0.020225503728788334)
# epoch 50
# minibatch 50/150
# average cost array(0.025557668842053943)
# epoch 50
# minibatch 51/150
# average cost array(0.021231412621755895)
# epoch 50
# minibatch 52/150
# average cost array(0.0263760344456958)
# epoch 50
# minibatch 53/150
# average cost array(0.02708460063228032)
# epoch 50
# minibatch 54/150
# average cost array(0.029971026707765646)
# epoch 50
# minibatch 55/150
# average cost array(0.012807762109276779)
# epoch 50
# minibatch 56/150
# average cost array(0.01827226197800029)
# epoch 50
# minibatch 57/150
# average cost array(0.03832518407182402)
# epoch 50
# minibatch 58/150
# average cost array(0.01170309888128384)
# epoch 50
# minibatch 59/150
# average cost array(0.026655549612641844)
# epoch 50
# minibatch 60/150
# average cost array(0.029593956296717433)
# epoch 50
# minibatch 61/150
# average cost array(0.038179479876246925)
# epoch 50
# minibatch 62/150
# average cost array(0.023017215238055506)
# epoch 50
# minibatch 63/150
# average cost array(0.01686648392731678)
# epoch 50
# minibatch 64/150
# average cost array(0.01921017892268862)
# epoch 50
# minibatch 65/150
# average cost array(0.025543860555433662)
# epoch 50
# minibatch 66/150
# average cost array(0.031102965255710914)
# epoch 50
# minibatch 67/150
# average cost array(0.017633727435078773)
# epoch 50
# minibatch 68/150
# average cost array(0.019855486287516284)
# epoch 50
# minibatch 69/150
# average cost array(0.02957892959124036)
# epoch 50
# minibatch 70/150
# average cost array(0.015713517060047807)
# epoch 50
# minibatch 71/150
# average cost array(0.026291683267914524)
# epoch 50
# minibatch 72/150
# average cost array(0.020060400731080293)
# epoch 50
# minibatch 73/150
# average cost array(0.013240320854404564)
# epoch 50
# minibatch 74/150
# average cost array(0.02648354371812699)
# epoch 50
# minibatch 75/150
# average cost array(0.03171116329172026)
# epoch 50
# minibatch 76/150
# average cost array(0.04875154443868142)
# epoch 50
# minibatch 77/150
# average cost array(0.025066883382948612)
# epoch 50
# minibatch 78/150
# average cost array(0.04788264735207554)
# epoch 50
# minibatch 79/150
# average cost array(0.05540150069516987)
# epoch 50
# minibatch 80/150
# average cost array(0.03925324170769133)
# epoch 50
# minibatch 81/150
# average cost array(0.05785036775043582)
# epoch 50
# minibatch 82/150
# average cost array(0.06158388512429316)
# epoch 50
# minibatch 83/150
# average cost array(0.038549948147322446)
# epoch 50
# minibatch 84/150
# average cost array(0.06382321515987888)
# epoch 50
# minibatch 85/150
# average cost array(0.059067673837628044)
# epoch 50
# minibatch 86/150
# average cost array(0.055583281772678995)
# epoch 50
# minibatch 87/150
# average cost array(0.04532831713414566)
# epoch 50
# minibatch 88/150
# average cost array(0.03773009293114607)
# epoch 50
# minibatch 89/150
# average cost array(0.03344458148607324)
# epoch 50
# minibatch 90/150
# average cost array(0.07363926168935153)
# epoch 50
# minibatch 91/150
# average cost array(0.06848034362444821)
# epoch 50
# minibatch 92/150
# average cost array(0.037811512661644495)
# epoch 50
# minibatch 93/150
# average cost array(0.05982796125851003)
# epoch 50
# minibatch 94/150
# average cost array(0.07552310491342587)
# epoch 50
# minibatch 95/150
# average cost array(0.04045434952958651)
# epoch 50
# minibatch 96/150
# average cost array(0.052400793220880815)
# epoch 50
# minibatch 97/150
# average cost array(0.04520210651670107)
# epoch 50
# minibatch 98/150
# average cost array(0.05719100446894596)
# epoch 50
# minibatch 99/150
# average cost array(0.05719502427625027)
# epoch 50
# minibatch 100/150
# average cost array(0.06171092382436087)
# epoch 50
# minibatch 101/150
# average cost array(0.06520284939197786)
# epoch 50
# minibatch 102/150
# average cost array(0.04301771753951471)
# epoch 50
# minibatch 103/150
# average cost array(0.052426738828111955)
# epoch 50
# minibatch 104/150
# average cost array(0.06252866095354256)
# epoch 50
# minibatch 105/150
# average cost array(0.058524839462488154)
# epoch 50
# minibatch 106/150
# average cost array(0.0602119768135994)
# epoch 50
# minibatch 107/150
# average cost array(0.03633358697543162)
# epoch 50
# minibatch 108/150
# average cost array(0.038088952017067614)
# epoch 50
# minibatch 109/150
# average cost array(0.04649859289033202)
# epoch 50
# minibatch 110/150
# average cost array(0.06574727222924)
# epoch 50
# minibatch 111/150
# average cost array(0.03648359928093521)
# epoch 50
# minibatch 112/150
# average cost array(0.05875549269666901)
# epoch 50
# minibatch 113/150
# average cost array(0.07418454029558644)
# epoch 50
# minibatch 114/150
# average cost array(0.04991170338484187)
# epoch 50
# minibatch 115/150
# average cost array(0.054516138194126575)
# epoch 50
# minibatch 116/150
# average cost array(0.048036964381275395)
# epoch 50
# minibatch 117/150
# average cost array(0.0799842173728751)
# epoch 50
# minibatch 118/150
# average cost array(0.059882936522495676)
# epoch 50
# minibatch 119/150
# average cost array(0.04908367769795485)
# epoch 50
# minibatch 120/150
# average cost array(0.05067744383835297)
# epoch 50
# minibatch 121/150
# average cost array(0.05335888676839712)
# epoch 50
# minibatch 122/150
# average cost array(0.03192003028568009)
# epoch 50
# minibatch 123/150
# average cost array(0.046477346511208724)
# epoch 50
# minibatch 124/150
# average cost array(0.05896644066193564)
# epoch 50
# minibatch 125/150
# average cost array(0.06799005863218292)
# epoch 50
# minibatch 126/150
# average cost array(0.054842282850352655)
# epoch 50
# minibatch 127/150
# average cost array(0.049699678588742004)
# epoch 50
# minibatch 128/150
# average cost array(0.030060581852042835)
# epoch 50
# minibatch 129/150
# average cost array(0.06051950928595725)
# epoch 50
# minibatch 130/150
# average cost array(0.04030923979121397)
# epoch 50
# minibatch 131/150
# average cost array(0.05351192112002963)
# epoch 50
# minibatch 132/150
# average cost array(0.06678271950452845)
# epoch 50
# minibatch 133/150
# average cost array(0.05887626804001739)
# epoch 50
# minibatch 134/150
# average cost array(0.042613434456672775)
# epoch 50
# minibatch 135/150
# average cost array(0.04536248890045251)
# epoch 50
# minibatch 136/150
# average cost array(0.033083876622363284)
# epoch 50
# minibatch 137/150
# average cost array(0.06705831685396575)
# epoch 50
# minibatch 138/150
# average cost array(0.03933742991017311)
# epoch 50
# minibatch 139/150
# average cost array(0.06317968989093745)
# epoch 50
# minibatch 140/150
# average cost array(0.05840265294708056)
# epoch 50
# minibatch 141/150
# average cost array(0.049379158323986)
# epoch 50
# minibatch 142/150
# average cost array(0.05999042096045045)
# epoch 50
# minibatch 143/150
# average cost array(0.03487398814470087)
# epoch 50
# minibatch 144/150
# average cost array(0.05178506381506907)
# epoch 50
# minibatch 145/150
# average cost array(0.055031746647488014)
# epoch 50
# minibatch 146/150
# average cost array(0.05066142871892877)
# epoch 50
# minibatch 147/150
# average cost array(0.05124567175064178)
# epoch 50
# minibatch 148/150
# average cost array(0.05170552730859024)
# epoch 50
# minibatch 149/150
# average cost array(0.035925319443864664)
# epoch 50
# minibatch 150/150
# average cost array(0.042359607289774476)
# testing

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1)
ax.plot(a1, v1, 'bo', lw=5, alpha=0.6, label='g = 1')
ax.plot(a3, v3, 'go', lw=5, alpha=0.6, label='g = 3')
ax.plot(a15, v15, 'ro', lw=5, alpha=0.6, label='g = 15')
ax.axis([0, 1, 0, 1])
ax.set_xlabel("Analytic")
ax.set_ylabel("Variational")

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1)
ax.plot(a1, nn1, 'bo', lw=5, alpha=0.6, label='g = 1')
ax.plot(a3, nn3, 'go', lw=5, alpha=0.6, label='g = 3')
ax.plot(a15, nn15, 'ro', lw=5, alpha=0.6, label='g = 15')
ax.axis([0, 1, 0, 1])
ax.set_xlabel("Analytic")
ax.set_ylabel("Neural Net")
