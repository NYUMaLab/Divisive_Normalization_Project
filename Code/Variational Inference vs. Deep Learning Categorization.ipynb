# %%
import numpy as np

nneuron = 41

sprefs = np.linspace(-60, 60, nneuron)

sig0_sq      = float(3**2)
sig1_sq      = float(12**2)
sigtc_sq     = float(10**2)
ndatapergain = 3000
mu = 0

tau_0 = 1/sig0_sq
tau_1 = 1/sig1_sq
d_tau = tau_0 - tau_1
sig_tc = 10
min_angle = -60
max_angle = 60
step = 3
prefact = np.sqrt(tau_0/tau_1)

def generate_popcode_data(ndatapergain, nneuron, sig0_sq, sig1_sq, sigtc_sq, gain, noise):
    s_s0 = np.random.normal(mu, np.sqrt(sig0_sq), ndatapergain/2)
    s_s1 = np.random.normal(mu, np.sqrt(sig1_sq), ndatapergain/2)
    s = np.concatenate((s_s0, s_s1), axis=1)
    sprefs_data = np.tile(sprefs, (ndatapergain, 1))
    r = gain * np.exp(-np.square((np.transpose(np.tile(s, (nneuron, 1))) - sprefs_data))/(2 * sigtc_sq))
    if noise == "poisson":
        r = np.random.poisson(r) + 0.0
    ar = np.sum(r, axis=1)/sigtc_sq
    br = np.sum(r*sprefs_data, axis=1)/sigtc_sq
    
    term_1 = (1 + sig1_sq * ar) / (1 + sig0_sq  * ar)
    term_2_num = (sig1_sq - sig0_sq) * br**2
    term_2_denom = 2 * (1 + sig0_sq  * ar) * (1 + sig1_sq * ar)
    xpnt_a = .5 * np.log(term_1) - term_2_num/term_2_denom
    p = 1/(1 + np.exp(-xpnt_a))
    return r, p, ar, br

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

def run_variational_inference(ar, br):
    #variational inference
    p = np.random.random_sample()
    tau = np.random.random_sample() * .5
    eta = br
    
    prev_tau = 0
    prev_p = 0
    conv = 0
    while prev_tau != tau and prev_p != p:
    #while round(prev_tau, 3) != round(tau, 3) and round(prev_p, 3) != round(p, 3):
        prev_tau = tau
        prev_p = p
        conv += 1
        tau = ar + (tau_0 - (d_tau * p))
        xpnt = (((eta/tau)**2 + 1/tau) * d_tau)/2
        p = 1/(1 + prefact * np.exp(-xpnt))
        #round
        tau = round(tau, 3)
        p = round(p, 3)
    conv -= 1
    
    return 1 - p, conv

r1, p1, ar1, br1 = generate_popcode_data(ndatapergain, nneuron, sig0_sq, sig1_sq, sigtc_sq, 1, "poisson")
r3, p3, ar3, br3 = generate_popcode_data(ndatapergain, nneuron, sig0_sq, sig1_sq, sigtc_sq, 3, "poisson")
r15, p15, ar15, br15 = generate_popcode_data(ndatapergain, nneuron, sig0_sq, sig1_sq, sigtc_sq, 15, "poisson")
a1 = p1
a3 = p3
a15 = p15
v1 = [0] * len(a1)
v3 = [0] * len(a3)
v15 = [0] * len(a15)
for i in range(len(a1)):
    v1[i], _ = run_variational_inference(ar1[i], br1[i])
    v3[i], _ = run_variational_inference(ar3[i], br3[i])
    v15[i], _ = run_variational_inference(ar15[i], br15[i])

# %%
"""
Multilayer ReLU net
"""

import os
import sys
import time

import numpy

import theano
import theano.tensor as T

def relu(x):
    return theano.tensor.switch(x<0, 0, x)

class HiddenLayer(object):
    def __init__(self, rng, input, n_in, n_out, W=None, b=None,
                 activation=relu):
        """
        Typical hidden layer of a MLP: units are fully-connected and have
        sigmoidal activation function. Weight matrix W is of shape (n_in,n_out)
        and the bias vector b is of shape (n_out,).

        NOTE : The nonlinearity used here is tanh

        Hidden unit activation is given by: tanh(dot(input,W) + b)

        :type rng: numpy.random.RandomState
        :param rng: a random number generator used to initialize weights

        :type input: theano.tensor.dmatrix
        :param input: a symbolic tensor of shape (n_examples, n_in)

        :type n_in: int
        :param n_in: dimensionality of input

        :type n_out: int
        :param n_out: number of hidden units

        :type activation: theano.Op or function
        :param activation: Non linearity to be applied in the hidden
                           layer
        """
        self.input = input
        # end-snippet-1

        # `W` is initialized with `W_values` which is uniformely sampled
        # from sqrt(-6./(n_in+n_hidden)) and sqrt(6./(n_in+n_hidden))
        # for tanh activation function
        # the output of uniform if converted using asarray to dtype
        # theano.config.floatX so that the code is runable on GPU
        # Note : optimal initialization of weights is dependent on the
        #        activation function used (among other things).
        #        For example, results presented in [Xavier10] suggest that you
        #        should use 4 times larger initial weights for sigmoid
        #        compared to tanh
        #        We have no info for other function, so we use the same as
        #        tanh.
        if W is None:
            """
            W_values = numpy.asarray(
                rng.uniform(
                    low=-numpy.sqrt(6. / (n_in + n_out)),
                    high=numpy.sqrt(6. / (n_in + n_out)),
                    size=(n_in, n_out)
                ),
                dtype=theano.config.floatX
            )
            """
            W_values = .05 * numpy.random.randn(n_in, n_out)
            #W_values = .1 * numpy.random.randn(n_in, n_out)
            
            """
            if activation == theano.tensor.nnet.sigmoid:
                W_values *= 4
            """

            W = theano.shared(value=W_values, name='W', borrow=True)

        if b is None:
            b_values = numpy.zeros((n_out,), dtype=theano.config.floatX)
            b = theano.shared(value=b_values, name='b', borrow=True)

        self.W = W
        self.b = b

        lin_output = T.dot(input, self.W) + self.b
        self.output = (
            lin_output if activation is None
            else activation(lin_output)
        )
        # parameters of the model
        self.params = [self.W, self.b]

class MLP(object):


    def __init__(self, rng, input, n_in, n_hidden, n_out):
        """Initialize the parameters for the multilayer perceptron

        :type rng: numpy.random.RandomState
        :param rng: a random number generator used to initialize weights

        :type input: theano.tensor.TensorType
        :param input: symbolic variable that describes the input of the
        architecture (one minibatch)

        :type n_in: int
        :param n_in: number of input units, the dimension of the space in
        which the datapoints lie

        :type n_hidden: int
        :param n_hidden: number of hidden units

        :type n_out: int
        :param n_out: number of output units, the dimension of the space in
        which the labels lie

        """

        # Since we are dealing with a one hidden layer MLP, this will translate
        # into a HiddenLayer with a tanh activation function connected to the
        # LogisticRegression layer; the activation function can be replaced by
        # sigmoid or any other nonlinear function
        self.hiddenLayer1 = HiddenLayer(
            rng=rng,
            input=input,
            n_in=n_in,
            n_out=n_hidden,
            activation=relu
        )
        
        self.hiddenLayer2 = HiddenLayer(
            rng=rng,
            input=self.hiddenLayer1.output,
            n_in=n_hidden,
            n_out=n_out,
            activation=relu
        )
        
        self.y_pred = self.hiddenLayer2.output
        
        # the parameters of the model are the parameters of the two layers it is made out of
        self.params = self.hiddenLayer1.params + self.hiddenLayer2.params
        
    def mse(self, y):
        # error between output and target
        return T.mean((self.y_pred.T - y) ** 2)

def shared_dataset(data_xy, borrow=True):
        """ Function that loads the dataset into shared variables

        The reason we store our dataset in shared variables is to allow
        Theano to copy it into the GPU memory (when code is run on GPU).
        Since copying data into the GPU is slow, copying a minibatch everytime
        is needed (the default behaviour if the data is not in a shared
        variable) would lead to a large decrease in performance.
        """
        data_x, data_y, _, _ = data_xy
        shared_x = theano.shared(numpy.asarray(data_x,
                                               dtype='float32'),
                                 borrow=borrow)
        shared_y = theano.shared(numpy.asarray(data_y,
                                               dtype='float32'),
                                 borrow=borrow)
        # When storing data on the GPU it has to be stored as floats
        # therefore we will store the labels as ``floatX`` as well
        # (``shared_y`` does exactly that). But during our computations
        # we need them as ints (we use labels as index, and if they are
        # floats it doesn't make sense) therefore instead of returning
        # ``shared_y`` we will have to cast it to int. This little hack
        # lets ous get around this issue
        return shared_x, shared_y

def train_nn(dataset, n_hidden=2, learning_rate=0.01, n_epochs=10, batch_size=20, test_data=None):
    """
    Demonstrate stochastic gradient descent optimization for a multilayer
    perceptron

    This is demonstrated on MNIST.

    :type learning_rate: float
    :param learning_rate: learning rate used (factor for the stochastic
    gradient

    :type n_epochs: int
    :param n_epochs: maximal number of epochs to run the optimizer

    :type dataset: string
    :param dataset: the path of the MNIST dataset file from
                 http://www.iro.umontreal.ca/~lisa/deep/data/mnist/mnist.pkl.gz


   """
    train_set_x, train_set_y = shared_dataset(dataset)

    # compute number of minibatches for training, validation and testing
    n_train_batches = train_set_x.get_value(borrow=True).shape[0] / batch_size
    
    test_batch_size = 1
    
    ######################
    # BUILD ACTUAL MODEL #
    ######################
    print '... building the model'

    # allocate symbolic variables for the data
    index = T.lscalar()  # index to a [mini]batch
    x = T.fmatrix('x')   # input data from visual neurons
    y = T.fvector('y')  # posterior

    rng = numpy.random.RandomState(1234)

    # construct the MLP class
    nn = MLP(
        rng=rng,
        input=x,
        n_in=41,
        n_hidden=n_hidden,
        n_out=1
    )

    # the cost we minimize during training is the mean squared error; cost is expressed
    # here symbolically
    cost = nn.mse(y)

    # compute the gradient of cost with respect to theta (sotred in params)
    # the resulting gradients will be stored in a list gparams
    gparams = [T.grad(cost, param) for param in nn.params]

    # specify how to update the parameters of the model as a list of
    # (variable, update expression) pairs

    # given two list the zip A = [a1, a2, a3, a4] and B = [b1, b2, b3, b4] of
    # same length, zip generates a list C of same size, where each element
    # is a pair formed from the two lists :
    #    C = [(a1, b1), (a2, b2), (a3, b3), (a4, b4)]
    updates = [
        (param, param - learning_rate * gparam)
        for param, gparam in zip(nn.params, gparams)
    ]

    # compiling a Theano function `train_model` that returns the cost, but
    # in the same time updates the parameter of the model based on the rules
    # defined in `updates`
    train_model = theano.function(
        inputs=[index],
        outputs=cost,
        updates=updates,
        givens={
            x: train_set_x[index * batch_size: (index + 1) * batch_size],
            y: train_set_y[index * batch_size: (index + 1) * batch_size]
        }
    )

    ###############
    # TRAIN MODEL #
    ###############
    print '... training'

    start_time = time.clock()

    epoch = 0
    done_looping = False

    while (epoch < n_epochs) and (not done_looping):
        epoch = epoch + 1
        for minibatch_index in xrange(n_train_batches):
            
            minibatch_avg_cost = train_model(minibatch_index)
            
            print "epoch " + repr(epoch)
            print "minibatch " + repr(minibatch_index + 1) + "/" + repr(n_train_batches)
            print "average cost " + repr(minibatch_avg_cost)

    end_time = time.clock()

    print 'testing'
    test_batch_size = 1
    test_set_x, test_set_y = shared_dataset(test_data)
    test_model = theano.function(
        inputs=[index],
        outputs=nn.y_pred,
        givens={
            x: test_set_x[index * test_batch_size: (index + 1) * test_batch_size]
        },
    )
    
    true_ys = test_set_y.get_value()
    pred_ys = numpy.zeros(len(true_ys))
    for i in range(len(true_ys)):
        pred_ys[i] = test_model(i)
    
    return pred_ys, true_ys

train_data1 = generate_popcode_data(ndatapergain, nneuron, sig0_sq, sig1_sq, sigtc_sq, 1, "poisson")
train_data3 = generate_popcode_data(ndatapergain, nneuron, sig0_sq, sig1_sq, sigtc_sq, 3, "poisson")
train_data15 = generate_popcode_data(ndatapergain, nneuron, sig0_sq, sig1_sq, sigtc_sq, 15, "poisson")
nn1, _ = train_nn(train_data1, n_hidden=8, learning_rate=.01, n_epochs=50, test_data=(r1, p1, ar1, br1))
nn3, _ = train_nn(train_data3, n_hidden=8, learning_rate=.01, n_epochs=50, test_data=(r3, p3, ar3, br3))
nn15, _ = train_nn(train_data15, n_hidden=8, learning_rate=.01, n_epochs=50, test_data=(r15, p15, ar15, br15))
# Out:
# ... building the model
# ... training
# epoch 1
# minibatch 1/150
# average cost array(0.4075134803847947)
# epoch 1
# minibatch 2/150
# average cost array(0.45083504774278466)
# epoch 1
# minibatch 3/150
# average cost array(0.4141627126162993)
# epoch 1
# minibatch 4/150
# average cost array(0.37971471104814275)
# epoch 1
# minibatch 5/150
# average cost array(0.4138321206960784)
# epoch 1
# minibatch 6/150
# average cost array(0.41499070679467376)
# epoch 1
# minibatch 7/150
# average cost array(0.3949481991195306)
# epoch 1
# minibatch 8/150
# average cost array(0.3522511523278967)
# epoch 1
# minibatch 9/150
# average cost array(0.3337662357316807)
# epoch 1
# minibatch 10/150
# average cost array(0.3038600767569902)
# epoch 1
# minibatch 11/150
# average cost array(0.3226076721079326)
# epoch 1
# minibatch 12/150
# average cost array(0.3166001156529015)
# epoch 1
# minibatch 13/150
# average cost array(0.33957074379569063)
# epoch 1
# minibatch 14/150
# average cost array(0.26062234041945026)
# epoch 1
# minibatch 15/150
# average cost array(0.23952848729372)
# epoch 1
# minibatch 16/150
# average cost array(0.2626475101038563)
# epoch 1
# minibatch 17/150
# average cost array(0.2327754479572671)
# epoch 1
# minibatch 18/150
# average cost array(0.20885170872651324)
# epoch 1
# minibatch 19/150
# average cost array(0.22880063131477243)
# epoch 1
# minibatch 20/150
# average cost array(0.1766401611409916)
# epoch 1
# minibatch 21/150
# average cost array(0.18546581102552845)
# epoch 1
# minibatch 22/150
# average cost array(0.1934431773447373)
# epoch 1
# minibatch 23/150
# average cost array(0.18552672114078803)
# epoch 1
# minibatch 24/150
# average cost array(0.15701601755457456)
# epoch 1
# minibatch 25/150
# average cost array(0.14336239745140622)
# epoch 1
# minibatch 26/150
# average cost array(0.1668906590404929)
# epoch 1
# minibatch 27/150
# average cost array(0.16515126114566134)
# epoch 1
# minibatch 28/150
# average cost array(0.15420528866581334)
# epoch 1
# minibatch 29/150
# average cost array(0.16329104871789724)
# epoch 1
# minibatch 30/150
# average cost array(0.14432171579372904)
# epoch 1
# minibatch 31/150
# average cost array(0.12694786911854886)
# epoch 1
# minibatch 32/150
# average cost array(0.12179724921064043)
# epoch 1
# minibatch 33/150
# average cost array(0.11387161160273777)
# epoch 1
# minibatch 34/150
# average cost array(0.121162486836045)
# epoch 1
# minibatch 35/150
# average cost array(0.13453370670011444)
# epoch 1
# minibatch 36/150
# average cost array(0.09462928424968578)
# epoch 1
# minibatch 37/150
# average cost array(0.11509207670310044)
# epoch 1
# minibatch 38/150
# average cost array(0.09920607157443954)
# epoch 1
# minibatch 39/150
# average cost array(0.10102974455138602)
# epoch 1
# minibatch 40/150
# average cost array(0.11371023677175651)
# epoch 1
# minibatch 41/150
# average cost array(0.07525485168711503)
# epoch 1
# minibatch 42/150
# average cost array(0.07956639621298885)
# epoch 1
# minibatch 43/150
# average cost array(0.08348158440648903)
# epoch 1
# minibatch 44/150
# average cost array(0.07126613045699244)
# epoch 1
# minibatch 45/150
# average cost array(0.07212867755000264)
# epoch 1
# minibatch 46/150
# average cost array(0.07454145346434551)
# epoch 1
# minibatch 47/150
# average cost array(0.06887513479917803)
# epoch 1
# minibatch 48/150
# average cost array(0.06692272745710427)
# epoch 1
# minibatch 49/150
# average cost array(0.06462834271499734)
# epoch 1
# minibatch 50/150
# average cost array(0.06681525495567209)
# epoch 1
# minibatch 51/150
# average cost array(0.0652778908117054)
# epoch 1
# minibatch 52/150
# average cost array(0.06683634800352997)
# epoch 1
# minibatch 53/150
# average cost array(0.05218393664090537)
# epoch 1
# minibatch 54/150
# average cost array(0.06468957626960584)
# epoch 1
# minibatch 55/150
# average cost array(0.05046417353976758)
# epoch 1
# minibatch 56/150
# average cost array(0.0467834972752965)
# epoch 1
# minibatch 57/150
# average cost array(0.045681151630199354)
# epoch 1
# minibatch 58/150
# average cost array(0.0425550267274932)
# epoch 1
# minibatch 59/150
# average cost array(0.038880490914858935)
# epoch 1
# minibatch 60/150
# average cost array(0.0514392441049553)
# epoch 1
# minibatch 61/150
# average cost array(0.027923674964819324)
# epoch 1
# minibatch 62/150
# average cost array(0.0319108977663697)
# epoch 1
# minibatch 63/150
# average cost array(0.036250085103318265)
# epoch 1
# minibatch 64/150
# average cost array(0.037524413174102565)
# epoch 1
# minibatch 65/150
# average cost array(0.0389412148781252)
# epoch 1
# minibatch 66/150
# average cost array(0.03944623710098801)
# epoch 1
# minibatch 67/150
# average cost array(0.037560705059585274)
# epoch 1
# minibatch 68/150
# average cost array(0.0319923383390886)
# epoch 1
# minibatch 69/150
# average cost array(0.03553519201531142)
# epoch 1
# minibatch 70/150
# average cost array(0.032564880257275455)
# epoch 1
# minibatch 71/150
# average cost array(0.024139030502004073)
# epoch 1
# minibatch 72/150
# average cost array(0.027682053820953824)
# epoch 1
# minibatch 73/150
# average cost array(0.025912398679845405)
# epoch 1
# minibatch 74/150
# average cost array(0.02969535362648516)
# epoch 1
# minibatch 75/150
# average cost array(0.023010004849717006)
# epoch 1
# minibatch 76/150
# average cost array(0.08238440662565197)
# epoch 1
# minibatch 77/150
# average cost array(0.12385375368574283)
# epoch 1
# minibatch 78/150
# average cost array(0.10292277950666029)
# epoch 1
# minibatch 79/150
# average cost array(0.13743543389592267)
# epoch 1
# minibatch 80/150
# average cost array(0.08566305757870399)
# epoch 1
# minibatch 81/150
# average cost array(0.07817963162705181)
# epoch 1
# minibatch 82/150
# average cost array(0.05088790059653164)
# epoch 1
# minibatch 83/150
# average cost array(0.094033589956962)
# epoch 1
# minibatch 84/150
# average cost array(0.06627024987942738)
# epoch 1
# minibatch 85/150
# average cost array(0.1127985427072146)
# epoch 1
# minibatch 86/150
# average cost array(0.11943137844694221)
# epoch 1
# minibatch 87/150
# average cost array(0.07923197749050462)
# epoch 1
# minibatch 88/150
# average cost array(0.08496596497759823)
# epoch 1
# minibatch 89/150
# average cost array(0.06566156572221533)
# epoch 1
# minibatch 90/150
# average cost array(0.08675323688208655)
# epoch 1
# minibatch 91/150
# average cost array(0.0549938229867374)
# epoch 1
# minibatch 92/150
# average cost array(0.09082462944390493)
# epoch 1
# minibatch 93/150
# average cost array(0.05955498711526922)
# epoch 1
# minibatch 94/150
# average cost array(0.09151295547360842)
# epoch 1
# minibatch 95/150
# average cost array(0.07958933479624225)
# epoch 1
# minibatch 96/150
# average cost array(0.11702246143562159)
# epoch 1
# minibatch 97/150
# average cost array(0.0738884357637187)
# epoch 1
# minibatch 98/150
# average cost array(0.09684942210929805)
# epoch 1
# minibatch 99/150
# average cost array(0.0824693788704945)
# epoch 1
# minibatch 100/150
# average cost array(0.11139136341672859)
# epoch 1
# minibatch 101/150
# average cost array(0.0645941423177063)
# epoch 1
# minibatch 102/150
# average cost array(0.0651505914713815)
# epoch 1
# minibatch 103/150
# average cost array(0.0841630350134042)
# epoch 1
# minibatch 104/150
# average cost array(0.06799199396465586)
# epoch 1
# minibatch 105/150
# average cost array(0.06587601473104351)
# epoch 1
# minibatch 106/150
# average cost array(0.09537085542935073)
# epoch 1
# minibatch 107/150
# average cost array(0.07851101225966475)
# epoch 1
# minibatch 108/150
# average cost array(0.05431359939084466)
# epoch 1
# minibatch 109/150
# average cost array(0.07782660827696239)
# epoch 1
# minibatch 110/150
# average cost array(0.07368339390651879)
# epoch 1
# minibatch 111/150
# average cost array(0.06612039993643362)
# epoch 1
# minibatch 112/150
# average cost array(0.0822572945085289)
# epoch 1
# minibatch 113/150
# average cost array(0.06880979820521524)
# epoch 1
# minibatch 114/150
# average cost array(0.06562013494747991)
# epoch 1
# minibatch 115/150
# average cost array(0.08972559740408574)
# epoch 1
# minibatch 116/150
# average cost array(0.08038728934964398)
# epoch 1
# minibatch 117/150
# average cost array(0.08643484952514059)
# epoch 1
# minibatch 118/150
# average cost array(0.06653287732840016)
# epoch 1
# minibatch 119/150
# average cost array(0.0770290148060873)
# epoch 1
# minibatch 120/150
# average cost array(0.06840651622239158)
# epoch 1
# minibatch 121/150
# average cost array(0.08484289769277777)
# epoch 1
# minibatch 122/150
# average cost array(0.06431688190977383)
# epoch 1
# minibatch 123/150
# average cost array(0.05986303990058663)
# epoch 1
# minibatch 124/150
# average cost array(0.09092609878417726)
# epoch 1
# minibatch 125/150
# average cost array(0.07875182864774563)
# epoch 1
# minibatch 126/150
# average cost array(0.08690771879817125)
# epoch 1
# minibatch 127/150
# average cost array(0.06275307021532048)
# epoch 1
# minibatch 128/150
# average cost array(0.06381715540078023)
# epoch 1
# minibatch 129/150
# average cost array(0.10593826061673262)
# epoch 1
# minibatch 130/150
# average cost array(0.06636438186742573)
# epoch 1
# minibatch 131/150
# average cost array(0.08794648338749668)
# epoch 1
# minibatch 132/150
# average cost array(0.06023651713011435)
# epoch 1
# minibatch 133/150
# average cost array(0.07278343751707786)
# epoch 1
# minibatch 134/150
# average cost array(0.08746621100821723)
# epoch 1
# minibatch 135/150
# average cost array(0.07213720196092159)
# epoch 1
# minibatch 136/150
# average cost array(0.0777494511058088)
# epoch 1
# minibatch 137/150
# average cost array(0.06370175455731815)
# epoch 1
# minibatch 138/150
# average cost array(0.08070545561266614)
# epoch 1
# minibatch 139/150
# average cost array(0.052765955579385904)
# epoch 1
# minibatch 140/150
# average cost array(0.08108058772043658)
# epoch 1
# minibatch 141/150
# average cost array(0.06874066358208121)
# epoch 1
# minibatch 142/150
# average cost array(0.05408794427940592)
# epoch 1
# minibatch 143/150
# average cost array(0.07565071519941256)
# epoch 1
# minibatch 144/150
# average cost array(0.08149891905969021)
# epoch 1
# minibatch 145/150
# average cost array(0.08333189219811862)
# epoch 1
# minibatch 146/150
# average cost array(0.1001079230493193)
# epoch 1
# minibatch 147/150
# average cost array(0.07092257877828848)
# epoch 1
# minibatch 148/150
# average cost array(0.05860836543045818)
# epoch 1
# minibatch 149/150
# average cost array(0.06378333257335511)
# epoch 1
# minibatch 150/150
# average cost array(0.08304817140773997)
# epoch 2
# minibatch 1/150
# average cost array(0.06685859691143665)
# epoch 2
# minibatch 2/150
# average cost array(0.06673173448499689)
# epoch 2
# minibatch 3/150
# average cost array(0.06104478283965309)
# epoch 2
# minibatch 4/150
# average cost array(0.051224975844831634)
# epoch 2
# minibatch 5/150
# average cost array(0.055881579374436406)
# epoch 2
# minibatch 6/150
# average cost array(0.05347686173686398)
# epoch 2
# minibatch 7/150
# average cost array(0.05354583603477632)
# epoch 2
# minibatch 8/150
# average cost array(0.04352906980949234)
# epoch 2
# minibatch 9/150
# average cost array(0.042884459655139984)
# epoch 2
# minibatch 10/150
# average cost array(0.04087220152567761)
# epoch 2
# minibatch 11/150
# average cost array(0.04211753175232334)
# epoch 2
# minibatch 12/150
# average cost array(0.04493702047531322)
# epoch 2
# minibatch 13/150
# average cost array(0.04969030752313995)
# epoch 2
# minibatch 14/150
# average cost array(0.03585910456301312)
# epoch 2
# minibatch 15/150
# average cost array(0.02664893828303972)
# epoch 2
# minibatch 16/150
# average cost array(0.04196707171192477)
# epoch 2
# minibatch 17/150
# average cost array(0.032899934017721656)
# epoch 2
# minibatch 18/150
# average cost array(0.02304522886567763)
# epoch 2
# minibatch 19/150
# average cost array(0.047215156527297936)
# epoch 2
# minibatch 20/150
# average cost array(0.03655941478738729)
# epoch 2
# minibatch 21/150
# average cost array(0.027359077012258544)
# epoch 2
# minibatch 22/150
# average cost array(0.032642525537233326)
# epoch 2
# minibatch 23/150
# average cost array(0.03382813931217249)
# epoch 2
# minibatch 24/150
# average cost array(0.02831357413692937)
# epoch 2
# minibatch 25/150
# average cost array(0.03043410006367716)
# epoch 2
# minibatch 26/150
# average cost array(0.02426072569494655)
# epoch 2
# minibatch 27/150
# average cost array(0.03109154357571802)
# epoch 2
# minibatch 28/150
# average cost array(0.027119743327455315)
# epoch 2
# minibatch 29/150
# average cost array(0.021734971767138393)
# epoch 2
# minibatch 30/150
# average cost array(0.023923583365768497)
# epoch 2
# minibatch 31/150
# average cost array(0.02225213046946809)
# epoch 2
# minibatch 32/150
# average cost array(0.020272483370327173)
# epoch 2
# minibatch 33/150
# average cost array(0.022972013455965792)
# epoch 2
# minibatch 34/150
# average cost array(0.03246331807955822)
# epoch 2
# minibatch 35/150
# average cost array(0.028773465746604904)
# epoch 2
# minibatch 36/150
# average cost array(0.013777851373284068)
# epoch 2
# minibatch 37/150
# average cost array(0.020566512721325775)
# epoch 2
# minibatch 38/150
# average cost array(0.037048861654434974)
# epoch 2
# minibatch 39/150
# average cost array(0.02854715996277469)
# epoch 2
# minibatch 40/150
# average cost array(0.01990050232567983)
# epoch 2
# minibatch 41/150
# average cost array(0.029041745100041323)
# epoch 2
# minibatch 42/150
# average cost array(0.01599907824486669)
# epoch 2
# minibatch 43/150
# average cost array(0.024444219215680577)
# epoch 2
# minibatch 44/150
# average cost array(0.012331903138948528)
# epoch 2
# minibatch 45/150
# average cost array(0.014436957351186228)
# epoch 2
# minibatch 46/150
# average cost array(0.03788895867978365)
# epoch 2
# minibatch 47/150
# average cost array(0.028977763941182972)
# epoch 2
# minibatch 48/150
# average cost array(0.0119298904588345)
# epoch 2
# minibatch 49/150
# average cost array(0.013210116398191743)
# epoch 2
# minibatch 50/150
# average cost array(0.02794757983233224)
# epoch 2
# minibatch 51/150
# average cost array(0.014283345464790067)
# epoch 2
# minibatch 52/150
# average cost array(0.02718547061889979)
# epoch 2
# minibatch 53/150
# average cost array(0.012582987299568272)
# epoch 2
# minibatch 54/150
# average cost array(0.01928256328817695)
# epoch 2
# minibatch 55/150
# average cost array(0.021585213458976408)
# epoch 2
# minibatch 56/150
# average cost array(0.0164056773389442)
# epoch 2
# minibatch 57/150
# average cost array(0.014056889567197204)
# epoch 2
# minibatch 58/150
# average cost array(0.01715071651849782)
# epoch 2
# minibatch 59/150
# average cost array(0.017785096002683694)
# epoch 2
# minibatch 60/150
# average cost array(0.03229485470966427)
# epoch 2
# minibatch 61/150
# average cost array(0.013676122914835775)
# epoch 2
# minibatch 62/150
# average cost array(0.010655784556171244)
# epoch 2
# minibatch 63/150
# average cost array(0.013068643856051668)
# epoch 2
# minibatch 64/150
# average cost array(0.020214766667926622)
# epoch 2
# minibatch 65/150
# average cost array(0.014104015627416408)
# epoch 2
# minibatch 66/150
# average cost array(0.016758330588562284)
# epoch 2
# minibatch 67/150
# average cost array(0.009621033829456211)
# epoch 2
# minibatch 68/150
# average cost array(0.007914477287767667)
# epoch 2
# minibatch 69/150
# average cost array(0.01577926307277582)
# epoch 2
# minibatch 70/150
# average cost array(0.013707012594453376)
# epoch 2
# minibatch 71/150
# average cost array(0.009090443950999384)
# epoch 2
# minibatch 72/150
# average cost array(0.010062913882841208)
# epoch 2
# minibatch 73/150
# average cost array(0.02283554044310559)
# epoch 2
# minibatch 74/150
# average cost array(0.018176047131588602)
# epoch 2
# minibatch 75/150
# average cost array(0.011543656838727306)
# epoch 2
# minibatch 76/150
# average cost array(0.09625176446289835)
# epoch 2
# minibatch 77/150
# average cost array(0.14429323409478156)
# epoch 2
# minibatch 78/150
# average cost array(0.11943939791158531)
# epoch 2
# minibatch 79/150
# average cost array(0.15723962308778722)
# epoch 2
# minibatch 80/150
# average cost array(0.09557247522690922)
# epoch 2
# minibatch 81/150
# average cost array(0.08801800442528092)
# epoch 2
# minibatch 82/150
# average cost array(0.05175776873672013)
# epoch 2
# minibatch 83/150
# average cost array(0.09797278797924741)
# epoch 2
# minibatch 84/150
# average cost array(0.06680055439305266)
# epoch 2
# minibatch 85/150
# average cost array(0.12377785449343778)
# epoch 2
# minibatch 86/150
# average cost array(0.13070823520154246)
# epoch 2
# minibatch 87/150
# average cost array(0.08525756479169122)
# epoch 2
# minibatch 88/150
# average cost array(0.08383965076490155)
# epoch 2
# minibatch 89/150
# average cost array(0.06518424430384226)
# epoch 2
# minibatch 90/150
# average cost array(0.09444354336537883)
# epoch 2
# minibatch 91/150
# average cost array(0.04694357378918667)
# epoch 2
# minibatch 92/150
# average cost array(0.09289391817618184)
# epoch 2
# minibatch 93/150
# average cost array(0.05948360930677332)
# epoch 2
# minibatch 94/150
# average cost array(0.09658970166091625)
# epoch 2
# minibatch 95/150
# average cost array(0.07908077736533285)
# epoch 2
# minibatch 96/150
# average cost array(0.12101306430677221)
# epoch 2
# minibatch 97/150
# average cost array(0.07220892134852167)
# epoch 2
# minibatch 98/150
# average cost array(0.09371298365927633)
# epoch 2
# minibatch 99/150
# average cost array(0.08098932042348178)
# epoch 2
# minibatch 100/150
# average cost array(0.10926647418843094)
# epoch 2
# minibatch 101/150
# average cost array(0.06214508182197028)
# epoch 2
# minibatch 102/150
# average cost array(0.06711345401414506)
# epoch 2
# minibatch 103/150
# average cost array(0.0805707970365022)
# epoch 2
# minibatch 104/150
# average cost array(0.06506471338111543)
# epoch 2
# minibatch 105/150
# average cost array(0.0631929228678704)
# epoch 2
# minibatch 106/150
# average cost array(0.09522181239022606)
# epoch 2
# minibatch 107/150
# average cost array(0.07125286604163303)
# epoch 2
# minibatch 108/150
# average cost array(0.0511093858472579)
# epoch 2
# minibatch 109/150
# average cost array(0.07714363156277323)
# epoch 2
# minibatch 110/150
# average cost array(0.07117934131630291)
# epoch 2
# minibatch 111/150
# average cost array(0.06168391892276644)
# epoch 2
# minibatch 112/150
# average cost array(0.07719300871602779)
# epoch 2
# minibatch 113/150
# average cost array(0.06609631843714617)
# epoch 2
# minibatch 114/150
# average cost array(0.05819070427164251)
# epoch 2
# minibatch 115/150
# average cost array(0.0857161653198548)
# epoch 2
# minibatch 116/150
# average cost array(0.07603084705849761)
# epoch 2
# minibatch 117/150
# average cost array(0.08298994716543338)
# epoch 2
# minibatch 118/150
# average cost array(0.06183670907444246)
# epoch 2
# minibatch 119/150
# average cost array(0.07229054200916747)
# epoch 2
# minibatch 120/150
# average cost array(0.06386054308794338)
# epoch 2
# minibatch 121/150
# average cost array(0.07937587434623777)
# epoch 2
# minibatch 122/150
# average cost array(0.05846171295846845)
# epoch 2
# minibatch 123/150
# average cost array(0.05559468709378913)
# epoch 2
# minibatch 124/150
# average cost array(0.08527059611504655)
# epoch 2
# minibatch 125/150
# average cost array(0.07337856889805039)
# epoch 2
# minibatch 126/150
# average cost array(0.08253764054705988)
# epoch 2
# minibatch 127/150
# average cost array(0.057389832583132086)
# epoch 2
# minibatch 128/150
# average cost array(0.06388605388599986)
# epoch 2
# minibatch 129/150
# average cost array(0.09950535992075143)
# epoch 2
# minibatch 130/150
# average cost array(0.06264973749015543)
# epoch 2
# minibatch 131/150
# average cost array(0.07954890566544372)
# epoch 2
# minibatch 132/150
# average cost array(0.05356314624158045)
# epoch 2
# minibatch 133/150
# average cost array(0.06791825414150485)
# epoch 2
# minibatch 134/150
# average cost array(0.08277797045978405)
# epoch 2
# minibatch 135/150
# average cost array(0.06613192006016402)
# epoch 2
# minibatch 136/150
# average cost array(0.07232582823756144)
# epoch 2
# minibatch 137/150
# average cost array(0.056956693559662666)
# epoch 2
# minibatch 138/150
# average cost array(0.07441905243916344)
# epoch 2
# minibatch 139/150
# average cost array(0.049811044429135164)
# epoch 2
# minibatch 140/150
# average cost array(0.07698514881993211)
# epoch 2
# minibatch 141/150
# average cost array(0.06317756022180168)
# epoch 2
# minibatch 142/150
# average cost array(0.04522009078722589)
# epoch 2
# minibatch 143/150
# average cost array(0.06797862972840973)
# epoch 2
# minibatch 144/150
# average cost array(0.07854733525593108)
# epoch 2
# minibatch 145/150
# average cost array(0.07824790150103894)
# epoch 2
# minibatch 146/150
# average cost array(0.09396389722747268)
# epoch 2
# minibatch 147/150
# average cost array(0.06787387646124214)
# epoch 2
# minibatch 148/150
# average cost array(0.05130038991595289)
# epoch 2
# minibatch 149/150
# average cost array(0.05704746716425293)
# epoch 2
# minibatch 150/150
# average cost array(0.07449218505536212)
# epoch 3
# minibatch 1/150
# average cost array(0.058103286165058256)
# epoch 3
# minibatch 2/150
# average cost array(0.053557158596681545)
# epoch 3
# minibatch 3/150
# average cost array(0.05175070678738839)
# epoch 3
# minibatch 4/150
# average cost array(0.043586957073257805)
# epoch 3
# minibatch 5/150
# average cost array(0.047894249019664194)
# epoch 3
# minibatch 6/150
# average cost array(0.04378898701204502)
# epoch 3
# minibatch 7/150
# average cost array(0.04615413613293996)
# epoch 3
# minibatch 8/150
# average cost array(0.03542705369702283)
# epoch 3
# minibatch 9/150
# average cost array(0.03557927059050906)
# epoch 3
# minibatch 10/150
# average cost array(0.03577282117992661)
# epoch 3
# minibatch 11/150
# average cost array(0.033057657675334536)
# epoch 3
# minibatch 12/150
# average cost array(0.03680220589133106)
# epoch 3
# minibatch 13/150
# average cost array(0.04071709665401529)
# epoch 3
# minibatch 14/150
# average cost array(0.02722440404682251)
# epoch 3
# minibatch 15/150
# average cost array(0.021602717792858883)
# epoch 3
# minibatch 16/150
# average cost array(0.03645662740804222)
# epoch 3
# minibatch 17/150
# average cost array(0.028821948356492884)
# epoch 3
# minibatch 18/150
# average cost array(0.01993458963525839)
# epoch 3
# minibatch 19/150
# average cost array(0.039800514851422095)
# epoch 3
# minibatch 20/150
# average cost array(0.03534198937401149)
# epoch 3
# minibatch 21/150
# average cost array(0.024691170707699592)
# epoch 3
# minibatch 22/150
# average cost array(0.027194910588012093)
# epoch 3
# minibatch 23/150
# average cost array(0.02953859893060066)
# epoch 3
# minibatch 24/150
# average cost array(0.025775448730950334)
# epoch 3
# minibatch 25/150
# average cost array(0.030201735982677884)
# epoch 3
# minibatch 26/150
# average cost array(0.019280567488639332)
# epoch 3
# minibatch 27/150
# average cost array(0.02832486086754264)
# epoch 3
# minibatch 28/150
# average cost array(0.022802209888406987)
# epoch 3
# minibatch 29/150
# average cost array(0.017664871624000846)
# epoch 3
# minibatch 30/150
# average cost array(0.02171852510611526)
# epoch 3
# minibatch 31/150
# average cost array(0.01947145796719684)
# epoch 3
# minibatch 32/150
# average cost array(0.017177248276524833)
# epoch 3
# minibatch 33/150
# average cost array(0.020087957027317922)
# epoch 3
# minibatch 34/150
# average cost array(0.027937592026872272)
# epoch 3
# minibatch 35/150
# average cost array(0.024866375823290886)
# epoch 3
# minibatch 36/150
# average cost array(0.011102996135004364)
# epoch 3
# minibatch 37/150
# average cost array(0.018747663942109145)
# epoch 3
# minibatch 38/150
# average cost array(0.03368461620917224)
# epoch 3
# minibatch 39/150
# average cost array(0.026245389414757063)
# epoch 3
# minibatch 40/150
# average cost array(0.017384889511155084)
# epoch 3
# minibatch 41/150
# average cost array(0.027612534890491102)
# epoch 3
# minibatch 42/150
# average cost array(0.016067942646934917)
# epoch 3
# minibatch 43/150
# average cost array(0.022276877638485963)
# epoch 3
# minibatch 44/150
# average cost array(0.010170392140580645)
# epoch 3
# minibatch 45/150
# average cost array(0.013335510422038413)
# epoch 3
# minibatch 46/150
# average cost array(0.034913566604002896)
# epoch 3
# minibatch 47/150
# average cost array(0.027146439958812517)
# epoch 3
# minibatch 48/150
# average cost array(0.010847944251753252)
# epoch 3
# minibatch 49/150
# average cost array(0.01200169301784698)
# epoch 3
# minibatch 50/150
# average cost array(0.025854740655172466)
# epoch 3
# minibatch 51/150
# average cost array(0.011579122305432111)
# epoch 3
# minibatch 52/150
# average cost array(0.025709903513488102)
# epoch 3
# minibatch 53/150
# average cost array(0.01288480264694965)
# epoch 3
# minibatch 54/150
# average cost array(0.016187551848453788)
# epoch 3
# minibatch 55/150
# average cost array(0.020874322196786862)
# epoch 3
# minibatch 56/150
# average cost array(0.01629697215244457)
# epoch 3
# minibatch 57/150
# average cost array(0.01233332448294918)
# epoch 3
# minibatch 58/150
# average cost array(0.016971831945793204)
# epoch 3
# minibatch 59/150
# average cost array(0.01709984168602536)
# epoch 3
# minibatch 60/150
# average cost array(0.030896050497026317)
# epoch 3
# minibatch 61/150
# average cost array(0.01264566492210723)
# epoch 3
# minibatch 62/150
# average cost array(0.012742502672225667)
# epoch 3
# minibatch 63/150
# average cost array(0.01266827123940186)
# epoch 3
# minibatch 64/150
# average cost array(0.020517518591139604)
# epoch 3
# minibatch 65/150
# average cost array(0.015504680248948693)
# epoch 3
# minibatch 66/150
# average cost array(0.01575142706809309)
# epoch 3
# minibatch 67/150
# average cost array(0.009369873573110574)
# epoch 3
# minibatch 68/150
# average cost array(0.00746031716651917)
# epoch 3
# minibatch 69/150
# average cost array(0.015283006874638749)
# epoch 3
# minibatch 70/150
# average cost array(0.014335006572338247)
# epoch 3
# minibatch 71/150
# average cost array(0.009930287536787753)
# epoch 3
# minibatch 72/150
# average cost array(0.009172601874399342)
# epoch 3
# minibatch 73/150
# average cost array(0.02393578056555956)
# epoch 3
# minibatch 74/150
# average cost array(0.017855729914493586)
# epoch 3
# minibatch 75/150
# average cost array(0.010568985698414652)
# epoch 3
# minibatch 76/150
# average cost array(0.0861925879514572)
# epoch 3
# minibatch 77/150
# average cost array(0.12657433805593687)
# epoch 3
# minibatch 78/150
# average cost array(0.10601282631121137)
# epoch 3
# minibatch 79/150
# average cost array(0.1398900705396292)
# epoch 3
# minibatch 80/150
# average cost array(0.08521977843492219)
# epoch 3
# minibatch 81/150
# average cost array(0.07790639569316413)
# epoch 3
# minibatch 82/150
# average cost array(0.047424656635402546)
# epoch 3
# minibatch 83/150
# average cost array(0.08571193524658696)
# epoch 3
# minibatch 84/150
# average cost array(0.06100848444593528)
# epoch 3
# minibatch 85/150
# average cost array(0.10980033491783898)
# epoch 3
# minibatch 86/150
# average cost array(0.11615259807965579)
# epoch 3
# minibatch 87/150
# average cost array(0.07704803895220322)
# epoch 3
# minibatch 88/150
# average cost array(0.07345169634948104)
# epoch 3
# minibatch 89/150
# average cost array(0.05880079089888636)
# epoch 3
# minibatch 90/150
# average cost array(0.08709007328773878)
# epoch 3
# minibatch 91/150
# average cost array(0.040619950013019476)
# epoch 3
# minibatch 92/150
# average cost array(0.08194450058922148)
# epoch 3
# minibatch 93/150
# average cost array(0.05455736449380568)
# epoch 3
# minibatch 94/150
# average cost array(0.08378134948253915)
# epoch 3
# minibatch 95/150
# average cost array(0.07044721868454688)
# epoch 3
# minibatch 96/150
# average cost array(0.10664558251660569)
# epoch 3
# minibatch 97/150
# average cost array(0.0633451239062339)
# epoch 3
# minibatch 98/150
# average cost array(0.08315274622010962)
# epoch 3
# minibatch 99/150
# average cost array(0.07157470731739005)
# epoch 3
# minibatch 100/150
# average cost array(0.09761036889570171)
# epoch 3
# minibatch 101/150
# average cost array(0.05266843818417738)
# epoch 3
# minibatch 102/150
# average cost array(0.0607894854827231)
# epoch 3
# minibatch 103/150
# average cost array(0.06989174415944836)
# epoch 3
# minibatch 104/150
# average cost array(0.05803657309180667)
# epoch 3
# minibatch 105/150
# average cost array(0.05939114200404773)
# epoch 3
# minibatch 106/150
# average cost array(0.08582565267773018)
# epoch 3
# minibatch 107/150
# average cost array(0.06383443680481099)
# epoch 3
# minibatch 108/150
# average cost array(0.0443998790282568)
# epoch 3
# minibatch 109/150
# average cost array(0.06925633066493511)
# epoch 3
# minibatch 110/150
# average cost array(0.06175348748160332)
# epoch 3
# minibatch 111/150
# average cost array(0.05551099276778189)
# epoch 3
# minibatch 112/150
# average cost array(0.06708290850775465)
# epoch 3
# minibatch 113/150
# average cost array(0.0569201991943367)
# epoch 3
# minibatch 114/150
# average cost array(0.05206378602787091)
# epoch 3
# minibatch 115/150
# average cost array(0.07567137303312498)
# epoch 3
# minibatch 116/150
# average cost array(0.06456036048702447)
# epoch 3
# minibatch 117/150
# average cost array(0.07665159123937186)
# epoch 3
# minibatch 118/150
# average cost array(0.05535923359221835)
# epoch 3
# minibatch 119/150
# average cost array(0.06501188297944352)
# epoch 3
# minibatch 120/150
# average cost array(0.05678538380774317)
# epoch 3
# minibatch 121/150
# average cost array(0.06924336328580886)
# epoch 3
# minibatch 122/150
# average cost array(0.0530067589161219)
# epoch 3
# minibatch 123/150
# average cost array(0.05142493971241091)
# epoch 3
# minibatch 124/150
# average cost array(0.07276644756691926)
# epoch 3
# minibatch 125/150
# average cost array(0.06673562817036764)
# epoch 3
# minibatch 126/150
# average cost array(0.07255618262979031)
# epoch 3
# minibatch 127/150
# average cost array(0.053084050350720835)
# epoch 3
# minibatch 128/150
# average cost array(0.06103310370594569)
# epoch 3
# minibatch 129/150
# average cost array(0.08540754332524561)
# epoch 3
# minibatch 130/150
# average cost array(0.055723385987893906)
# epoch 3
# minibatch 131/150
# average cost array(0.06779424563501399)
# epoch 3
# minibatch 132/150
# average cost array(0.0471908478696814)
# epoch 3
# minibatch 133/150
# average cost array(0.06365889748986216)
# epoch 3
# minibatch 134/150
# average cost array(0.07114436202899535)
# epoch 3
# minibatch 135/150
# average cost array(0.059656402774468986)
# epoch 3
# minibatch 136/150
# average cost array(0.06494598028021477)
# epoch 3
# minibatch 137/150
# average cost array(0.05139639482886975)
# epoch 3
# minibatch 138/150
# average cost array(0.06528185695986735)
# epoch 3
# minibatch 139/150
# average cost array(0.0464613197757671)
# epoch 3
# minibatch 140/150
# average cost array(0.07081555925043322)
# epoch 3
# minibatch 141/150
# average cost array(0.05597009922483427)
# epoch 3
# minibatch 142/150
# average cost array(0.03879643299231878)
# epoch 3
# minibatch 143/150
# average cost array(0.057290243332665816)
# epoch 3
# minibatch 144/150
# average cost array(0.07136166123071871)
# epoch 3
# minibatch 145/150
# average cost array(0.07070929112514417)
# epoch 3
# minibatch 146/150
# average cost array(0.08425481863320802)
# epoch 3
# minibatch 147/150
# average cost array(0.06323900640532262)
# epoch 3
# minibatch 148/150
# average cost array(0.04527081304068177)
# epoch 3
# minibatch 149/150
# average cost array(0.05043810158999612)
# epoch 3
# minibatch 150/150
# average cost array(0.06471003893757166)
# epoch 4
# minibatch 1/150
# average cost array(0.05307326177610135)
# epoch 4
# minibatch 2/150
# average cost array(0.04541011732559009)
# epoch 4
# minibatch 3/150
# average cost array(0.04711467460004637)
# epoch 4
# minibatch 4/150
# average cost array(0.03973062020540545)
# epoch 4
# minibatch 5/150
# average cost array(0.044575214698549435)
# epoch 4
# minibatch 6/150
# average cost array(0.0385234777841919)
# epoch 4
# minibatch 7/150
# average cost array(0.04355469234101608)
# epoch 4
# minibatch 8/150
# average cost array(0.031372620170998414)
# epoch 4
# minibatch 9/150
# average cost array(0.03178314875173609)
# epoch 4
# minibatch 10/150
# average cost array(0.03439992020786947)
# epoch 4
# minibatch 11/150
# average cost array(0.028136804757084695)
# epoch 4
# minibatch 12/150
# average cost array(0.03204026802298192)
# epoch 4
# minibatch 13/150
# average cost array(0.036105142290637854)
# epoch 4
# minibatch 14/150
# average cost array(0.02231937069136731)
# epoch 4
# minibatch 15/150
# average cost array(0.019582373692032494)
# epoch 4
# minibatch 16/150
# average cost array(0.03393949016778162)
# epoch 4
# minibatch 17/150
# average cost array(0.027559398319511208)
# epoch 4
# minibatch 18/150
# average cost array(0.020057346826900524)
# epoch 4
# minibatch 19/150
# average cost array(0.034667719488371065)
# epoch 4
# minibatch 20/150
# average cost array(0.035916370599516655)
# epoch 4
# minibatch 21/150
# average cost array(0.02451756812528138)
# epoch 4
# minibatch 22/150
# average cost array(0.024235604340673324)
# epoch 4
# minibatch 23/150
# average cost array(0.02731455983356703)
# epoch 4
# minibatch 24/150
# average cost array(0.024657218941415846)
# epoch 4
# minibatch 25/150
# average cost array(0.03176044952417433)
# epoch 4
# minibatch 26/150
# average cost array(0.01687568739515511)
# epoch 4
# minibatch 27/150
# average cost array(0.02838936942411857)
# epoch 4
# minibatch 28/150
# average cost array(0.020910320043023362)
# epoch 4
# minibatch 29/150
# average cost array(0.017688812027527458)
# epoch 4
# minibatch 30/150
# average cost array(0.022239291119492965)
# epoch 4
# minibatch 31/150
# average cost array(0.018241530885164593)
# epoch 4
# minibatch 32/150
# average cost array(0.015962681949870522)
# epoch 4
# minibatch 33/150
# average cost array(0.018912883662453688)
# epoch 4
# minibatch 34/150
# average cost array(0.024813377959314258)
# epoch 4
# minibatch 35/150
# average cost array(0.023258788300196565)
# epoch 4
# minibatch 36/150
# average cost array(0.010300214908745775)
# epoch 4
# minibatch 37/150
# average cost array(0.01894168046504396)
# epoch 4
# minibatch 38/150
# average cost array(0.031990297586350275)
# epoch 4
# minibatch 39/150
# average cost array(0.02497786195673469)
# epoch 4
# minibatch 40/150
# average cost array(0.017083951351271127)
# epoch 4
# minibatch 41/150
# average cost array(0.027201554788314257)
# epoch 4
# minibatch 42/150
# average cost array(0.017427127499488725)
# epoch 4
# minibatch 43/150
# average cost array(0.022163339070843037)
# epoch 4
# minibatch 44/150
# average cost array(0.00939680072133055)
# epoch 4
# minibatch 45/150
# average cost array(0.0136767145888636)
# epoch 4
# minibatch 46/150
# average cost array(0.032413120678661464)
# epoch 4
# minibatch 47/150
# average cost array(0.026457456448627754)
# epoch 4
# minibatch 48/150
# average cost array(0.011414679140279235)
# epoch 4
# minibatch 49/150
# average cost array(0.01233937180551091)
# epoch 4
# minibatch 50/150
# average cost array(0.025160453229010855)
# epoch 4
# minibatch 51/150
# average cost array(0.010103139125000476)
# epoch 4
# minibatch 52/150
# average cost array(0.02547465802372434)
# epoch 4
# minibatch 53/150
# average cost array(0.014622627348330289)
# epoch 4
# minibatch 54/150
# average cost array(0.014450112116254996)
# epoch 4
# minibatch 55/150
# average cost array(0.020831421559988662)
# epoch 4
# minibatch 56/150
# average cost array(0.017046643523996992)
# epoch 4
# minibatch 57/150
# average cost array(0.011613901591625163)
# epoch 4
# minibatch 58/150
# average cost array(0.018083252776628696)
# epoch 4
# minibatch 59/150
# average cost array(0.017156635704883568)
# epoch 4
# minibatch 60/150
# average cost array(0.029679868918709683)
# epoch 4
# minibatch 61/150
# average cost array(0.011797609411411815)
# epoch 4
# minibatch 62/150
# average cost array(0.01611976319721915)
# epoch 4
# minibatch 63/150
# average cost array(0.013500330246022263)
# epoch 4
# minibatch 64/150
# average cost array(0.02132665230018268)
# epoch 4
# minibatch 65/150
# average cost array(0.018668492854823956)
# epoch 4
# minibatch 66/150
# average cost array(0.01566000801357611)
# epoch 4
# minibatch 67/150
# average cost array(0.010674148961686536)
# epoch 4
# minibatch 68/150
# average cost array(0.00829248713685836)
# epoch 4
# minibatch 69/150
# average cost array(0.015707119567366982)
# epoch 4
# minibatch 70/150
# average cost array(0.015938888648503534)
# epoch 4
# minibatch 71/150
# average cost array(0.012116357409229169)
# epoch 4
# minibatch 72/150
# average cost array(0.009593312202587235)
# epoch 4
# minibatch 73/150
# average cost array(0.02528928597989565)
# epoch 4
# minibatch 74/150
# average cost array(0.0188020545521319)
# epoch 4
# minibatch 75/150
# average cost array(0.010605662518389488)
# epoch 4
# minibatch 76/150
# average cost array(0.07578693888275145)
# epoch 4
# minibatch 77/150
# average cost array(0.10868963227912673)
# epoch 4
# minibatch 78/150
# average cost array(0.0910391613442493)
# epoch 4
# minibatch 79/150
# average cost array(0.1210814228058098)
# epoch 4
# minibatch 80/150
# average cost array(0.07419659312238477)
# epoch 4
# minibatch 81/150
# average cost array(0.06717851679209838)
# epoch 4
# minibatch 82/150
# average cost array(0.043396990603553134)
# epoch 4
# minibatch 83/150
# average cost array(0.07329480005398967)
# epoch 4
# minibatch 84/150
# average cost array(0.055859101894164855)
# epoch 4
# minibatch 85/150
# average cost array(0.09562925204287684)
# epoch 4
# minibatch 86/150
# average cost array(0.10037591851878658)
# epoch 4
# minibatch 87/150
# average cost array(0.06855675454502468)
# epoch 4
# minibatch 88/150
# average cost array(0.06269688397148276)
# epoch 4
# minibatch 89/150
# average cost array(0.05261821048100135)
# epoch 4
# minibatch 90/150
# average cost array(0.07919671354181411)
# epoch 4
# minibatch 91/150
# average cost array(0.03547108385569091)
# epoch 4
# minibatch 92/150
# average cost array(0.07090932089522563)
# epoch 4
# minibatch 93/150
# average cost array(0.04925922905446521)
# epoch 4
# minibatch 94/150
# average cost array(0.07085834540054578)
# epoch 4
# minibatch 95/150
# average cost array(0.061872530400039)
# epoch 4
# minibatch 96/150
# average cost array(0.09183339897590954)
# epoch 4
# minibatch 97/150
# average cost array(0.0550669101206868)
# epoch 4
# minibatch 98/150
# average cost array(0.07299900543430016)
# epoch 4
# minibatch 99/150
# average cost array(0.06174086349310235)
# epoch 4
# minibatch 100/150
# average cost array(0.08599094466779819)
# epoch 4
# minibatch 101/150
# average cost array(0.043804050085911816)
# epoch 4
# minibatch 102/150
# average cost array(0.05455428238204528)
# epoch 4
# minibatch 103/150
# average cost array(0.060859234843252466)
# epoch 4
# minibatch 104/150
# average cost array(0.05129734808500556)
# epoch 4
# minibatch 105/150
# average cost array(0.05590683361126775)
# epoch 4
# minibatch 106/150
# average cost array(0.07563716204406148)
# epoch 4
# minibatch 107/150
# average cost array(0.05723078996101211)
# epoch 4
# minibatch 108/150
# average cost array(0.03829857763126868)
# epoch 4
# minibatch 109/150
# average cost array(0.06193402054059778)
# epoch 4
# minibatch 110/150
# average cost array(0.05248752420472776)
# epoch 4
# minibatch 111/150
# average cost array(0.049997044746613456)
# epoch 4
# minibatch 112/150
# average cost array(0.05777004015789141)
# epoch 4
# minibatch 113/150
# average cost array(0.04774735596452315)
# epoch 4
# minibatch 114/150
# average cost array(0.0467321100683362)
# epoch 4
# minibatch 115/150
# average cost array(0.06645822269708039)
# epoch 4
# minibatch 116/150
# average cost array(0.05379411927615001)
# epoch 4
# minibatch 117/150
# average cost array(0.07039712553585607)
# epoch 4
# minibatch 118/150
# average cost array(0.04883996776109399)
# epoch 4
# minibatch 119/150
# average cost array(0.05731302177369626)
# epoch 4
# minibatch 120/150
# average cost array(0.04937747354415302)
# epoch 4
# minibatch 121/150
# average cost array(0.05978776769033382)
# epoch 4
# minibatch 122/150
# average cost array(0.04819099968447192)
# epoch 4
# minibatch 123/150
# average cost array(0.047738586536885924)
# epoch 4
# minibatch 124/150
# average cost array(0.060524493854978934)
# epoch 4
# minibatch 125/150
# average cost array(0.06011064918712983)
# epoch 4
# minibatch 126/150
# average cost array(0.06248766958970502)
# epoch 4
# minibatch 127/150
# average cost array(0.04869779730048368)
# epoch 4
# minibatch 128/150
# average cost array(0.058264703033951704)
# epoch 4
# minibatch 129/150
# average cost array(0.07170055813196723)
# epoch 4
# minibatch 130/150
# average cost array(0.04934464895797207)
# epoch 4
# minibatch 131/150
# average cost array(0.05659978229169445)
# epoch 4
# minibatch 132/150
# average cost array(0.041165248679610536)
# epoch 4
# minibatch 133/150
# average cost array(0.06019451665479973)
# epoch 4
# minibatch 134/150
# average cost array(0.05939681416461758)
# epoch 4
# minibatch 135/150
# average cost array(0.05369819399284596)
# epoch 4
# minibatch 136/150
# average cost array(0.05776013946333519)
# epoch 4
# minibatch 137/150
# average cost array(0.04634265677337739)
# epoch 4
# minibatch 138/150
# average cost array(0.05652133666728678)
# epoch 4
# minibatch 139/150
# average cost array(0.04380011391446169)
# epoch 4
# minibatch 140/150
# average cost array(0.0648107685830195)
# epoch 4
# minibatch 141/150
# average cost array(0.04906391631573948)
# epoch 4
# minibatch 142/150
# average cost array(0.03348982302898293)
# epoch 4
# minibatch 143/150
# average cost array(0.04769769960485841)
# epoch 4
# minibatch 144/150
# average cost array(0.06375520705873951)
# epoch 4
# minibatch 145/150
# average cost array(0.06290788337375841)
# epoch 4
# minibatch 146/150
# average cost array(0.07465243244592121)
# epoch 4
# minibatch 147/150
# average cost array(0.05855519377751948)
# epoch 4
# minibatch 148/150
# average cost array(0.03998370539215372)
# epoch 4
# minibatch 149/150
# average cost array(0.04463635819387492)
# epoch 4
# minibatch 150/150
# average cost array(0.05602998261399713)
# epoch 5
# minibatch 1/150
# average cost array(0.0488021584506201)
# epoch 5
# minibatch 2/150
# average cost array(0.03869718003423893)
# epoch 5
# minibatch 3/150
# average cost array(0.04382959430693932)
# epoch 5
# minibatch 4/150
# average cost array(0.03721401722314409)
# epoch 5
# minibatch 5/150
# average cost array(0.04279320591599718)
# epoch 5
# minibatch 6/150
# average cost array(0.034762331079569005)
# epoch 5
# minibatch 7/150
# average cost array(0.04231261371583065)
# epoch 5
# minibatch 8/150
# average cost array(0.02875691477434709)
# epoch 5
# minibatch 9/150
# average cost array(0.029297490250894936)
# epoch 5
# minibatch 10/150
# average cost array(0.03431230569873623)
# epoch 5
# minibatch 11/150
# average cost array(0.0253660530812717)
# epoch 5
# minibatch 12/150
# average cost array(0.02840021877873015)
# epoch 5
# minibatch 13/150
# average cost array(0.03322485015177206)
# epoch 5
# minibatch 14/150
# average cost array(0.020044925861995803)
# epoch 5
# minibatch 15/150
# average cost array(0.018805161441726125)
# epoch 5
# minibatch 16/150
# average cost array(0.03253505693524593)
# epoch 5
# minibatch 17/150
# average cost array(0.027528482644800935)
# epoch 5
# minibatch 18/150
# average cost array(0.0216341574514617)
# epoch 5
# minibatch 19/150
# average cost array(0.03072417514518778)
# epoch 5
# minibatch 20/150
# average cost array(0.036898859785722694)
# epoch 5
# minibatch 21/150
# average cost array(0.02529028550288719)
# epoch 5
# minibatch 22/150
# average cost array(0.02250998877687977)
# epoch 5
# minibatch 23/150
# average cost array(0.02608264519019184)
# epoch 5
# minibatch 24/150
# average cost array(0.024243925059796705)
# epoch 5
# minibatch 25/150
# average cost array(0.03388780361860323)
# epoch 5
# minibatch 26/150
# average cost array(0.015918219386093415)
# epoch 5
# minibatch 27/150
# average cost array(0.02987898519301351)
# epoch 5
# minibatch 28/150
# average cost array(0.020370656639289924)
# epoch 5
# minibatch 29/150
# average cost array(0.020226540875896776)
# epoch 5
# minibatch 30/150
# average cost array(0.023931480969367987)
# epoch 5
# minibatch 31/150
# average cost array(0.017937798026300755)
# epoch 5
# minibatch 32/150
# average cost array(0.01565984352241374)
# epoch 5
# minibatch 33/150
# average cost array(0.01873218669589312)
# epoch 5
# minibatch 34/150
# average cost array(0.022532447860596497)
# epoch 5
# minibatch 35/150
# average cost array(0.022926526981490218)
# epoch 5
# minibatch 36/150
# average cost array(0.010567828741526394)
# epoch 5
# minibatch 37/150
# average cost array(0.019901447698548878)
# epoch 5
# minibatch 38/150
# average cost array(0.03171507537377414)
# epoch 5
# minibatch 39/150
# average cost array(0.02393610751913168)
# epoch 5
# minibatch 40/150
# average cost array(0.017732451147807075)
# epoch 5
# minibatch 41/150
# average cost array(0.027695000877711356)
# epoch 5
# minibatch 42/150
# average cost array(0.019245052970712533)
# epoch 5
# minibatch 43/150
# average cost array(0.023438273434584996)
# epoch 5
# minibatch 44/150
# average cost array(0.009455835385200334)
# epoch 5
# minibatch 45/150
# average cost array(0.01464509992070589)
# epoch 5
# minibatch 46/150
# average cost array(0.030336288154251868)
# epoch 5
# minibatch 47/150
# average cost array(0.026545731003745104)
# epoch 5
# minibatch 48/150
# average cost array(0.01284103522530127)
# epoch 5
# minibatch 49/150
# average cost array(0.013537317001584207)
# epoch 5
# minibatch 50/150
# average cost array(0.025474749173894157)
# epoch 5
# minibatch 51/150
# average cost array(0.009346843787658482)
# epoch 5
# minibatch 52/150
# average cost array(0.025928332484622462)
# epoch 5
# minibatch 53/150
# average cost array(0.016932637519182038)
# epoch 5
# minibatch 54/150
# average cost array(0.013606527914241615)
# epoch 5
# minibatch 55/150
# average cost array(0.021283242272690316)
# epoch 5
# minibatch 56/150
# average cost array(0.01808024712301028)
# epoch 5
# minibatch 57/150
# average cost array(0.01150365033861735)
# epoch 5
# minibatch 58/150
# average cost array(0.019881275575215743)
# epoch 5
# minibatch 59/150
# average cost array(0.017652717553434)
# epoch 5
# minibatch 60/150
# average cost array(0.028659954250172353)
# epoch 5
# minibatch 61/150
# average cost array(0.011297097986355779)
# epoch 5
# minibatch 62/150
# average cost array(0.01972185598124301)
# epoch 5
# minibatch 63/150
# average cost array(0.015038613627227864)
# epoch 5
# minibatch 64/150
# average cost array(0.022124415485347618)
# epoch 5
# minibatch 65/150
# average cost array(0.022606606505840836)
# epoch 5
# minibatch 66/150
# average cost array(0.015949062855241163)
# epoch 5
# minibatch 67/150
# average cost array(0.012637292218341404)
# epoch 5
# minibatch 68/150
# average cost array(0.00972937303022785)
# epoch 5
# minibatch 69/150
# average cost array(0.01657706464510009)
# epoch 5
# minibatch 70/150
# average cost array(0.018015489210649077)
# epoch 5
# minibatch 71/150
# average cost array(0.014906238360251105)
# epoch 5
# minibatch 72/150
# average cost array(0.010832505278925918)
# epoch 5
# minibatch 73/150
# average cost array(0.02652777575119584)
# epoch 5
# minibatch 74/150
# average cost array(0.02058891779528425)
# epoch 5
# minibatch 75/150
# average cost array(0.011350215468545111)
# epoch 5
# minibatch 76/150
# average cost array(0.06687955422153104)
# epoch 5
# minibatch 77/150
# average cost array(0.09285384868956058)
# epoch 5
# minibatch 78/150
# average cost array(0.0772073786651436)
# epoch 5
# minibatch 79/150
# average cost array(0.1041115517606542)
# epoch 5
# minibatch 80/150
# average cost array(0.06410935620392408)
# epoch 5
# minibatch 81/150
# average cost array(0.05806313982399024)
# epoch 5
# minibatch 82/150
# average cost array(0.04011244891622512)
# epoch 5
# minibatch 83/150
# average cost array(0.06270653283928622)
# epoch 5
# minibatch 84/150
# average cost array(0.05229328340052741)
# epoch 5
# minibatch 85/150
# average cost array(0.08355670317053779)
# epoch 5
# minibatch 86/150
# average cost array(0.08603474630544887)
# epoch 5
# minibatch 87/150
# average cost array(0.06097978039873726)
# epoch 5
# minibatch 88/150
# average cost array(0.053291391523478414)
# epoch 5
# minibatch 89/150
# average cost array(0.04743239140295961)
# epoch 5
# minibatch 90/150
# average cost array(0.07187094249377368)
# epoch 5
# minibatch 91/150
# average cost array(0.03193757162930573)
# epoch 5
# minibatch 92/150
# average cost array(0.061445790077408725)
# epoch 5
# minibatch 93/150
# average cost array(0.04447884748559653)
# epoch 5
# minibatch 94/150
# average cost array(0.06005425922605125)
# epoch 5
# minibatch 95/150
# average cost array(0.05440693868556189)
# epoch 5
# minibatch 96/150
# average cost array(0.07886487579706872)
# epoch 5
# minibatch 97/150
# average cost array(0.04826293071897482)
# epoch 5
# minibatch 98/150
# average cost array(0.06457843595092302)
# epoch 5
# minibatch 99/150
# average cost array(0.05303040366044044)
# epoch 5
# minibatch 100/150
# average cost array(0.07581459909087936)
# epoch 5
# minibatch 101/150
# average cost array(0.03662941993583938)
# epoch 5
# minibatch 102/150
# average cost array(0.049422420883205774)
# epoch 5
# minibatch 103/150
# average cost array(0.05398686687743319)
# epoch 5
# minibatch 104/150
# average cost array(0.04558153679543102)
# epoch 5
# minibatch 105/150
# average cost array(0.05309469406630004)
# epoch 5
# minibatch 106/150
# average cost array(0.06611249669749072)
# epoch 5
# minibatch 107/150
# average cost array(0.05203285760965352)
# epoch 5
# minibatch 108/150
# average cost array(0.03383398579439929)
# epoch 5
# minibatch 109/150
# average cost array(0.056142851721640054)
# epoch 5
# minibatch 110/150
# average cost array(0.04471284021054715)
# epoch 5
# minibatch 111/150
# average cost array(0.04565675326900203)
# epoch 5
# minibatch 112/150
# average cost array(0.05026891300402938)
# epoch 5
# minibatch 113/150
# average cost array(0.03991588786903914)
# epoch 5
# minibatch 114/150
# average cost array(0.04246389052475976)
# epoch 5
# minibatch 115/150
# average cost array(0.05980347090919612)
# epoch 5
# minibatch 116/150
# average cost array(0.046075520433431064)
# epoch 5
# minibatch 117/150
# average cost array(0.06501486128586229)
# epoch 5
# minibatch 118/150
# average cost array(0.0431538397774674)
# epoch 5
# minibatch 119/150
# average cost array(0.05024230973652664)
# epoch 5
# minibatch 120/150
# average cost array(0.04267597582872099)
# epoch 5
# minibatch 121/150
# average cost array(0.05183251504650851)
# epoch 5
# minibatch 122/150
# average cost array(0.04421369562408652)
# epoch 5
# minibatch 123/150
# average cost array(0.04482644749676186)
# epoch 5
# minibatch 124/150
# average cost array(0.05031975925430744)
# epoch 5
# minibatch 125/150
# average cost array(0.05424257149561866)
# epoch 5
# minibatch 126/150
# average cost array(0.05432449147824041)
# epoch 5
# minibatch 127/150
# average cost array(0.04476526231061277)
# epoch 5
# minibatch 128/150
# average cost array(0.055869973886408256)
# epoch 5
# minibatch 129/150
# average cost array(0.060300730752387774)
# epoch 5
# minibatch 130/150
# average cost array(0.044752678600363284)
# epoch 5
# minibatch 131/150
# average cost array(0.04742865181235136)
# epoch 5
# minibatch 132/150
# average cost array(0.036211409903436395)
# epoch 5
# minibatch 133/150
# ...
# epoch 49
# minibatch 67/150
# average cost array(0.001417911797517823)
# epoch 49
# minibatch 68/150
# average cost array(0.0013368065299489663)
# epoch 49
# minibatch 69/150
# average cost array(0.001651601600444205)
# epoch 49
# minibatch 70/150
# average cost array(0.002582370046553144)
# epoch 49
# minibatch 71/150
# average cost array(0.002051561743931205)
# epoch 49
# minibatch 72/150
# average cost array(0.001386965910736336)
# epoch 49
# minibatch 73/150
# average cost array(0.0007882961662182923)
# epoch 49
# minibatch 74/150
# average cost array(0.0016448928643710155)
# epoch 49
# minibatch 75/150
# average cost array(0.0017025927975801557)
# epoch 49
# minibatch 76/150
# average cost array(0.0010608707537603681)
# epoch 49
# minibatch 77/150
# average cost array(0.0007123031800895698)
# epoch 49
# minibatch 78/150
# average cost array(0.0024718867852311396)
# epoch 49
# minibatch 79/150
# average cost array(0.00040621322958351295)
# epoch 49
# minibatch 80/150
# average cost array(0.0009053758712816503)
# epoch 49
# minibatch 81/150
# average cost array(0.0003624873457616476)
# epoch 49
# minibatch 82/150
# average cost array(0.001155398835885767)
# epoch 49
# minibatch 83/150
# average cost array(0.0006647461685949803)
# epoch 49
# minibatch 84/150
# average cost array(0.0003788894420584716)
# epoch 49
# minibatch 85/150
# average cost array(0.00067101414605993)
# epoch 49
# minibatch 86/150
# average cost array(0.0004548358856081654)
# epoch 49
# minibatch 87/150
# average cost array(0.0003918348006614345)
# epoch 49
# minibatch 88/150
# average cost array(0.0006628816068167836)
# epoch 49
# minibatch 89/150
# average cost array(0.0004665901803258313)
# epoch 49
# minibatch 90/150
# average cost array(0.0005875625684922215)
# epoch 49
# minibatch 91/150
# average cost array(0.0012717153157391452)
# epoch 49
# minibatch 92/150
# average cost array(0.001269434239646041)
# epoch 49
# minibatch 93/150
# average cost array(0.001148036432500682)
# epoch 49
# minibatch 94/150
# average cost array(0.000814710014324811)
# epoch 49
# minibatch 95/150
# average cost array(0.0006673854205863236)
# epoch 49
# minibatch 96/150
# average cost array(0.0005636640192327004)
# epoch 49
# minibatch 97/150
# average cost array(0.0009330409341144791)
# epoch 49
# minibatch 98/150
# average cost array(0.0016814581593413008)
# epoch 49
# minibatch 99/150
# average cost array(0.0006778562599109724)
# epoch 49
# minibatch 100/150
# average cost array(0.0009094290455844512)
# epoch 49
# minibatch 101/150
# average cost array(0.0012045982315598705)
# epoch 49
# minibatch 102/150
# average cost array(0.0011802271001664633)
# epoch 49
# minibatch 103/150
# average cost array(0.0007367859300935933)
# epoch 49
# minibatch 104/150
# average cost array(0.0011086005655543331)
# epoch 49
# minibatch 105/150
# average cost array(0.0005139127795469465)
# epoch 49
# minibatch 106/150
# average cost array(0.0007986614516623039)
# epoch 49
# minibatch 107/150
# average cost array(0.001479798057282388)
# epoch 49
# minibatch 108/150
# average cost array(0.0004275198406855238)
# epoch 49
# minibatch 109/150
# average cost array(0.0010306176159130462)
# epoch 49
# minibatch 110/150
# average cost array(0.0011512451631830528)
# epoch 49
# minibatch 111/150
# average cost array(0.0013368511948614501)
# epoch 49
# minibatch 112/150
# average cost array(0.0009781687595340626)
# epoch 49
# minibatch 113/150
# average cost array(0.001780633614220722)
# epoch 49
# minibatch 114/150
# average cost array(0.0011057472285009892)
# epoch 49
# minibatch 115/150
# average cost array(0.000911182929907463)
# epoch 49
# minibatch 116/150
# average cost array(0.0013231254826969908)
# epoch 49
# minibatch 117/150
# average cost array(0.0006596183825964104)
# epoch 49
# minibatch 118/150
# average cost array(0.0006553796206450781)
# epoch 49
# minibatch 119/150
# average cost array(0.00029902004461409925)
# epoch 49
# minibatch 120/150
# average cost array(0.0005347293555013621)
# epoch 49
# minibatch 121/150
# average cost array(0.0011788383431470208)
# epoch 49
# minibatch 122/150
# average cost array(0.001184129672680586)
# epoch 49
# minibatch 123/150
# average cost array(0.0006834032738247565)
# epoch 49
# minibatch 124/150
# average cost array(0.0011110531082512425)
# epoch 49
# minibatch 125/150
# average cost array(0.0006819035541657394)
# epoch 49
# minibatch 126/150
# average cost array(0.0008319361483899123)
# epoch 49
# minibatch 127/150
# average cost array(0.0009326800161257498)
# epoch 49
# minibatch 128/150
# average cost array(0.001418398436725991)
# epoch 49
# minibatch 129/150
# average cost array(0.0015560354621845167)
# epoch 49
# minibatch 130/150
# average cost array(0.0006042220781715166)
# epoch 49
# minibatch 131/150
# average cost array(0.0007591250733218692)
# epoch 49
# minibatch 132/150
# average cost array(0.0005128583992516944)
# epoch 49
# minibatch 133/150
# average cost array(0.000732928351480472)
# epoch 49
# minibatch 134/150
# average cost array(0.00037539084234179253)
# epoch 49
# minibatch 135/150
# average cost array(0.0008044265464681045)
# epoch 49
# minibatch 136/150
# average cost array(0.000255799435612664)
# epoch 49
# minibatch 137/150
# average cost array(0.0007289740431429027)
# epoch 49
# minibatch 138/150
# average cost array(0.0006530039311820795)
# epoch 49
# minibatch 139/150
# average cost array(0.0007892830234558385)
# epoch 49
# minibatch 140/150
# average cost array(0.0005809757231436954)
# epoch 49
# minibatch 141/150
# average cost array(0.0013035802857901966)
# epoch 49
# minibatch 142/150
# average cost array(0.0007230099385926543)
# epoch 49
# minibatch 143/150
# average cost array(0.00047380438794509996)
# epoch 49
# minibatch 144/150
# average cost array(0.0009080567268040879)
# epoch 49
# minibatch 145/150
# average cost array(0.0010124320222656073)
# epoch 49
# minibatch 146/150
# average cost array(0.0008427077566847188)
# epoch 49
# minibatch 147/150
# average cost array(0.000979402976294264)
# epoch 49
# minibatch 148/150
# average cost array(0.0005558653299006335)
# epoch 49
# minibatch 149/150
# average cost array(0.0006198955444446161)
# epoch 49
# minibatch 150/150
# average cost array(0.000639905439051253)
# epoch 50
# minibatch 1/150
# average cost array(0.0015024180223174564)
# epoch 50
# minibatch 2/150
# average cost array(0.0019465226731436164)
# epoch 50
# minibatch 3/150
# average cost array(0.0009172480651146776)
# epoch 50
# minibatch 4/150
# average cost array(0.001700120127877645)
# epoch 50
# minibatch 5/150
# average cost array(0.0016260035935082174)
# epoch 50
# minibatch 6/150
# average cost array(0.0012431989263966012)
# epoch 50
# minibatch 7/150
# average cost array(0.0007080445091943268)
# epoch 50
# minibatch 8/150
# average cost array(0.002804815495205403)
# epoch 50
# minibatch 9/150
# average cost array(0.002196770724579137)
# epoch 50
# minibatch 10/150
# average cost array(0.0014119258531075187)
# epoch 50
# minibatch 11/150
# average cost array(0.0015596540721132496)
# epoch 50
# minibatch 12/150
# average cost array(0.0015148015997273755)
# epoch 50
# minibatch 13/150
# average cost array(0.001190010278283912)
# epoch 50
# minibatch 14/150
# average cost array(0.0016443027844002729)
# epoch 50
# minibatch 15/150
# average cost array(0.0005186328327651584)
# epoch 50
# minibatch 16/150
# average cost array(0.0014528389047027547)
# epoch 50
# minibatch 17/150
# average cost array(0.0010643057186298373)
# epoch 50
# minibatch 18/150
# average cost array(0.0011028422667481164)
# epoch 50
# minibatch 19/150
# average cost array(0.0017355245068116803)
# epoch 50
# minibatch 20/150
# average cost array(0.0019365867970101407)
# epoch 50
# minibatch 21/150
# average cost array(0.0010032557246633285)
# epoch 50
# minibatch 22/150
# average cost array(0.0007985997577640393)
# epoch 50
# minibatch 23/150
# average cost array(0.002218201687567107)
# epoch 50
# minibatch 24/150
# average cost array(0.0015801032037883506)
# epoch 50
# minibatch 25/150
# average cost array(0.0009067482066505555)
# epoch 50
# minibatch 26/150
# average cost array(0.0013002258516260404)
# epoch 50
# minibatch 27/150
# average cost array(0.0012628658979303626)
# epoch 50
# minibatch 28/150
# average cost array(0.0017454412007736138)
# epoch 50
# minibatch 29/150
# average cost array(0.0019646374778148233)
# epoch 50
# minibatch 30/150
# average cost array(0.0015573418740631416)
# epoch 50
# minibatch 31/150
# average cost array(0.0009746292593751291)
# epoch 50
# minibatch 32/150
# average cost array(0.0019323549501107228)
# epoch 50
# minibatch 33/150
# average cost array(0.001808644920111783)
# epoch 50
# minibatch 34/150
# average cost array(0.001079993277819167)
# epoch 50
# minibatch 35/150
# average cost array(0.0017820568016508266)
# epoch 50
# minibatch 36/150
# average cost array(0.0017215720721679242)
# epoch 50
# minibatch 37/150
# average cost array(0.0020232190071828226)
# epoch 50
# minibatch 38/150
# average cost array(0.0013022720314605654)
# epoch 50
# minibatch 39/150
# average cost array(0.0017530359856919747)
# epoch 50
# minibatch 40/150
# average cost array(0.0012957080214118738)
# epoch 50
# minibatch 41/150
# average cost array(0.001726461129504611)
# epoch 50
# minibatch 42/150
# average cost array(0.0009283689184772098)
# epoch 50
# minibatch 43/150
# average cost array(0.003306662776739782)
# epoch 50
# minibatch 44/150
# average cost array(0.0017218019302709304)
# epoch 50
# minibatch 45/150
# average cost array(0.0016947852346009082)
# epoch 50
# minibatch 46/150
# average cost array(0.0009101290303573856)
# epoch 50
# minibatch 47/150
# average cost array(0.0019509245848717792)
# epoch 50
# minibatch 48/150
# average cost array(0.002390405175848359)
# epoch 50
# minibatch 49/150
# average cost array(0.0006945172777150295)
# epoch 50
# minibatch 50/150
# average cost array(0.0018068029923070904)
# epoch 50
# minibatch 51/150
# average cost array(0.0018486735118497873)
# epoch 50
# minibatch 52/150
# average cost array(0.0008530259196570919)
# epoch 50
# minibatch 53/150
# average cost array(0.0012955661858396164)
# epoch 50
# minibatch 54/150
# average cost array(0.001246564020244981)
# epoch 50
# minibatch 55/150
# average cost array(0.001744137819261473)
# epoch 50
# minibatch 56/150
# average cost array(0.0015890099052367009)
# epoch 50
# minibatch 57/150
# average cost array(0.001304866328625993)
# epoch 50
# minibatch 58/150
# average cost array(0.0016731664169889835)
# epoch 50
# minibatch 59/150
# average cost array(0.0020043583205910775)
# epoch 50
# minibatch 60/150
# average cost array(0.0013065696395269304)
# epoch 50
# minibatch 61/150
# average cost array(0.0016472496938601557)
# epoch 50
# minibatch 62/150
# average cost array(0.001303951761259073)
# epoch 50
# minibatch 63/150
# average cost array(0.0011671586786701992)
# epoch 50
# minibatch 64/150
# average cost array(0.0015255165897738363)
# epoch 50
# minibatch 65/150
# average cost array(0.0011619671501574206)
# epoch 50
# minibatch 66/150
# average cost array(0.0015095369912660546)
# epoch 50
# minibatch 67/150
# average cost array(0.001377810863034342)
# epoch 50
# minibatch 68/150
# average cost array(0.0013028275374429297)
# epoch 50
# minibatch 69/150
# average cost array(0.0016239926803440195)
# epoch 50
# minibatch 70/150
# average cost array(0.0025241005434453803)
# epoch 50
# minibatch 71/150
# average cost array(0.0020196853838454413)
# epoch 50
# minibatch 72/150
# average cost array(0.0013575996588094728)
# epoch 50
# minibatch 73/150
# average cost array(0.0007764289975073982)
# epoch 50
# minibatch 74/150
# average cost array(0.0016170671729525445)
# epoch 50
# minibatch 75/150
# average cost array(0.001671814466030506)
# epoch 50
# minibatch 76/150
# average cost array(0.0010425059606225502)
# epoch 50
# minibatch 77/150
# average cost array(0.0007022173847539278)
# epoch 50
# minibatch 78/150
# average cost array(0.002440620177730076)
# epoch 50
# minibatch 79/150
# average cost array(0.00040577442638053973)
# epoch 50
# minibatch 80/150
# average cost array(0.000888081280672684)
# epoch 50
# minibatch 81/150
# average cost array(0.00035132073148444964)
# epoch 50
# minibatch 82/150
# average cost array(0.0011414442725160697)
# epoch 50
# minibatch 83/150
# average cost array(0.0006573223388243819)
# epoch 50
# minibatch 84/150
# average cost array(0.0003702078398738109)
# epoch 50
# minibatch 85/150
# average cost array(0.0006697855745674642)
# epoch 50
# minibatch 86/150
# average cost array(0.0004489133939622225)
# epoch 50
# minibatch 87/150
# average cost array(0.00038406452738146076)
# epoch 50
# minibatch 88/150
# average cost array(0.000662576927742471)
# epoch 50
# minibatch 89/150
# average cost array(0.00046143969993490773)
# epoch 50
# minibatch 90/150
# average cost array(0.0005820101563557849)
# epoch 50
# minibatch 91/150
# average cost array(0.0012528718298131663)
# epoch 50
# minibatch 92/150
# average cost array(0.0012426900935534745)
# epoch 50
# minibatch 93/150
# average cost array(0.0011273598850392282)
# epoch 50
# minibatch 94/150
# average cost array(0.0008073472855712758)
# epoch 50
# minibatch 95/150
# average cost array(0.0006583286766275458)
# epoch 50
# minibatch 96/150
# average cost array(0.0005651725699394478)
# epoch 50
# minibatch 97/150
# average cost array(0.000920991331857458)
# epoch 50
# minibatch 98/150
# average cost array(0.001643391169654516)
# epoch 50
# minibatch 99/150
# average cost array(0.0006641344067236835)
# epoch 50
# minibatch 100/150
# average cost array(0.0008973461336792516)
# epoch 50
# minibatch 101/150
# average cost array(0.0011963419488946847)
# epoch 50
# minibatch 102/150
# average cost array(0.0011598260616763007)
# epoch 50
# minibatch 103/150
# average cost array(0.0007247767634024864)
# epoch 50
# minibatch 104/150
# average cost array(0.0010939061653287125)
# epoch 50
# minibatch 105/150
# average cost array(0.0004985712839772523)
# epoch 50
# minibatch 106/150
# average cost array(0.0008008598284623974)
# epoch 50
# minibatch 107/150
# average cost array(0.0014702621163300874)
# epoch 50
# minibatch 108/150
# average cost array(0.0004253386189525821)
# epoch 50
# minibatch 109/150
# average cost array(0.0010170291732758483)
# epoch 50
# minibatch 110/150
# average cost array(0.0011246006854318208)
# epoch 50
# minibatch 111/150
# average cost array(0.0013052478954063214)
# epoch 50
# minibatch 112/150
# average cost array(0.0009742490392126386)
# epoch 50
# minibatch 113/150
# average cost array(0.0017476144332340044)
# epoch 50
# minibatch 114/150
# average cost array(0.0010872772114383308)
# epoch 50
# minibatch 115/150
# average cost array(0.000892880843128502)
# epoch 50
# minibatch 116/150
# average cost array(0.0013002068674687474)
# epoch 50
# minibatch 117/150
# average cost array(0.0006538310123584293)
# epoch 50
# minibatch 118/150
# average cost array(0.0006481518382136722)
# epoch 50
# minibatch 119/150
# average cost array(0.00029808472035310166)
# epoch 50
# minibatch 120/150
# average cost array(0.0005238810065947253)
# epoch 50
# minibatch 121/150
# average cost array(0.0011561004319248446)
# epoch 50
# minibatch 122/150
# average cost array(0.001173762993772193)
# epoch 50
# minibatch 123/150
# average cost array(0.000669683612740447)
# epoch 50
# minibatch 124/150
# average cost array(0.0011092871962045195)
# epoch 50
# minibatch 125/150
# average cost array(0.0006880946227800943)
# epoch 50
# minibatch 126/150
# average cost array(0.0008131014706432514)
# epoch 50
# minibatch 127/150
# average cost array(0.0009318752086858101)
# epoch 50
# minibatch 128/150
# average cost array(0.001397091244780419)
# epoch 50
# minibatch 129/150
# average cost array(0.0015359858872581816)
# epoch 50
# minibatch 130/150
# average cost array(0.0006020234069982071)
# epoch 50
# minibatch 131/150
# average cost array(0.000754059115598604)
# epoch 50
# minibatch 132/150
# average cost array(0.000510626014848447)
# epoch 50
# minibatch 133/150
# average cost array(0.0007119826555799008)
# epoch 50
# minibatch 134/150
# average cost array(0.0003749504874110116)
# epoch 50
# minibatch 135/150
# average cost array(0.000786595233549524)
# epoch 50
# minibatch 136/150
# average cost array(0.0002565210991865004)
# epoch 50
# minibatch 137/150
# average cost array(0.0007263060224445611)
# epoch 50
# minibatch 138/150
# average cost array(0.0006557127277072746)
# epoch 50
# minibatch 139/150
# average cost array(0.0007825479172263285)
# epoch 50
# minibatch 140/150
# average cost array(0.0005718383207849257)
# epoch 50
# minibatch 141/150
# average cost array(0.0012802833325591223)
# epoch 50
# minibatch 142/150
# average cost array(0.0007038727752374486)
# epoch 50
# minibatch 143/150
# average cost array(0.00047158682960653784)
# epoch 50
# minibatch 144/150
# average cost array(0.0009035786136903853)
# epoch 50
# minibatch 145/150
# average cost array(0.000999131350759121)
# epoch 50
# minibatch 146/150
# average cost array(0.0008250019352634734)
# epoch 50
# minibatch 147/150
# average cost array(0.00096116071216644)
# epoch 50
# minibatch 148/150
# average cost array(0.0005477006548714541)
# epoch 50
# minibatch 149/150
# average cost array(0.0006066616679605778)
# epoch 50
# minibatch 150/150
# average cost array(0.0006360184762514792)
# testing

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1)
ax.plot(a1, v1, 'bo', lw=5, alpha=0.6, label='g = 1')
ax.plot(a3, v3, 'go', lw=5, alpha=0.6, label='g = 3')
ax.plot(a15, v15, 'ro', lw=5, alpha=0.6, label='g = 15')
ax.axis([0, 1, 0, 1])
ax.set_xlabel("Analytic")
ax.set_ylabel("Variational")

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1)
ax.plot(a1, nn1, 'bo', lw=5, alpha=0.6, label='g = 1')
ax.plot(a3, nn3, 'go', lw=5, alpha=0.6, label='g = 3')
ax.plot(a15, nn15, 'ro', lw=5, alpha=0.6, label='g = 15')
ax.axis([0, 1, 0, 1])
ax.set_xlabel("Analytic")
ax.set_ylabel("Neural Net")
